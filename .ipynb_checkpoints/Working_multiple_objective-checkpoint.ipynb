# %%
from pulp import *
import numpy as np
import pandas as pd
import random
import datetime

# %%
sample_num = 120
target = pd.DataFrame.from_dict(
    {
        "home_spread": [12],
        "home_spread_ml": [-110],
        "away_spread_ml": [-110],
        "total": [240],
        "over": [-110],
        "under": [-110]
    }
)

# %%
target
# Out:
#    home_spread  home_spread_ml  away_spread_ml  total  over  under
# 0           12            -110            -110    240  -110   -110

# %%
target["implied_home"] = np.where(
    target['home_spread_ml'] < 0,
    1.0 - (100.00/(abs(target["home_spread_ml"])+100.0)),
    100.0/(target["home_spread_ml"] + 100.0)
)
target["implied_away"] = np.where(
    target['away_spread_ml'] < 0,
    1.0 - (100.00/(abs(target["away_spread_ml"])+100.0)),
    100.0/(target["home_spread_ml"] + 100.0)
)
target["implied_over"] = np.where(
    target['over'] < 0,
    1.0-(100.00/(abs(target["over"])+100.0)),
    100.0/(target["over"]+100.0)
)
target["implied_under"] = np.where(
    target['under'] < 0,
    1.0-(100.00/(abs(target["under"])+100.0)),
    100.0/(target["under"]+100.0)
)

target["home_win"] = round((target["implied_home"] * 1.0) / (target["implied_home"] + target["implied_away"]),7)
target["away_win"] = round((target["implied_away"] * 1.0) / (target["implied_home"] + target["implied_away"]),7)
target["over_prob"] = round((target["implied_over"] * 1.0) / (target["implied_over"] + target["implied_under"]),7)
target["under_prob"] = round((target["implied_under"] * 1.0) / (target["implied_over"] + target["implied_under"]),7)

# %%
true_target = target[["total", "home_spread", "home_win", "away_win", "over_prob", "under_prob"]]

# %%
true_target_values = {key: val[0] for key, val in true_target.to_dict().items()}

# %%
true_target_values
# Out:
# {'total': 240,
#  'home_spread': 12,
#  'home_win': 0.5,
#  'away_win': 0.5,
#  'over_prob': 0.5,
#  'under_prob': 0.5}

# %%
clean_de_vigged = pd.read_excel("Sample_NBA_Data.xlsx")

# %%
clean_de_vigged.sort_values("game_id")
# Out:
#        game_id   game_date               home_team              away_team  \
# 3426         1  2011-03-04           Brooklyn Nets        Toronto Raptors
# 948          2  2011-03-05           Atlanta Hawks  Oklahoma City Thunder
# 12276        3  2011-03-05          Boston Celtics  Golden State Warriors
# 11454        4  2011-03-05           Brooklyn Nets        Toronto Raptors
# 12104        5  2011-03-05        Dallas Mavericks         Indiana Pacers
# ...        ...         ...                     ...                    ...
# 3656     12344  2022-03-02         Houston Rockets   Los Angeles Clippers
# 4679     12345  2022-03-02      Los Angeles Lakers       Dallas Mavericks
# 751      12346  2022-03-02  Minnesota Timberwolves  Golden State Warriors
# 5450     12347  2022-03-02         Toronto Raptors          Brooklyn Nets
# 1226     12348  2022-03-02      Washington Wizards        Detroit Pistons
#
#        home_score  away_score  spread  total  over_odds  under_odds  \
# 3426          116         103    -2.5  203.5       -111        -111
# 948           104         111    -2.5  192.0       -111        -111
# 12276         107         103    -9.5  205.5       -109        -107
# 11454         137         136    -2.0  206.0       -111        -111
# 12104         116         108    -9.0  208.0       -108        -109
# ...           ...         ...     ...    ...        ...         ...
# 3656          100         113     7.0  228.0       -109        -106
# 4679          104         109     5.0  219.0       -110        -107
# 751           129         114     3.5  231.0       -110        -102
# 5450          109         108    -8.0  219.0       -109        -106
# 1226          116         113    -3.5  217.5       -108        -110
#
#        away_true_prob  home_true_prob  under_true_prob  over_true_prob  \
# 3426              0.5             0.5         0.500000        0.500000
# 948               0.5             0.5         0.500000        0.500000
# 12276             0.5             0.5         0.497774        0.502226
# 11454             0.5             0.5         0.500000        0.500000
# 12104             0.5             0.5         0.501105        0.498895
# ...               ...             ...              ...             ...
# 3656              0.5             0.5         0.496637        0.503363
# 4679              0.5             0.5         0.496684        0.503316
# 751               0.5             0.5         0.490834        0.509166
# 5450              0.5             0.5         0.496637        0.503363
# 1226              0.5             0.5         0.502195        0.497805
#
#        home_margin  points  spread_home
# 3426            13     219         -2.5
# 948             -7     215         -2.5
# 12276            4     210         -9.5
# 11454            1     273         -2.0
# 12104            8     224         -9.0
# ...            ...     ...          ...
# 3656           -13     213          7.0
# 4679            -5     213          5.0
# 751             15     243          3.5
# 5450             1     217         -8.0
# 1226             3     229         -3.5
#
# [12348 rows x 17 columns]

# %%
unranked_data = clean_de_vigged.copy(deep=True)

# %%
date_diff = (pd.to_datetime(unranked_data["game_date"], format='%Y-%m-%d') - datetime.datetime.utcnow()) /np.timedelta64(1, 'D')

unranked_data["pythag_error"] = (
    abs(unranked_data["spread_home"] - true_target_values["home_spread"]) + abs(unranked_data["total"] - true_target_values["total"])
)
#     + (0.00001 * date_diff))

conditions = [
    unranked_data["points"] > true_target_values["total"],
    unranked_data["points"] < true_target_values["total"],
    unranked_data["points"] == true_target_values["total"]
]

values = [
    "over",
    "under",
    "push"
]

unranked_data["total_result"] = np.select(
    conditions, values
)

conditions = [
    unranked_data["home_score"] +  true_target_values["home_spread"] - unranked_data["away_score"]> 0,
    unranked_data["home_score"]  +  true_target_values["home_spread"] - unranked_data["away_score"]< 0,
    unranked_data["home_score"]  +  true_target_values["home_spread"] - unranked_data["away_score"]== 0
]

values = [
    "home_cover",
    "away_cover",
    "push"
]

unranked_data["spread_result"] = np.select(
    conditions, values
)

conditions = [
    unranked_data["spread_home"] < true_target_values["home_spread"],
    unranked_data["spread_home"] > true_target_values["home_spread"],
    unranked_data["spread_home"] == true_target_values["home_spread"]
]

values = [
    "home",
    "away",
    "push"
]


unranked_data["predictive_spread_cover"] = np.select(
    conditions, values
)

conditions = [
    unranked_data["total"] < true_target_values["total"],
    unranked_data["total"] > true_target_values["total"],
    unranked_data["total"] == true_target_values["total"]
]

values = [
    "under",
    "over",
    "push"
]


unranked_data["predictive_total"] = np.select(
    conditions, values
)

# %%
unranked_data
# Out:
#        game_id   game_date               home_team              away_team  \
# 0         2149  2014-01-01         Houston Rockets       Sacramento Kings
# 1         8549  2019-01-20          Indiana Pacers      Charlotte Hornets
# 2         2228  2014-01-12  Portland Trail Blazers         Boston Celtics
# 3         8628  2019-01-30           Brooklyn Nets          Chicago Bulls
# 4           15  2011-03-06    Los Angeles Clippers         Denver Nuggets
# ...        ...         ...                     ...                    ...
# 12343    10044  2020-02-25         Houston Rockets        New York Knicks
# 12344     1037  2012-12-31           Orlando Magic             Miami Heat
# 12345     7437  2018-02-25   Golden State Warriors  Oklahoma City Thunder
# 12346      483  2012-03-21         Houston Rockets     Los Angeles Lakers
# 12347     6883  2017-12-05    New Orleans Pelicans  Golden State Warriors
#
#        home_score  away_score  spread  total  over_odds  under_odds  ...  \
# 0             106         110   -10.0  215.5       -111        -107  ...
# 1             120          95    -8.0  218.5       -109        -110  ...
# 2             112         104   -12.0  210.0       -108        -108  ...
# 3             122         117    -6.5  220.5       -111        -109  ...
# 4             100          94    -2.0  208.0       -106        -109  ...
# ...           ...         ...     ...    ...        ...         ...  ...
# 12343         123         112   -13.0  226.5       -110        -110  ...
# 12344         110         112     9.5  194.5       -102        -106  ...
# 12345         112          80   -10.0  233.0       -107        -108  ...
# 12346         107         104     3.0  191.0       -108        -110  ...
# 12347         115         125     9.0  228.5       -110        -108  ...
#
#        under_true_prob  over_true_prob  home_margin  points  spread_home  \
# 0             0.495610        0.504390           -4     216        -10.0
# 1             0.501090        0.498910           25     215         -8.0
# 2             0.500000        0.500000            8     216        -12.0
# 3             0.497835        0.502165            5     239         -6.5
# 4             0.503363        0.496637            6     194         -2.0
# ...                ...             ...          ...     ...          ...
# 12343         0.500000        0.500000           11     235        -13.0
# 12344         0.504714        0.495286           -2     222          9.5
# 12345         0.501121        0.498879           32     192        -10.0
# 12346         0.502195        0.497805            3     211          3.0
# 12347         0.497805        0.502195          -10     240          9.0
#
#        pythag_error  total_result  spread_result predictive_spread_cover  \
# 0              46.5         under     home_cover                    home
# 1              41.5         under     home_cover                    home
# 2              54.0         under     home_cover                    home
# 3              38.0         under     home_cover                    home
# 4              46.0         under     home_cover                    home
# ...             ...           ...            ...                     ...
# 12343          38.5         under     home_cover                    home
# 12344          48.0         under     home_cover                    home
# 12345          29.0         under     home_cover                    home
# 12346          58.0         under     home_cover                    home
# 12347          14.5          push     home_cover                    home
#
#       predictive_total
# 0                under
# 1                under
# 2                under
# 3                under
# 4                under
# ...                ...
# 12343            under
# 12344            under
# 12345            under
# 12346            under
# 12347            under
#
# [12348 rows x 22 columns]

# %%
unranked_data["pythag_error_rank"] = unranked_data["pythag_error"].rank(method="first")

# %%
unranked_data.sort_values("pythag_error_rank")
# Out:
#        game_id   game_date              home_team              away_team  \
# 9116     10831  2021-03-19     Washington Wizards              Utah Jazz
# 6106      6846  2017-11-30     Los Angeles Lakers  Golden State Warriors
# 2487     10035  2020-02-24  Golden State Warriors   New Orleans Pelicans
# 3284     10036  2020-02-24  Golden State Warriors   New Orleans Pelicans
# 8153     10047  2020-02-25     Washington Wizards        Milwaukee Bucks
# ...        ...         ...                    ...                    ...
# 537       5239  2016-03-29              Utah Jazz     Los Angeles Lakers
# 4448      3529  2015-02-01          Atlanta Hawks     Philadelphia 76ers
# 11468     3876  2015-03-29          Chicago Bulls        New York Knicks
# 2542      3477  2015-01-25      Memphis Grizzlies     Philadelphia 76ers
# 5136      3476  2015-01-25      Memphis Grizzlies     Philadelphia 76ers
#
#        home_score  away_score  spread  total  over_odds  under_odds  ...  \
# 9116          131         122    10.5  241.0       -111        -108  ...
# 6106          123         127    13.0  242.0       -114        -114  ...
# 2487          101         115    10.0  238.0       -110        -108  ...
# 3284          101         115    10.0  238.0       -110        -108  ...
# 8153          134         137    12.5  243.5       -109        -108  ...
# ...           ...         ...     ...    ...        ...         ...  ...
# 537           123          75   -14.0  190.0       -109        -108  ...
# 4448           91          85   -16.5  192.0       -107        -111  ...
# 11468         111          80   -17.5  190.0       -108        -108  ...
# 2542          101          83   -18.0  190.0       -108        -108  ...
# 5136          101          83   -18.0  190.0       -108        -108  ...
#
#        over_true_prob  home_margin  points  spread_home  pythag_error  \
# 9116         0.503270            9     253         10.5           2.5
# 6106         0.500000           -4     250         13.0           3.0
# 2487         0.502195          -14     216         10.0           4.0
# 3284         0.502195          -14     216         10.0           4.0
# 8153         0.501105           -3     271         12.5           4.0
# ...               ...          ...     ...          ...           ...
# 537          0.501105           48     198        -14.0          76.0
# 4448         0.495610            6     176        -16.5          76.5
# 11468        0.500000           31     191        -17.5          79.5
# 2542         0.500000           18     184        -18.0          80.0
# 5136         0.500000           18     184        -18.0          80.0
#
#        total_result  spread_result  predictive_spread_cover predictive_total  \
# 9116           over     home_cover                     home             over
# 6106           over     home_cover                     away             over
# 2487          under     away_cover                     home            under
# 3284          under     away_cover                     home            under
# 8153           over     home_cover                     away             over
# ...             ...            ...                      ...              ...
# 537           under     home_cover                     home            under
# 4448          under     home_cover                     home            under
# 11468         under     home_cover                     home            under
# 2542          under     home_cover                     home            under
# 5136          under     home_cover                     home            under
#
#       pythag_error_rank
# 9116                1.0
# 6106                2.0
# 2487                3.0
# 3284                4.0
# 8153                5.0
# ...                 ...
# 537             12344.0
# 4448            12345.0
# 11468           12346.0
# 2542            12347.0
# 5136            12348.0
#
# [12348 rows x 23 columns]

# %%
ranked_data = unranked_data[["game_id", "spread_home", "pythag_error", "points", "home_margin", "home_score", "away_score", "total_result", "spread_result", "pythag_error_rank", "predictive_spread_cover", "predictive_total"]].sort_values("pythag_error_rank").copy(deep=True)

# %%
ranked_data.to_excel("ranked_data_from_python.xlsx",index=False)

# %%
ranked_data
# Out:
#        game_id  spread_home  pythag_error  points  home_margin  home_score  \
# 9116     10831         10.5           2.5     253            9         131
# 6106      6846         13.0           3.0     250           -4         123
# 2487     10035         10.0           4.0     216          -14         101
# 3284     10036         10.0           4.0     216          -14         101
# 8153     10047         12.5           4.0     271           -3         134
# ...        ...          ...           ...     ...          ...         ...
# 537       5239        -14.0          76.0     198           48         123
# 4448      3529        -16.5          76.5     176            6          91
# 11468     3876        -17.5          79.5     191           31         111
# 2542      3477        -18.0          80.0     184           18         101
# 5136      3476        -18.0          80.0     184           18         101
#
#        away_score total_result spread_result  pythag_error_rank  \
# 9116          122         over    home_cover                1.0
# 6106          127         over    home_cover                2.0
# 2487          115        under    away_cover                3.0
# 3284          115        under    away_cover                4.0
# 8153          137         over    home_cover                5.0
# ...           ...          ...           ...                ...
# 537            75        under    home_cover            12344.0
# 4448           85        under    home_cover            12345.0
# 11468          80        under    home_cover            12346.0
# 2542           83        under    home_cover            12347.0
# 5136           83        under    home_cover            12348.0
#
#       predictive_spread_cover predictive_total
# 9116                     home             over
# 6106                     away             over
# 2487                     home            under
# 3284                     home            under
# 8153                     away             over
# ...                       ...              ...
# 537                      home            under
# 4448                     home            under
# 11468                    home            under
# 2542                     home            under
# 5136                     home            under
#
# [12348 rows x 12 columns]

# %%
chosen_data = ranked_data[ranked_data["pythag_error_rank"] <= sample_num]

# %%
chosen_data["points"].median()
# Out:
# 238.5

# %%
chosen_data["total_result"].value_counts()
# Out:
# under    63
# over     55
# push      2
# Name: total_result, dtype: int64

# %%
chosen_data["spread_result"].value_counts()
# Out:
# home_cover    78
# away_cover    40
# push           2
# Name: spread_result, dtype: int64

# %%
chosen_data.query("total_result == 'under'")
# Out:
#        game_id  spread_home  pythag_error  points  home_margin  home_score  \
# 2487     10035         10.0           4.0     216          -14         101
# 3284     10036         10.0           4.0     216          -14         101
# 11182     9795         10.5           5.5     214          -20          97
# 11526     8188         11.0           5.5     239          -17         111
# 8189     10758          8.5           6.0     236            2         119
# ...        ...          ...           ...     ...          ...         ...
# 174      10058          7.5          11.5     194          -10          92
# 202       5407         11.5          11.5     214           20         117
# 1027      7210          8.5          11.5     231           -7         112
# 1163      6676          9.0          11.5     235          -19         108
# 1405      9583         11.0          11.5     220           12         116
#
#        away_score total_result spread_result  pythag_error_rank  \
# 2487          115        under    away_cover                3.0
# 3284          115        under    away_cover                4.0
# 11182         117        under    away_cover               11.0
# 11526         128        under    away_cover               12.0
# 8189          117        under    home_cover               14.0
# ...           ...          ...           ...                ...
# 174           102        under    home_cover              115.0
# 202            97        under    home_cover              116.0
# 1027          119        under    home_cover              118.0
# 1163          127        under    away_cover              119.0
# 1405          104        under    home_cover              120.0
#
#       predictive_spread_cover predictive_total
# 2487                     home            under
# 3284                     home            under
# 11182                    home            under
# 11526                    home            under
# 8189                     home            under
# ...                       ...              ...
# 174                      home            under
# 202                      home            under
# 1027                     home            under
# 1163                     home            under
# 1405                     home            under
#
# [63 rows x 12 columns]

# %%
chosen_data["pythag_error_rank"].sum()
# Out:
# 7260.0

# %%
chosen = LpVariable.dicts(
            "chosen",
            (
                np.array(unranked_data["game_id"])
            ),
            lowBound=0,
            cat="Binary",
        )

# %%
np.array(unranked_data["game_id"])
# Out:
# array([2149, 8549, 2228, ..., 7437,  483, 6883], dtype=int64)

# %%
chosen
# Out:
# {2149: chosen_2149,
#  8549: chosen_8549,
#  2228: chosen_2228,
#  8628: chosen_8628,
#  15: chosen_15,
#  6415: chosen_6415,
#  3334: chosen_3334,
#  9734: chosen_9734,
#  2702: chosen_2702,
#  9102: chosen_9102,
#  3887: chosen_3887,
#  10287: chosen_10287,
#  3966: chosen_3966,
#  10366: chosen_10366,
#  5151: chosen_5151,
#  11551: chosen_11551,
#  1280: chosen_1280,
#  7680: chosen_7680,
#  1359: chosen_1359,
#  7759: chosen_7759,
#  5388: chosen_5388,
#  11788: chosen_11788,
#  6336: chosen_6336,
#  3492: chosen_3492,
#  9892: chosen_9892,
#  3097: chosen_3097,
#  9497: chosen_9497,
#  3571: chosen_3571,
#  9971: chosen_9971,
#  1754: chosen_1754,
#  8154: chosen_8154,
#  3018: chosen_3018,
#  9418: chosen_9418,
#  1912: chosen_1912,
#  8312: chosen_8312,
#  4519: chosen_4519,
#  10919: chosen_10919,
#  2860: chosen_2860,
#  9260: chosen_9260,
#  4835: chosen_4835,
#  11235: chosen_11235,
#  1833: chosen_1833,
#  8233: chosen_8233,
#  4440: chosen_4440,
#  10840: chosen_10840,
#  6257: chosen_6257,
#  5546: chosen_5546,
#  11946: chosen_11946,
#  1596: chosen_1596,
#  7996: chosen_7996,
#  2070: chosen_2070,
#  8470: chosen_8470,
#  6020: chosen_6020,
#  3413: chosen_3413,
#  9813: chosen_9813,
#  884: chosen_884,
#  7284: chosen_7284,
#  4756: chosen_4756,
#  11156: chosen_11156,
#  5862: chosen_5862,
#  12262: chosen_12262,
#  3176: chosen_3176,
#  9576: chosen_9576,
#  4598: chosen_4598,
#  10998: chosen_10998,
#  726: chosen_726,
#  7126: chosen_7126,
#  1042: chosen_1042,
#  7442: chosen_7442,
#  4993: chosen_4993,
#  11393: chosen_11393,
#  2781: chosen_2781,
#  3669: chosen_3669,
#  10069: chosen_10069,
#  3748: chosen_3748,
#  10148: chosen_10148,
#  1535: chosen_1535,
#  7935: chosen_7935,
#  4854: chosen_4854,
#  11254: chosen_11254,
#  508: chosen_508,
#  6908: chosen_6908,
#  5012: chosen_5012,
#  11412: chosen_11412,
#  4617: chosen_4617,
#  11017: chosen_11017,
#  3274: chosen_3274,
#  9674: chosen_9674,
#  4222: chosen_4222,
#  10622: chosen_10622,
#  3432: chosen_3432,
#  9832: chosen_9832,
#  5091: chosen_5091,
#  11491: chosen_11491,
#  4538: chosen_4538,
#  10938: chosen_10938,
#  9181: chosen_9181,
#  5783: chosen_5783,
#  12183: chosen_12183,
#  489: chosen_489,
#  6889: chosen_6889,
#  331: chosen_331,
#  6731: chosen_6731,
#  647: chosen_647,
#  7047: chosen_7047,
#  1991: chosen_1991,
#  8391: chosen_8391,
#  2939: chosen_2939,
#  9339: chosen_9339,
#  4203: chosen_4203,
#  10603: chosen_10603,
#  568: chosen_568,
#  6968: chosen_6968,
#  2623: chosen_2623,
#  9023: chosen_9023,
#  3255: chosen_3255,
#  9655: chosen_9655,
#  1438: chosen_1438,
#  7838: chosen_7838,
#  4677: chosen_4677,
#  11077: chosen_11077,
#  6099: chosen_6099,
#  2544: chosen_2544,
#  8944: chosen_8944,
#  2307: chosen_2307,
#  8707: chosen_8707,
#  805: chosen_805,
#  7205: chosen_7205,
#  1675: chosen_1675,
#  8075: chosen_8075,
#  3650: chosen_3650,
#  10050: chosen_10050,
#  5941: chosen_5941,
#  12341: chosen_12341,
#  5072: chosen_5072,
#  11472: chosen_11472,
#  94: chosen_94,
#  6494: chosen_6494,
#  5625: chosen_5625,
#  12025: chosen_12025,
#  2465: chosen_2465,
#  8865: chosen_8865,
#  5467: chosen_5467,
#  11867: chosen_11867,
#  2789: chosen_2789,
#  9189: chosen_9189,
#  2868: chosen_2868,
#  9268: chosen_9268,
#  655: chosen_655,
#  7055: chosen_7055,
#  3974: chosen_3974,
#  10374: chosen_10374,
#  1920: chosen_1920,
#  8320: chosen_8320,
#  3342: chosen_3342,
#  9742: chosen_9742,
#  2473: chosen_2473,
#  8873: chosen_8873,
#  2394: chosen_2394,
#  8794: chosen_8794,
#  2552: chosen_2552,
#  8952: chosen_8952,
#  6028: chosen_6028,
#  4132: chosen_4132,
#  10532: chosen_10532,
#  3737: chosen_3737,
#  10137: chosen_10137,
#  4211: chosen_4211,
#  10611: chosen_10611,
#  2710: chosen_2710,
#  9110: chosen_9110,
#  4053: chosen_4053,
#  10453: chosen_10453,
#  3658: chosen_3658,
#  10058: chosen_10058,
#  3500: chosen_3500,
#  9900: chosen_9900,
#  5159: chosen_5159,
#  11559: chosen_11559,
#  2631: chosen_2631,
#  9031: chosen_9031,
#  5080: chosen_5080,
#  11480: chosen_11480,
#  260: chosen_260,
#  6660: chosen_6660,
#  6186: chosen_6186,
#  4527: chosen_4527,
#  10927: chosen_10927,
#  2947: chosen_2947,
#  9347: chosen_9347,
#  5475: chosen_5475,
#  11875: chosen_11875,
#  3353: chosen_3353,
#  9753: chosen_9753,
#  4380: chosen_4380,
#  10780: chosen_10780,
#  6039: chosen_6039,
#  3590: chosen_3590,
#  9990: chosen_9990,
#  666: chosen_666,
#  7066: chosen_7066,
#  6355: chosen_6355,
#  5407: chosen_5407,
#  11807: chosen_11807,
#  1140: chosen_1140,
#  7540: chosen_7540,
#  1377: chosen_1377,
#  7777: chosen_7777,
#  5960: chosen_5960,
#  2404: chosen_2404,
#  8804: chosen_8804,
#  6276: chosen_6276,
#  2246: chosen_2246,
#  8646: chosen_8646,
#  5486: chosen_5486,
#  11886: chosen_11886,
#  252: chosen_252,
#  6652: chosen_6652,
#  410: chosen_410,
#  6810: chosen_6810,
#  5704: chosen_5704,
#  12104: chosen_12104,
#  2386: chosen_2386,
#  8786: chosen_8786,
#  3808: chosen_3808,
#  10208: chosen_10208,
#  1517: chosen_1517,
#  7917: chosen_7917,
#  4282: chosen_4282,
#  10682: chosen_10682,
#  173: chosen_173,
#  6573: chosen_6573,
#  5230: chosen_5230,
#  11630: chosen_11630,
#  1121: chosen_1121,
#  7521: chosen_7521,
#  6178: chosen_6178,
#  4361: chosen_4361,
#  10761: chosen_10761,
#  4045: chosen_4045,
#  1524: chosen_1524,
#  7924: chosen_7924,
#  4843: chosen_4843,
#  11243: chosen_11243,
#  5396: chosen_5396,
#  11796: chosen_11796,
#  102: chosen_102,
#  6502: chosen_6502,
#  1366: chosen_1366,
#  7766: chosen_7766,
#  23: chosen_23,
#  6423: chosen_6423,
#  1445: chosen_1445,
#  7845: chosen_7845,
#  1129: chosen_1129,
#  7529: chosen_7529,
#  497: chosen_497,
#  6897: chosen_6897,
#  4606: chosen_4606,
#  11006: chosen_11006,
#  1287: chosen_1287,
#  7687: chosen_7687,
#  339: chosen_339,
#  6739: chosen_6739,
#  2562: chosen_2562,
#  8962: chosen_8962,
#  113: chosen_113,
#  6513: chosen_6513,
#  982: chosen_982,
#  7382: chosen_7382,
#  2009: chosen_2009,
#  8409: chosen_8409,
#  2167: chosen_2167,
#  8567: chosen_8567,
#  4933: chosen_4933,
#  11333: chosen_11333,
#  271: chosen_271,
#  6671: chosen_6671,
#  5723: chosen_5723,
#  12123: chosen_12123,
#  3511: chosen_3511,
#  9911: chosen_9911,
#  2088: chosen_2088,
#  8488: chosen_8488,
#  192: chosen_192,
#  6592: chosen_6592,
#  2800: chosen_2800,
#  9200: chosen_9200,
#  4696: chosen_4696,
#  11096: chosen_11096,
#  5328: chosen_5328,
#  11728: chosen_11728,
#  4301: chosen_4301,
#  10701: chosen_10701,
#  6118: chosen_6118,
#  4459: chosen_4459,
#  10859: chosen_10859,
#  3116: chosen_3116,
#  9516: chosen_9516,
#  903: chosen_903,
#  7303: chosen_7303,
#  2641: chosen_2641,
#  9041: chosen_9041,
#  3827: chosen_3827,
#  10227: chosen_10227,
#  2325: chosen_2325,
#  8725: chosen_8725,
#  4143: chosen_4143,
#  10543: chosen_10543,
#  1298: chosen_1298,
#  7698: chosen_7698,
#  34: chosen_34,
#  6434: chosen_6434,
#  6197: chosen_6197,
#  587: chosen_587,
#  6987: chosen_6987,
#  4775: chosen_4775,
#  11175: chosen_11175,
#  4064: chosen_4064,
#  10464: chosen_10464,
#  2879: chosen_2879,
#  9279: chosen_9279,
#  1219: chosen_1219,
#  7619: chosen_7619,
#  350: chosen_350,
#  6750: chosen_6750,
#  1456: chosen_1456,
#  7856: chosen_7856,
#  1061: chosen_1061,
#  7461: chosen_7461,
#  745: chosen_745,
#  7145: chosen_7145,
#  5170: chosen_5170,
#  11570: chosen_11570,
#  1930: chosen_1930,
#  8330: chosen_8330,
#  6107: chosen_6107,
#  2236: chosen_2236,
#  8636: chosen_8636,
#  5238: chosen_5238,
#  11638: chosen_11638,
#  1208: chosen_1208,
#  7608: chosen_7608,
#  971: chosen_971,
#  7371: chosen_7371,
#  3421: chosen_3421,
#  9821: chosen_9821,
#  3816: chosen_3816,
#  10216: chosen_10216,
#  181: chosen_181,
#  6581: chosen_6581,
#  5870: chosen_5870,
#  12270: chosen_12270,
#  3579: chosen_3579,
#  9979: chosen_9979,
#  5791: chosen_5791,
#  12191: chosen_12191,
#  6265: chosen_6265,
#  2078: chosen_2078,
#  8478: chosen_8478,
#  5317: chosen_5317,
#  11717: chosen_11717,
#  2315: chosen_2315,
#  8715: chosen_8715,
#  3263: chosen_3263,
#  9663: chosen_9663,
#  6344: chosen_6344,
#  734: chosen_734,
#  7134: chosen_7134,
#  3895: chosen_3895,
#  10295: chosen_10295,
#  1999: chosen_1999,
#  8399: chosen_8399,
#  813: chosen_813,
#  7213: chosen_7213,
#  576: chosen_576,
#  6976: chosen_6976,
#  1682: chosen_1682,
#  8082: chosen_8082,
#  4685: chosen_4685,
#  11085: chosen_11085,
#  3184: chosen_3184,
#  9584: chosen_9584,
#  1050: chosen_1050,
#  5565: chosen_5565,
#  11965: chosen_11965,
#  3985: chosen_3985,
#  10385: chosen_10385,
#  5249: chosen_5249,
#  11649: chosen_11649,
#  5802: chosen_5802,
#  12202: chosen_12202,
#  824: chosen_824,
#  7224: chosen_7224,
#  3906: chosen_3906,
#  10306: chosen_10306,
#  429: chosen_429,
#  6829: chosen_6829,
#  1851: chosen_1851,
#  8251: chosen_8251,
#  2958: chosen_2958,
#  9358: chosen_9358,
#  5881: chosen_5881,
#  12281: chosen_12281,
#  3195: chosen_3195,
#  9595: chosen_9595,
#  1614: chosen_1614,
#  8014: chosen_8014,
#  7450: chosen_7450,
#  892: chosen_892,
#  7292: chosen_7292,
#  5633: chosen_5633,
#  12033: chosen_12033,
#  4290: chosen_4290,
#  10690: chosen_10690,
#  3105: chosen_3105,
#  9505: chosen_9505,
#  4369: chosen_4369,
#  10769: chosen_10769,
#  5949: chosen_5949,
#  4922: chosen_4922,
#  11322: chosen_11322,
#  5001: chosen_5001,
#  11401: chosen_11401,
#  4764: chosen_4764,
#  11164: chosen_11164,
#  3026: chosen_3026,
#  9426: chosen_9426,
#  5712: chosen_5712,
#  12112: chosen_12112,
#  2157: chosen_2157,
#  8557: chosen_8557,
#  3349: chosen_3349,
#  9749: chosen_9749,
#  3428: chosen_3428,
#  9828: chosen_9828,
#  1215: chosen_1215,
#  7615: chosen_7615,
#  4534: chosen_4534,
#  10934: chosen_10934,
#  3902: chosen_3902,
#  10302: chosen_10302,
#  188: chosen_188,
#  6588: chosen_6588,
#  4692: chosen_4692,
#  11092: chosen_11092,
#  4297: chosen_4297,
#  10697: chosen_10697,
#  5403: chosen_5403,
#  11803: chosen_11803,
#  4060: chosen_4060,
#  10460: chosen_10460,
#  3112: chosen_3112,
#  9512: chosen_9512,
#  2954: chosen_2954,
#  9354: chosen_9354,
#  267: chosen_267,
#  6667: chosen_6667,
#  5719: chosen_5719,
#  12119: chosen_12119,
#  5640: chosen_5640,
#  12040: chosen_12040,
#  30: chosen_30,
#  6430: chosen_6430,
#  3033: chosen_3033,
#  9433: chosen_9433,
#  5245: chosen_5245,
#  11645: chosen_11645,
#  4929: chosen_4929,
#  11329: chosen_11329,
#  5087: chosen_5087,
#  11487: chosen_11487,
#  109: chosen_109,
#  6509: chosen_6509,
#  1057: chosen_1057,
#  7457: chosen_7457,
#  5956: chosen_5956,
#  2084: chosen_2084,
#  8484: chosen_8484,
#  5166: chosen_5166,
#  2869: chosen_2869,
#  9269: chosen_9269,
#  2948: chosen_2948,
#  9348: chosen_9348,
#  735: chosen_735,
#  7135: chosen_7135,
#  4054: chosen_4054,
#  10454: chosen_10454,
#  2000: chosen_2000,
#  8400: chosen_8400,
#  3422: chosen_3422,
#  9822: chosen_9822,
#  2553: chosen_2553,
#  8953: chosen_8953,
#  2474: chosen_2474,
#  8874: chosen_8874,
#  6108: chosen_6108,
#  2632: chosen_2632,
#  9032: chosen_9032,
#  4212: chosen_4212,
#  10612: chosen_10612,
#  3817: chosen_3817,
#  10217: chosen_10217,
#  4291: chosen_4291,
#  11566: chosen_11566,
#  4218: chosen_4218,
#  10618: chosen_10618,
#  2796: chosen_2796,
#  9196: chosen_9196,
#  5324: chosen_5324,
#  11724: chosen_11724,
#  346: chosen_346,
#  6746: chosen_6746,
#  4613: chosen_4613,
#  11013: chosen_11013,
#  5798: chosen_5798,
#  12198: chosen_12198,
#  3270: chosen_3270,
#  9670: chosen_9670,
#  1926: chosen_1926,
#  8326: chosen_8326,
#  4771: chosen_4771,
#  11171: chosen_11171,
#  820: chosen_820,
#  7220: chosen_7220,
#  1689: chosen_1689,
#  8089: chosen_8089,
#  6351: chosen_6351,
#  10691: chosen_10691,
#  2790: chosen_2790,
#  9190: chosen_9190,
#  4133: chosen_4133,
#  10533: chosen_10533,
#  3738: chosen_3738,
#  10138: chosen_10138,
#  3580: chosen_3580,
#  9980: chosen_9980,
#  5239: chosen_5239,
#  11639: chosen_11639,
#  2711: chosen_2711,
#  9111: chosen_9111,
#  5160: chosen_5160,
#  11560: chosen_11560,
#  340: chosen_340,
#  6740: chosen_6740,
#  6266: chosen_6266,
#  4607: chosen_4607,
#  11007: chosen_11007,
#  5555: chosen_5555,
#  11955: chosen_11955,
#  1604: chosen_1604,
#  8004: chosen_8004,
#  3027: chosen_3027,
#  9427: chosen_9427,
#  182: chosen_182,
#  6582: chosen_6582,
#  5476: chosen_5476,
#  11876: chosen_11876,
#  4923: chosen_4923,
#  11323: chosen_11323,
#  1446: chosen_1446,
#  7846: chosen_7846,
#  103: chosen_103,
#  6503: chosen_6503,
#  1525: chosen_1525,
#  7925: chosen_7925,
#  577: chosen_577,
#  6977: chosen_6977,
#  4686: chosen_4686,
#  11086: chosen_11086,
#  1209: chosen_1209,
#  7609: chosen_7609,
#  419: chosen_419,
#  6819: chosen_6819,
#  1367: chosen_1367,
#  7767: chosen_7767,
#  662: chosen_662,
#  7062: chosen_7062,
#  1847: chosen_1847,
#  8247: chosen_8247,
#  4376: chosen_4376,
#  10776: chosen_10776,
#  2242: chosen_2242,
#  8642: chosen_8642,
#  6193: chosen_6193,
#  3981: chosen_3981,
#  10381: chosen_10381,
#  1768: chosen_1768,
#  8168: chosen_8168,
#  4139: chosen_4139,
#  10539: chosen_10539,
#  2480: chosen_2480,
#  8880: chosen_8880,
#  583: chosen_583,
#  6983: chosen_6983,
#  3191: chosen_3191,
#  9591: chosen_9591,
#  2005: chosen_2005,
#  8405: chosen_8405,
#  1531: chosen_1531,
#  6187: chosen_6187,
#  2316: chosen_2316,
#  8716: chosen_8716,
#  5318: chosen_5318,
#  11718: chosen_11718,
#  3501: chosen_3501,
#  9901: chosen_9901,
#  3896: chosen_3896,
#  10296: chosen_10296,
#  1288: chosen_1288,
#  7688: chosen_7688,
#  1051: chosen_1051,
#  7451: chosen_7451,
#  261: chosen_261,
#  6661: chosen_6661,
#  5950: chosen_5950,
#  3659: chosen_3659,
#  10059: chosen_10059,
#  5871: chosen_5871,
#  12271: chosen_12271,
#  2158: chosen_2158,
#  8558: chosen_8558,
#  6345: chosen_6345,
#  5397: chosen_5397,
#  7931: chosen_7931,
#  3823: chosen_3823,
#  10223: chosen_10223,
#  4455: chosen_4455,
#  10855: chosen_10855,
#  2559: chosen_2559,
#  8959: chosen_8959,
#  3507: chosen_3507,
#  9907: chosen_9907,
#  3744: chosen_3744,
#  10144: chosen_10144,
#  2638: chosen_2638,
#  9038: chosen_9038,
#  4850: chosen_4850,
#  11250: chosen_11250,
#  899: chosen_899,
#  7299: chosen_7299,
#  1136: chosen_1136,
#  7536: chosen_7536,
#  2875: chosen_2875,
#  9275: chosen_9275,
#  1294: chosen_1294,
#  7694: chosen_7694,
#  6035: chosen_6035,
#  11797: chosen_11797,
#  2395: chosen_2395,
#  8795: chosen_8795,
#  3343: chosen_3343,
#  9743: chosen_9743,
#  814: chosen_814,
#  7214: chosen_7214,
#  24: chosen_24,
#  6424: chosen_6424,
#  3975: chosen_3975,
#  10375: chosen_10375,
#  2079: chosen_2079,
#  8479: chosen_8479,
#  656: chosen_656,
#  7056: chosen_7056,
#  893: chosen_893,
#  7293: chosen_7293,
#  1762: chosen_1762,
#  8162: chosen_8162,
#  3264: chosen_3264,
#  9664: chosen_9664,
#  1130: chosen_1130,
#  7530: chosen_7530,
#  4765: chosen_4765,
#  5877: chosen_5877,
#  12277: chosen_12277,
#  3665: chosen_3665,
#  10065: chosen_10065,
#  1610: chosen_1610,
#  8010: chosen_8010,
#  741: chosen_741,
#  7141: chosen_7141,
#  425: chosen_425,
#  6825: chosen_6825,
#  1452: chosen_1452,
#  7852: chosen_7852,
#  6272: chosen_6272,
#  3586: chosen_3586,
#  9986: chosen_9986,
#  5008: chosen_5008,
#  11408: chosen_11408,
#  504: chosen_504,
#  6904: chosen_6904,
#  2717: chosen_2717,
#  9117: chosen_9117,
#  1373: chosen_1373,
#  7773: chosen_7773,
#  5482: chosen_5482,
#  2549: chosen_2549,
#  8949: chosen_8949,
#  2628: chosen_2628,
#  9028: chosen_9028,
#  415: chosen_415,
#  6815: chosen_6815,
#  3734: chosen_3734,
#  10134: chosen_10134,
#  1680: chosen_1680,
#  8080: chosen_8080,
#  3102: chosen_3102,
#  9502: chosen_9502,
#  2233: chosen_2233,
#  8633: chosen_8633,
#  2154: chosen_2154,
#  8554: chosen_8554,
#  2312: chosen_2312,
#  8712: chosen_8712,
#  5788: chosen_5788,
#  12188: chosen_12188,
#  3892: chosen_3892,
#  10292: chosen_10292,
#  3497: chosen_3497,
#  9897: chosen_9897,
#  11165: chosen_11165,
#  972: chosen_972,
#  7372: chosen_7372,
#  5713: chosen_5713,
#  12113: chosen_12113,
#  4370: chosen_4370,
#  10770: chosen_10770,
#  3185: chosen_3185,
#  9585: chosen_9585,
#  4449: chosen_4449,
#  10849: chosen_10849,
#  6029: chosen_6029,
#  5002: chosen_5002,
#  11402: chosen_11402,
#  4844: chosen_4844,
#  11244: chosen_11244,
#  5081: chosen_5081,
#  11481: chosen_11481,
#  3106: chosen_3106,
#  9506: chosen_9506,
#  5792: chosen_5792,
#  12192: chosen_12192,
#  2237: chosen_2237,
#  8637: chosen_8637,
#  3971: chosen_3971,
#  10371: chosen_10371,
#  2470: chosen_2470,
#  8870: chosen_8870,
#  20: chosen_20,
#  6420: chosen_6420,
#  5946: chosen_5946,
#  12346: chosen_12346,
#  3813: chosen_3813,
#  10213: chosen_10213,
#  3418: chosen_3418,
#  9818: chosen_9818,
#  3260: chosen_3260,
#  9660: chosen_9660,
#  4919: chosen_4919,
#  11319: chosen_11319,
#  2391: chosen_2391,
#  8791: chosen_8791,
#  4287: chosen_4287,
#  10687: chosen_10687,
#  4840: chosen_4840,
#  11240: chosen_11240,
#  2707: chosen_2707,
#  9107: chosen_9107,
#  789: chosen_789,
#  7189: chosen_7189,
#  868: chosen_868,
#  7268: chosen_7268,
#  5055: chosen_5055,
#  11455: chosen_11455,
#  1974: chosen_1974,
#  8374: chosen_8374,
#  1342: chosen_1342,
#  7742: chosen_7742,
#  4028: chosen_4028,
#  10428: chosen_10428,
#  2132: chosen_2132,
#  8532: chosen_8532,
#  1737: chosen_1737,
#  8137: chosen_8137,
#  1658: chosen_1658,
#  8058: chosen_8058,
#  394: chosen_394,
#  6794: chosen_6794,
#  552: chosen_552,
#  6952: chosen_6952,
#  1500: chosen_1500,
#  7900: chosen_7900,
#  5644: chosen_5644,
#  12044: chosen_12044,
#  1772: chosen_1772,
#  8172: chosen_8172,
#  2483: chosen_2483,
#  8883: chosen_8883,
#  3037: chosen_3037,
#  9437: chosen_9437,
#  1693: chosen_1693,
#  8093: chosen_8093,
#  1109: chosen_1109,
#  7509: chosen_7509,
#  1188: chosen_1188,
#  7588: chosen_7588,
#  2294: chosen_2294,
#  8694: chosen_8694,
#  5375: chosen_5375,
#  11775: chosen_11775,
#  4348: chosen_4348,
#  10748: chosen_10748,
#  2452: chosen_2452,
#  8852: chosen_8852,
#  1662: chosen_1662,
#  8062: chosen_8062,
#  236: chosen_236,
#  6636: chosen_6636,
#  3159: chosen_3159,
#  9559: chosen_9559,
#  473: chosen_473,
#  6873: chosen_6873,
#  3080: chosen_3080,
#  9480: chosen_9480,
#  5371: chosen_5371,
#  11771: chosen_11771,
#  2527: chosen_2527,
#  8927: chosen_8927,
#  78: chosen_78,
#  6478: chosen_6478,
#  315: chosen_315,
#  6715: chosen_6715,
#  5134: chosen_5134,
#  11534: chosen_11534,
#  4897: chosen_4897,
#  11297: chosen_11297,
#  4186: chosen_4186,
#  10586: chosen_10586,
#  710: chosen_710,
#  7110: chosen_7110,
#  6262: chosen_6262,
#  5235: chosen_5235,
#  11635: chosen_11635,
#  1284: chosen_1284,
#  7684: chosen_7684,
#  4603: chosen_4603,
#  11003: chosen_11003,
#  5156: chosen_5156,
#  11556: chosen_11556,
#  1126: chosen_1126,
#  7526: chosen_7526,
#  6183: chosen_6183,
#  1205: chosen_1205,
#  7605: chosen_7605,
#  4366: chosen_4366,
#  10766: chosen_10766,
#  889: chosen_889,
#  7289: chosen_7289,
#  257: chosen_257,
#  6657: chosen_6657,
#  1047: chosen_1047,
#  7447: chosen_7447,
#  99: chosen_99,
#  6499: chosen_6499,
#  2057: chosen_2057,
#  8457: chosen_8457,
#  714: chosen_714,
#  7114: chosen_7114,
#  2531: chosen_2531,
#  8931: chosen_8931,
#  872: chosen_872,
#  7272: chosen_7272,
#  793: chosen_793,
#  7193: chosen_7193,
#  1978: chosen_1978,
#  8378: chosen_8378,
#  1820: chosen_1820,
#  8220: chosen_8220,
#  3479: chosen_3479,
#  9879: chosen_9879,
#  1030: chosen_1030,
#  7430: chosen_7430,
#  3400: chosen_3400,
#  9800: chosen_9800,
#  3795: chosen_3795,
#  10195: chosen_10195,
#  4506: chosen_4506,
#  10906: chosen_10906,
#  2606: chosen_2606,
#  9006: chosen_9006,
#  5924: chosen_5924,
#  12324: chosen_12324,
#  3396: chosen_3396,
#  9796: chosen_9796,
#  3791: chosen_3791,
#  10191: chosen_10191,
#  5292: chosen_5292,
#  11692: chosen_11692,
#  2053: chosen_2053,
#  8453: chosen_8453,
#  4660: chosen_4660,
#  11060: chosen_11060,
#  5766: chosen_5766,
#  12166: chosen_12166,
#  3238: chosen_3238,
#  9638: chosen_9638,
#  5529: chosen_5529,
#  11929: chosen_11929,
#  6082: chosen_6082,
#  3633: chosen_3633,
#  10033: chosen_10033,
#  631: chosen_631,
#  1996: chosen_1996,
#  8396: chosen_8396,
#  5867: chosen_5867,
#  12267: chosen_12267,
#  4998: chosen_4998,
#  11398: chosen_11398,
#  968: chosen_968,
#  7368: chosen_7368,
#  731: chosen_731,
#  7131: chosen_7131,
#  3181: chosen_3181,
#  9581: chosen_9581,
#  6341: chosen_6341,
#  3576: chosen_3576,
#  9976: chosen_9976,
#  3339: chosen_3339,
#  9739: chosen_9739,
#  5551: chosen_5551,
#  11951: chosen_11951,
#  5630: chosen_5630,
#  12030: chosen_12030,
#  1838: chosen_1838,
#  8238: chosen_8238,
#  5077: chosen_5077,
#  4980: chosen_4980,
#  11380: chosen_11380,
#  2847: chosen_2847,
#  9247: chosen_9247,
#  6244: chosen_6244,
#  5217: chosen_5217,
#  11617: chosen_11617,
#  3716: chosen_3716,
#  10116: chosen_10116,
#  3558: chosen_3558,
#  9958: chosen_9958,
#  6086: chosen_6086,
#  2: chosen_2,
#  6402: chosen_6402,
#  2926: chosen_2926,
#  9326: chosen_9326,
#  3953: chosen_3953,
#  10353: chosen_10353,
#  4822: chosen_4822,
#  11222: chosen_11222,
#  5849: chosen_5849,
#  12249: chosen_12249,
#  1741: chosen_1741,
#  8141: chosen_8141,
#  556: chosen_556,
#  6956: chosen_6956,
#  6007: chosen_6007,
#  4111: chosen_4111,
#  10511: chosen_10511,
#  1899: chosen_1899,
#  8299: chosen_8299,
#  2373: chosen_2373,
#  8773: chosen_8773,
#  951: chosen_951,
#  7351: chosen_7351,
#  5928: chosen_5928,
#  12328: chosen_12328,
#  4032: chosen_4032,
#  10432: chosen_10432,
#  240: chosen_240,
#  6640: chosen_6640,
#  2768: chosen_2768,
#  9168: chosen_9168,
#  1583: chosen_1583,
#  7983: chosen_7983,
#  2136: chosen_2136,
#  8536: chosen_8536,
#  81: chosen_81,
#  7031: chosen_7031,
#  4502: chosen_4502,
#  10902: chosen_10902,
#  5687: chosen_5687,
#  12087: chosen_12087,
#  6320: chosen_6320,
#  1421: chosen_1421,
#  7821: chosen_7821,
#  2211: chosen_2211,
#  8611: chosen_8611,
#  1816: chosen_1816,
#  8216: chosen_8216,
#  4423: chosen_4423,
#  10823: chosen_10823,
#  5608: chosen_5608,
#  12008: chosen_12008,
#  ...}

# %%
pythag_errors = unranked_data[["game_id","pythag_error"]].set_index("game_id")["pythag_error"].to_dict()

# %%
prob = LpProblem("Pythag error minimize", LpMinimize)
# Out:
# D:\Documents\envs\shane\lib\site-packages\pulp\pulp.py:1199: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")

# %%
prob += (
    lpSum(
        [
            chosen[game_id] * pythag_errors[game_id]
            for game_id in unranked_data["game_id"].to_list()
        ]
    ),
    "Minimize pythag error",
)

# %%
prob
# Out:
# Pythag_error_minimize:
# MINIMIZE
# 51.0*chosen_1 + 59.0*chosen_10 + 48.5*chosen_100 + 56.0*chosen_1000 + 20.5*chosen_10000 + 33.0*chosen_10001 + 27.5*chosen_10002 + 49.5*chosen_10003 + 31.5*chosen_10004 + 40.5*chosen_10005 + 25.0*chosen_10006 + 21.5*chosen_10007 + 16.0*chosen_10008 + 45.0*chosen_10009 + 56.0*chosen_1001 + 14.0*chosen_10010 + 9.0*chosen_10011 + 45.0*chosen_10012 + 22.0*chosen_10013 + 29.0*chosen_10014 + 28.5*chosen_10015 + 17.5*chosen_10016 + 32.5*chosen_10017 + 37.5*chosen_10018 + 27.0*chosen_10019 + 45.5*chosen_1002 + 7.5*chosen_10020 + 31.5*chosen_10021 + 35.5*chosen_10022 + 21.5*chosen_10023 + 18.0*chosen_10024 + 37.5*chosen_10025 + 27.0*chosen_10026 + 45.0*chosen_10027 + 37.0*chosen_10028 + 43.0*chosen_10029 + 51.5*chosen_1003 + 34.0*chosen_10030 + 37.5*chosen_10031 + 21.0*chosen_10032 + 18.5*chosen_10033 + 18.5*chosen_10034 + 4.0*chosen_10035 + 4.0*chosen_10036 + 34.5*chosen_10037 + 34.5*chosen_10038 + 37.0*chosen_10039 + 59.0*chosen_1004 + 37.0*chosen_10040 + 42.5*chosen_10041 + 24.0*chosen_10042 + 27.0*chosen_10043 + 38.5*chosen_10044 + 27.5*chosen_10045 + 33.5*chosen_10046 + 4.0*chosen_10047 + 25.0*chosen_10048 + 52.5*chosen_10049 + 54.0*chosen_1005 + 21.5*chosen_10050 + 20.0*chosen_10051 + 22.5*chosen_10052 + 19.0*chosen_10053 + 43.5*chosen_10054 + 28.0*chosen_10055 + 26.0*chosen_10056 + 30.0*chosen_10057 + 11.5*chosen_10058 + 15.5*chosen_10059 + 42.0*chosen_1006 + 39.5*chosen_10060 + 17.0*chosen_10061 + 21.0*chosen_10062 + 44.0*chosen_10063 + 39.0*chosen_10064 + 49.5*chosen_10065 + 13.0*chosen_10066 + 39.0*chosen_10067 + 27.0*chosen_10068 + 26.5*chosen_10069 + 43.5*chosen_1007 + 35.5*chosen_10070 + 29.5*chosen_10071 + 41.0*chosen_10072 + 26.0*chosen_10073 + 43.0*chosen_10074 + 51.5*chosen_10075 + 30.0*chosen_10076 + 15.5*chosen_10077 + 18.0*chosen_10078 + 23.5*chosen_10079 + 47.0*chosen_1008 + 27.5*chosen_10080 + 34.0*chosen_10081 + 46.5*chosen_10082 + 13.0*chosen_10083 + 39.5*chosen_10084 + 9.0*chosen_10085 + 41.0*chosen_10086 + 46.5*chosen_10087 + 33.5*chosen_10088 + 12.0*chosen_10089 + 58.5*chosen_1009 + 12.0*chosen_10090 + 18.0*chosen_10091 + 18.0*chosen_10092 + 14.5*chosen_10093 + 25.5*chosen_10094 + 19.0*chosen_10095 + 19.5*chosen_10096 + 11.0*chosen_10097 + 39.0*chosen_10098 + 30.5*chosen_10099 + 49.0*chosen_101 + 61.0*chosen_1010 + 39.0*chosen_10100 + 37.0*chosen_10101 + 49.5*chosen_10102 + 45.5*chosen_10103 + 18.5*chosen_10104 + 23.0*chosen_10105 + 22.5*chosen_10106 + 31.0*chosen_10107 + 32.5*chosen_10108 + 18.5*chosen_10109 + 65.5*chosen_1011 + 34.5*chosen_10110 + 40.5*chosen_10111 + 42.5*chosen_10112 + 21.5*chosen_10113 + 24.0*chosen_10114 + 23.0*chosen_10115 + 34.5*chosen_10116 + 15.0*chosen_10117 + 16.5*chosen_10118 + 38.5*chosen_10119 + 53.0*chosen_1012 + 33.0*chosen_10120 + 29.5*chosen_10121 + 24.5*chosen_10122 + 41.0*chosen_10123 + 34.5*chosen_10124 + 25.0*chosen_10125 + 15.5*chosen_10126 + 22.0*chosen_10127 + 29.5*chosen_10128 + 16.5*chosen_10129 + 55.5*chosen_1013 + 18.0*chosen_10130 + 40.5*chosen_10131 + 38.5*chosen_10132 + 23.5*chosen_10133 + 33.5*chosen_10134 + 29.0*chosen_10135 + 28.0*chosen_10136 + 22.5*chosen_10137 + 23.5*chosen_10138 + 24.0*chosen_10139 + 65.5*chosen_1014 + 26.5*chosen_10140 + 26.5*chosen_10141 + 39.0*chosen_10142 + 39.0*chosen_10143 + 26.0*chosen_10144 + 26.0*chosen_10145 + 46.5*chosen_10146 + 46.5*chosen_10147 + 21.0*chosen_10148 + 21.0*chosen_10149 + 56.5*chosen_1015 + 14.5*chosen_10150 + 14.5*chosen_10151 + 35.0*chosen_10152 + 37.5*chosen_10153 + 34.0*chosen_10154 + 38.5*chosen_10155 + 18.0*chosen_10156 + 34.0*chosen_10157 + 38.0*chosen_10158 + 35.5*chosen_10159 + 39.0*chosen_1016 + 23.0*chosen_10160 + 16.5*chosen_10161 + 27.0*chosen_10162 + 24.5*chosen_10163 + 29.0*chosen_10164 + 56.5*chosen_10165 + 54.0*chosen_10166 + 24.5*chosen_10167 + 34.5*chosen_10168 + 24.5*chosen_10169 + 58.0*chosen_1017 + 20.0*chosen_10170 + 32.0*chosen_10171 + 33.0*chosen_10172 + 44.0*chosen_10173 + 24.0*chosen_10174 + 32.5*chosen_10175 + 29.0*chosen_10176 + 28.0*chosen_10177 + 21.5*chosen_10178 + 27.5*chosen_101 ...
# VARIABLES
# 0 <= chosen_1 <= 1 Integer
# 0 <= chosen_10 <= 1 Integer
# 0 <= chosen_100 <= 1 Integer
# 0 <= chosen_1000 <= 1 Integer
# 0 <= chosen_10000 <= 1 Integer
# 0 <= chosen_10001 <= 1 Integer
# 0 <= chosen_10002 <= 1 Integer
# 0 <= chosen_10003 <= 1 Integer
# 0 <= chosen_10004 <= 1 Integer
# 0 <= chosen_10005 <= 1 Integer
# 0 <= chosen_10006 <= 1 Integer
# 0 <= chosen_10007 <= 1 Integer
# 0 <= chosen_10008 <= 1 Integer
# 0 <= chosen_10009 <= 1 Integer
# 0 <= chosen_1001 <= 1 Integer
# 0 <= chosen_10010 <= 1 Integer
# 0 <= chosen_10011 <= 1 Integer
# 0 <= chosen_10012 <= 1 Integer
# 0 <= chosen_10013 <= 1 Integer
# 0 <= chosen_10014 <= 1 Integer
# 0 <= chosen_10015 <= 1 Integer
# 0 <= chosen_10016 <= 1 Integer
# 0 <= chosen_10017 <= 1 Integer
# 0 <= chosen_10018 <= 1 Integer
# 0 <= chosen_10019 <= 1 Integer
# 0 <= chosen_1002 <= 1 Integer
# 0 <= chosen_10020 <= 1 Integer
# 0 <= chosen_10021 <= 1 Integer
# 0 <= chosen_10022 <= 1 Integer
# 0 <= chosen_10023 <= 1 Integer
# 0 <= chosen_10024 <= 1 Integer
# 0 <= chosen_10025 <= 1 Integer
# 0 <= chosen_10026 <= 1 Integer
# 0 <= chosen_10027 <= 1 Integer
# 0 <= chosen_10028 <= 1 Integer
# 0 <= chosen_10029 <= 1 Integer
# 0 <= chosen_1003 <= 1 Integer
# 0 <= chosen_10030 <= 1 Integer
# 0 <= chosen_10031 <= 1 Integer
# 0 <= chosen_10032 <= 1 Integer
# 0 <= chosen_10033 <= 1 Integer
# 0 <= chosen_10034 <= 1 Integer
# 0 <= chosen_10035 <= 1 Integer
# 0 <= chosen_10036 <= 1 Integer
# 0 <= chosen_10037 <= 1 Integer
# 0 <= chosen_10038 <= 1 Integer
# 0 <= chosen_10039 <= 1 Integer
# 0 <= chosen_1004 <= 1 Integer
# 0 <= chosen_10040 <= 1 Integer
# 0 <= chosen_10041 <= 1 Integer
# 0 <= chosen_10042 <= 1 Integer
# 0 <= chosen_10043 <= 1 Integer
# 0 <= chosen_10044 <= 1 Integer
# 0 <= chosen_10045 <= 1 Integer
# 0 <= chosen_10046 <= 1 Integer
# 0 <= chosen_10047 <= 1 Integer
# 0 <= chosen_10048 <= 1 Integer
# 0 <= chosen_10049 <= 1 Integer
# 0 <= chosen_1005 <= 1 Integer
# 0 <= chosen_10050 <= 1 Integer
# 0 <= chosen_10051 <= 1 Integer
# 0 <= chosen_10052 <= 1 Integer
# 0 <= chosen_10053 <= 1 Integer
# 0 <= chosen_10054 <= 1 Integer
# 0 <= chosen_10055 <= 1 Integer
# 0 <= chosen_10056 <= 1 Integer
# 0 <= chosen_10057 <= 1 Integer
# 0 <= chosen_10058 <= 1 Integer
# 0 <= chosen_10059 <= 1 Integer
# 0 <= chosen_1006 <= 1 Integer
# 0 <= chosen_10060 <= 1 Integer
# 0 <= chosen_10061 <= 1 Integer
# 0 <= chosen_10062 <= 1 Integer
# 0 <= chosen_10063 <= 1 Integer
# 0 <= chosen_10064 <= 1 Integer
# 0 <= chosen_10065 <= 1 Integer
# 0 <= chosen_10066 <= 1 Integer
# 0 <= chosen_10067 <= 1 Integer
# 0 <= chosen_10068 <= 1 Integer
# 0 <= chosen_10069 <= 1 Integer
# 0 <= chosen_1007 <= 1 Integer
# 0 <= chosen_10070 <= 1 Integer
# 0 <= chosen_10071 <= 1 Integer
# 0 <= chosen_10072 <= 1 Integer
# 0 <= chosen_10073 <= 1 Integer
# 0 <= chosen_10074 <= 1 Integer
# 0 <= chosen_10075 <= 1 Integer
# 0 <= chosen_10076 <= 1 Integer
# 0 <= chosen_10077 <= 1 Integer
# 0 <= chosen_10078 <= 1 Integer
# 0 <= chosen_10079 <= 1 Integer
# 0 <= chosen_1008 <= 1 Integer
# 0 <= chosen_10080 <= 1 Integer
# 0 <= chosen_10081 <= 1 Integer
# 0 <= chosen_10082 <= 1 Integer
# 0 <= chosen_10083 <= 1 Integer
# 0 <= chosen_10084 <= 1 Integer
# 0 <= chosen_10085 <= 1 Integer
# 0 <= chosen_10086 <= 1 Integer
# 0 <= chosen_10087 <= 1 Integer
# 0 <= chosen_10088 <= 1 Integer
# 0 <= chosen_10089 <= 1 Integer
# 0 <= chosen_1009 <= 1 Integer
# 0 <= chosen_10090 <= 1 Integer
# 0 <= chosen_10091 <= 1 Integer
# 0 <= chosen_10092 <= 1 Integer
# 0 <= chosen_10093 <= 1 Integer
# 0 <= chosen_10094 <= 1 Integer
# 0 <= chosen_10095 <= 1 Integer
# 0 <= chosen_10096 <= 1 Integer
# 0 <= chosen_10097 <= 1 Integer
# 0 <= chosen_10098 <= 1 Integer
# 0 <= chosen_10099 <= 1 Integer
# 0 <= chosen_101 <= 1 Integer
# 0 <= chosen_1010 <= 1 Integer
# 0 <= chosen_10100 <= 1 Integer
# 0 <= chosen_10101 <= 1 Integer
# 0 <= chosen_10102 <= 1 Integer
# 0 <= chosen_10103 <= 1 Integer
# 0 <= chosen_10104 <= 1 Integer
# 0 <= chosen_10105 <= 1 Integer
# 0 <= chosen_10106 <= 1 Integer
# 0 <= chosen_10107 <= 1 Integer
# 0 <= chosen_10108 <= 1 Integer
# 0 <= chosen_10109 <= 1 Integer
# 0 <= chosen_1011 <= 1 Integer
# 0 <= chosen_10110 <= 1 Integer
# 0 <= chosen_10111 <= 1 Integer
# 0 <= chosen_10112 <= 1 Integer
# 0 <= chosen_10113 <= 1 Integer
# 0 <= chosen_10114 <= 1 Integer
# 0 <= chosen_10115 <= 1 Integer
# 0 <= chosen_10116 <= 1 Integer
# 0 <= chosen_10117 <= 1 Integer
# 0 <= chosen_10118 <= 1 Integer
# 0 <= chosen_10119 <= 1 Integer
# 0 <= chosen_1012 <= 1 Integer
# 0 <= chosen_10120 <= 1 Integer
# 0 <= chosen_10121 <= 1 Integer
# 0 <= chosen_10122 <= 1 Integer
# 0 <= chosen_10123 <= 1 Integer
# 0 <= chosen_10124 <= 1 Integer
# 0 <= chosen_10125 <= 1 Integer
# 0 <= chosen_10126 <= 1 Integer
# 0 <= chosen_10127 <= 1 Integer
# 0 <= chosen_10128 <= 1 Integer
# 0 <= chosen_10129 <= 1 Integer
# 0 <= chosen_1013 <= 1 Integer
# 0 <= chosen_10130 <= 1 Integer
# 0 <= chosen_10131 <= 1 Integer
# 0 <= chosen_10132 <= 1 Integer
# 0 <= chosen_10133 <= 1 Integer
# 0 <= chosen_10134 <= 1 Integer
# 0 <= chosen_10135 <= 1 Integer
# 0 <= chosen_10136 <= 1 Integer
# 0 <= chosen_10137 <= 1 Integer
# 0 <= chosen_10138 <= 1 Integer
# 0 <= chosen_10139 <= 1 Integer
# 0 <= chosen_1014 <= 1 Integer
# 0 <= chosen_10140 <= 1 Integer
# 0 <= chosen_10141 <= 1 Integer
# 0 <= chosen_10142 <= 1 Integer
# 0 <= chosen_10143 <= 1 Integer
# 0 <= chosen_10144 <= 1 Integer
# 0 <= chosen_10145 <= 1 Integer
# 0 <= chosen_10146 <= 1 Integer
# 0 <= chosen_10147 <= 1 Integer
# 0 <= chosen_10148 <= 1 Integer
# 0 <= chosen_10149 <= 1 Integer
# 0 <= chosen_1015 <= 1 Integer
# 0 <= chosen_10150 <= 1 Integer
# 0 <= chosen_10151 <= 1 Integer
# 0 <= chosen_10152 <= 1 Integer
# 0 <= chosen_10153 <= 1 Integer
# 0 <= chosen_10154 <= 1 Integer
# 0 <= chosen_10155 <= 1 Integer
# 0 <= chosen_10156 <= 1 Integer
# 0 <= chosen_10157 <= 1 Integer
# 0 <= chosen_10158 <= 1 Integer
# 0 <= chosen_10159 <= 1 Integer
# 0 <= chosen_1016 <= 1 Integer
# 0 <= chosen_10160 <= 1 Integer
# 0 <= chosen_10161 <= 1 Integer
# 0 <= chosen_10162 <= 1 Integer
# 0 <= chosen_10163 <= 1 Integer
# 0 <= chosen_10164 <= 1 Integer
# 0 <= chosen_10165 <= 1 Integer
# 0 <= chosen_10166 <= 1 Integer
# 0 <= chosen_10167 <= 1 Integer
# 0 <= chosen_10168 <= 1 Integer
# 0 <= chosen_10169 <= 1 Integer
# 0 <= chosen_1017 <= 1 Integer
# 0 <= chosen_10170 <= 1 Integer
# 0 <= chosen_10171 <= 1 Integer
# 0 <= chosen_10172 <= 1 Integer
# 0 <= chosen_10173 <= 1 Integer
# 0 <= chosen_10174 <= 1 Integer
# 0 <= chosen_10175 <= 1 Integer
# 0 <= chosen_10176 <= 1 Integer
# 0 <= chosen_10177 <= 1 Integer
# 0 <= chosen_10178 <= 1 Integer
# 0 <= chosen_10179 <= 1 Integer
# 0 <= chosen_1018 <= 1 Integer
# 0 <= chosen_10180 <= 1 Integer
# 0 <= chosen_10181 <= 1 Integer
# 0 <= chosen_10182 <= 1 Integer
# 0 <= chosen_10183 <= 1 Integer
# 0 <= chosen_10184 <= 1 Integer
# 0 <= chosen_10185 <= 1 Integer
# 0 <= chosen_10186 <= 1 Integer
# 0 <= chosen_10187 <= 1 Integer
# 0 <= chosen_10188 <= 1 Integer
# 0 <= chosen_10189 <= 1 Integer
# 0 <= chosen_1019 <= 1 Integer
# 0 <= chosen_10190 <= 1 Integer
# 0 <= chosen_10191 <= 1 Integer
# 0 <= chosen_10192 <= 1 Integer
# 0 <= chosen_10193 <= 1 Integer
# 0 <= chosen_10194 <= 1 Integer
# 0 <= chosen_10195 <= 1 Integer
# 0 <= chosen_10196 <= 1 Integer
# 0 <= chosen_10197 <= 1 Integer
# 0 <= chosen_10198 <= 1 Integer
# 0 <= chosen_10199 <= 1 Integer
# 0 <= chosen_102 <= 1 Integer
# 0 <= chosen_1020 <= 1 Integer
# 0 <= chosen_10200 <= 1 Integer
# 0 <= chosen_10201 <= 1 Integer
# 0 <= chosen_10202 <= 1 Integer
# 0 <= chosen_10203 <= 1 Integer
# 0 <= chosen_10204 <= 1 Integer
# 0 <= chosen_10205 <= 1 Integer
# 0 <= chosen_10206 <= 1 Integer
# 0 <= chosen_10207 <= 1 Integer
# 0 <= chosen_10208 <= 1 Integer
# 0 <= chosen_10209 <= 1 Integer
# 0 <= chosen_1021 <= 1 Integer
# 0 <= chosen_10210 <= 1 Integer
# 0 <= chosen_10211 <= 1 Integer
# 0 <= chosen_10212 <= 1 Integer
# 0 <= chosen_10213 <= 1 Integer
# 0 <= chosen_10214 <= 1 Integer
# 0 <= chosen_10215 <= 1 Integer
# 0 <= chosen_10216 <= 1 Integer
# 0 <= chosen_10217 <= 1 Integer
# 0 <= chosen_10218 <= 1 Integer
# 0 <= chosen_10219 <= 1 Integer
# 0 <= chosen_1022 <= 1 Integer
# 0 <= chosen_10220 <= 1 Integer
# 0 <= chosen_10221 <= 1 Integer
# 0 <= chosen_10222 <= 1 Integer
# 0 <= chosen_10223 <= 1 Integer
# 0 <= chosen_10224 <= 1 Integer
# 0 <= chosen_10225 <= 1 Integer
# 0 <= chosen_10226 <= 1 Integer
# 0 <= chosen_10227 <= 1 Integer
# 0 <= chosen_10228 <= 1 Integer
# 0 <= chosen_10229 <= 1 Integer
# 0 <= chosen_1023 <= 1 Integer
# 0 <= chosen_10230 <= 1 Integer
# 0 <= chosen_10231 <= 1 Integer
# 0 <= chosen_10232 <= 1 Integer
# 0 <= chosen_10233 <= 1 Integer
# 0 <= chosen_10234 <= 1 Integer
# 0 <= chosen_10235 <= 1 Integer
# 0 <= chosen_10236 <= 1 Integer
# 0 <= chosen_10237 <= 1 Integer
# 0 <= chosen_10238 <= 1 Integer
# 0 <= chosen_10239 <= 1 Integer
# 0 <= chosen_1024 <= 1 Integer
# 0 <= chosen_10240 <= 1 Integer
# 0 <= chosen_10241 <= 1 Integer
# 0 <= chosen_10242 <= 1 Integer
# 0 <= chosen_10243 <= 1 Integer
# 0 <= chosen_10244 <= 1 Integer
# 0 <= chosen_10245 <= 1 Integer
# 0 <= chosen_10246 <= 1 Integer
# 0 <= chosen_10247 <= 1 Integer
# 0 <= chosen_10248 <= 1 Integer
# 0 <= chosen_10249 <= 1 Integer
# 0 <= chosen_1025 <= 1 Integer
# 0 <= chosen_10250 <= 1 Integer
# 0 <= chosen_10251 <= 1 Integer
# 0 <= chosen_10252 <= 1 Integer
# 0 <= chosen_10253 <= 1 Integer
# 0 <= chosen_10254 <= 1 Integer
# 0 <= chosen_10255 <= 1 Integer
# 0 <= chosen_10256 <= 1 Integer
# 0 <= chosen_10257 <= 1 Integer
# 0 <= chosen_10258 <= 1 Integer
# 0 <= chosen_10259 <= 1 Integer
# 0 <= chosen_1026 <= 1 Integer
# 0 <= chosen_10260 <= 1 Integer
# 0 <= chosen_10261 <= 1 Integer
# 0 <= chosen_10262 <= 1 Integer
# 0 <= chosen_10263 <= 1 Integer
# 0 <= chosen_10264 <= 1 Integer
# 0 <= chosen_10265 <= 1 Integer
# 0 <= chosen_10266 <= 1 Integer
# 0 <= chosen_10267 <= 1 Integer
# 0 <= chosen_10268 <= 1 Integer
# 0 <= chosen_10269 <= 1 Integer
# 0 <= chosen_1027 <= 1 Integer
# 0 <= chosen_10270 <= 1 Integer
# 0 <= chosen_10271 <= 1 Integer
# 0 <= chosen_10272 <= 1 Integer
# 0 <= chosen_10273 <= 1 Integer
# 0 <= chosen_10274 <= 1 Integer
# 0 <= chosen_10275 <= 1 Integer
# 0 <= chosen_10276 <= 1 Integer
# 0 <= chosen_10277 <= 1 Integer
# 0 <= chosen_10278 <= 1 Integer
# 0 <= chosen_10279 <= 1 Integer
# 0 <= chosen_1028 <= 1 Integer
# 0 <= chosen_10280 <= 1 Integer
# 0 <= chosen_10281 <= 1 Integer
# 0 <= chosen_10282 <= 1 Integer
# 0 <= chosen_10283 <= 1 Integer
# 0 <= chosen_10284 <= 1 Integer
# 0 <= chosen_10285 <= 1 Integer
# 0 <= chosen_10286 <= 1 Integer
# 0 <= chosen_10287 <= 1 Integer
# 0 <= chosen_10288 <= 1 Integer
# 0 <= chosen_10289 <= 1 Integer
# 0 <= chosen_1029 <= 1 Integer
# 0 <= chosen_10290 <= 1 Integer
# 0 <= chosen_10291 <= 1 Integer
# 0 <= chosen_10292 <= 1 Integer
# 0 <= chosen_10293 <= 1 Integer
# 0 <= chosen_10294 <= 1 Integer
# 0 <= chosen_10295 <= 1 Integer
# 0 <= chosen_10296 <= 1 Integer
# 0 <= chosen_10297 <= 1 Integer
# 0 <= chosen_10298 <= 1 Integer
# 0 <= chosen_10299 <= 1 Integer
# 0 <= chosen_103 <= 1 Integer
# 0 <= chosen_1030 <= 1 Integer
# 0 <= chosen_10300 <= 1 Integer
# 0 <= chosen_10301 <= 1 Integer
# 0 <= chosen_10302 <= 1 Integer
# 0 <= chosen_10303 <= 1 Integer
# 0 <= chosen_10304 <= 1 Integer
# 0 <= chosen_10305 <= 1 Integer
# 0 <= chosen_10306 <= 1 Integer
# 0 <= chosen_10307 <= 1 Integer
# 0 <= chosen_10308 <= 1 Integer
# 0 <= chosen_10309 <= 1 Integer
# 0 <= chosen_1031 <= 1 Integer
# 0 <= chosen_10310 <= 1 Integer
# 0 <= chosen_10311 <= 1 Integer
# 0 <= chosen_10312 <= 1 Integer
# 0 <= chosen_10313 <= 1 Integer
# 0 <= chosen_10314 <= 1 Integer
# 0 <= chosen_10315 <= 1 Integer
# 0 <= chosen_10316 <= 1 Integer
# 0 <= chosen_10317 <= 1 Integer
# 0 <= chosen_10318 <= 1 Integer
# 0 <= chosen_10319 <= 1 Integer
# 0 <= chosen_1032 <= 1 Integer
# 0 <= chosen_10320 <= 1 Integer
# 0 <= chosen_10321 <= 1 Integer
# 0 <= chosen_10322 <= 1 Integer
# 0 <= chosen_10323 <= 1 Integer
# 0 <= chosen_10324 <= 1 Integer
# 0 <= chosen_10325 <= 1 Integer
# 0 <= chosen_10326 <= 1 Integer
# 0 <= chosen_10327 <= 1 Integer
# 0 <= chosen_10328 <= 1 Integer
# 0 <= chosen_10329 <= 1 Integer
# 0 <= chosen_1033 <= 1 Integer
# 0 <= chosen_10330 <= 1 Integer
# 0 <= chosen_10331 <= 1 Integer
# 0 <= chosen_10332 <= 1 Integer
# 0 <= chosen_10333 <= 1 Integer
# 0 <= chosen_10334 <= 1 Integer
# 0 <= chosen_10335 <= 1 Integer
# 0 <= chosen_10336 <= 1 Integer
# 0 <= chosen_10337 <= 1 Integer
# 0 <= chosen_10338 <= 1 Integer
# 0 <= chosen_10339 <= 1 Integer
# 0 <= chosen_1034 <= 1 Integer
# 0 <= chosen_10340 <= 1 Integer
# 0 <= chosen_10341 <= 1 Integer
# 0 <= chosen_10342 <= 1 Integer
# 0 <= chosen_10343 <= 1 Integer
# 0 <= chosen_10344 <= 1 Integer
# 0 <= chosen_10345 <= 1 Integer
# 0 <= chosen_10346 <= 1 Integer
# 0 <= chosen_10347 <= 1 Integer
# 0 <= chosen_10348 <= 1 Integer
# 0 <= chosen_10349 <= 1 Integer
# 0 <= chosen_1035 <= 1 Integer
# 0 <= chosen_10350 <= 1 Integer
# 0 <= chosen_10351 <= 1 Integer
# 0 <= chosen_10352 <= 1 Integer
# 0 <= chosen_10353 <= 1 Integer
# 0 <= chosen_10354 <= 1 Integer
# 0 <= chosen_10355 <= 1 Integer
# 0 <= chosen_10356 <= 1 Integer
# 0 <= chosen_10357 <= 1 Integer
# 0 <= chosen_10358 <= 1 Integer
# 0 <= chosen_10359 <= 1 Integer
# 0 <= chosen_1036 <= 1 Integer
# 0 <= chosen_10360 <= 1 Integer
# 0 <= chosen_10361 <= 1 Integer
# 0 <= chosen_10362 <= 1 Integer
# 0 <= chosen_10363 <= 1 Integer
# 0 <= chosen_10364 <= 1 Integer
# 0 <= chosen_10365 <= 1 Integer
# 0 <= chosen_10366 <= 1 Integer
# 0 <= chosen_10367 <= 1 Integer
# 0 <= chosen_10368 <= 1 Integer
# 0 <= chosen_10369 <= 1 Integer
# 0 <= chosen_1037 <= 1 Integer
# 0 <= chosen_10370 <= 1 Integer
# 0 <= chosen_10371 <= 1 Integer
# 0 <= chosen_10372 <= 1 Integer
# 0 <= chosen_10373 <= 1 Integer
# 0 <= chosen_10374 <= 1 Integer
# 0 <= chosen_10375 <= 1 Integer
# 0 <= chosen_10376 <= 1 Integer
# 0 <= chosen_10377 <= 1 Integer
# 0 <= chosen_10378 <= 1 Integer
# 0 <= chosen_10379 <= 1 Integer
# 0 <= chosen_1038 <= 1 Integer
# 0 <= chosen_10380 <= 1 Integer
# 0 <= chosen_10381 <= 1 Integer
# 0 <= chosen_10382 <= 1 Integer
# 0 <= chosen_10383 <= 1 Integer
# 0 <= chosen_10384 <= 1 Integer
# 0 <= chosen_10385 <= 1 Integer
# 0 <= chosen_10386 <= 1 Integer
# 0 <= chosen_10387 <= 1 Integer
# 0 <= chosen_10388 <= 1 Integer
# 0 <= chosen_10389 <= 1 Integer
# 0 <= chosen_1039 <= 1 Integer
# 0 <= chosen_10390 <= 1 Integer
# 0 <= chosen_10391 <= 1 Integer
# 0 <= chosen_10392 <= 1 Integer
# 0 <= chosen_10393 <= 1 Integer
# 0 <= chosen_10394 <= 1 Integer
# 0 <= chosen_10395 <= 1 Integer
# 0 <= chosen_10396 <= 1 Integer
# 0 <= chosen_10397 <= 1 Integer
# 0 <= chosen_10398 <= 1 Integer
# 0 <= chosen_10399 <= 1 Integer
# 0 <= chosen_104 <= 1 Integer
# 0 <= chosen_1040 <= 1 Integer
# 0 <= chosen_10400 <= 1 Integer
# 0 <= chosen_10401 <= 1 Integer
# 0 <= chosen_10402 <= 1 Integer
# 0 <= chosen_10403 <= 1 Integer
# 0 <= chosen_10404 <= 1 Integer
# 0 <= chosen_10405 <= 1 Integer
# 0 <= chosen_10406 <= 1 Integer
# 0 <= chosen_10407 <= 1 Integer
# 0 <= chosen_10408 <= 1 Integer
# 0 <= chosen_10409 <= 1 Integer
# 0 <= chosen_1041 <= 1 Integer
# 0 <= chosen_10410 <= 1 Integer
# 0 <= chosen_10411 <= 1 Integer
# 0 <= chosen_10412 <= 1 Integer
# 0 <= chosen_10413 <= 1 Integer
# 0 <= chosen_10414 <= 1 Integer
# 0 <= chosen_10415 <= 1 Integer
# 0 <= chosen_10416 <= 1 Integer
# 0 <= chosen_10417 <= 1 Integer
# 0 <= chosen_10418 <= 1 Integer
# 0 <= chosen_10419 <= 1 Integer
# 0 <= chosen_1042 <= 1 Integer
# 0 <= chosen_10420 <= 1 Integer
# 0 <= chosen_10421 <= 1 Integer
# 0 <= chosen_10422 <= 1 Integer
# 0 <= chosen_10423 <= 1 Integer
# 0 <= chosen_10424 <= 1 Integer
# 0 <= chosen_10425 <= 1 Integer
# 0 <= chosen_10426 <= 1 Integer
# 0 <= chosen_10427 <= 1 Integer
# 0 <= chosen_10428 <= 1 Integer
# 0 <= chosen_10429 <= 1 Integer
# 0 <= chosen_1043 <= 1 Integer
# 0 <= chosen_10430 <= 1 Integer
# 0 <= chosen_10431 <= 1 Integer
# 0 <= chosen_10432 <= 1 Integer
# 0 <= chosen_10433 <= 1 Integer
# 0 <= chosen_10434 <= 1 Integer
# 0 <= chosen_10435 <= 1 Integer
# 0 <= chosen_10436 <= 1 Integer
# 0 <= chosen_10437 <= 1 Integer
# 0 <= chosen_10438 <= 1 Integer
# 0 <= chosen_10439 <= 1 Integer
# 0 <= chosen_1044 <= 1 Integer
# 0 <= chosen_10440 <= 1 Integer
# 0 <= chosen_10441 <= 1 Integer
# 0 <= chosen_10442 <= 1 Integer
# 0 <= chosen_10443 <= 1 Integer
# 0 <= chosen_10444 <= 1 Integer
# 0 <= chosen_10445 <= 1 Integer
# 0 <= chosen_10446 <= 1 Integer
# 0 <= chosen_10447 <= 1 Integer
# 0 <= chosen_10448 <= 1 Integer
# 0 <= chosen_10449 <= 1 Integer
# 0 <= chosen_1045 <= 1 Integer
# 0 <= chosen_10450 <= 1 Integer
# 0 <= chosen_10451 <= 1 Integer
# 0 <= chosen_10452 <= 1 Integer
# 0 <= chosen_10453 <= 1 Integer
# 0 <= chosen_10454 <= 1 Integer
# 0 <= chosen_10455 <= 1 Integer
# 0 <= chosen_10456 <= 1 Integer
# 0 <= chosen_10457 <= 1 Integer
# 0 <= chosen_10458 <= 1 Integer
# 0 <= chosen_10459 <= 1 Integer
# 0 <= chosen_1046 <= 1 Integer
# 0 <= chosen_10460 <= 1 Integer
# 0 <= chosen_10461 <= 1 Integer
# 0 <= chosen_10462 <= 1 Integer
# 0 <= chosen_10463 <= 1 Integer
# 0 <= chosen_10464 <= 1 Integer
# 0 <= chosen_10465 <= 1 Integer
# 0 <= chosen_10466 <= 1 Integer
# 0 <= chosen_10467 <= 1 Integer
# 0 <= chosen_10468 <= 1 Integer
# 0 <= chosen_10469 <= 1 Integer
# 0 <= chosen_1047 <= 1 Integer
# 0 <= chosen_10470 <= 1 Integer
# 0 <= chosen_10471 <= 1 Integer
# 0 <= chosen_10472 <= 1 Integer
# 0 <= chosen_10473 <= 1 Integer
# 0 <= chosen_10474 <= 1 Integer
# 0 <= chosen_10475 <= 1 Integer
# 0 <= chosen_10476 <= 1 Integer
# 0 <= chosen_10477 <= 1 Integer
# 0 <= chosen_10478 <= 1 Integer
# 0 <= chosen_10479 <= 1 Integer
# 0 <= chosen_1048 <= 1 Integer
# 0 <= chosen_10480 <= 1 Integer
# 0 <= chosen_10481 <= 1 Integer
# 0 <= chosen_10482 <= 1 Integer
# 0 <= chosen_10483 <= 1 Integer
# 0 <= chosen_10484 <= 1 Integer
# 0 <= chosen_10485 <= 1 Integer
# 0 <= chosen_10486 <= 1 Integer
# 0 <= chosen_10487 <= 1 Integer
# 0 <= chosen_10488 <= 1 Integer
# 0 <= chosen_10489 <= 1 Integer
# 0 <= chosen_1049 <= 1 Integer
# 0 <= chosen_10490 <= 1 Integer
# 0 <= chosen_10491 <= 1 Integer
# 0 <= chosen_10492 <= 1 Integer
# 0 <= chosen_10493 <= 1 Integer
# 0 <= chosen_10494 <= 1 Integer
# 0 <= chosen_10495 <= 1 Integer
# 0 <= chosen_10496 <= 1 Integer
# 0 <= chosen_10497 <= 1 Integer
# 0 <= chosen_10498 <= 1 Integer
# 0 <= chosen_10499 <= 1 Integer
# 0 <= chosen_105 <= 1 Integer
# 0 <= chosen_1050 <= 1 Integer
# 0 <= chosen_10500 <= 1 Integer
# 0 <= chosen_10501 <= 1 Integer
# 0 <= chosen_10502 <= 1 Integer
# 0 <= chosen_10503 <= 1 Integer
# 0 <= chosen_10504 <= 1 Integer
# 0 <= chosen_10505 <= 1 Integer
# 0 <= chosen_10506 <= 1 Integer
# 0 <= chosen_10507 <= 1 Integer
# 0 <= chosen_10508 <= 1 Integer
# 0 <= chosen_10509 <= 1 Integer
# 0 <= chosen_1051 <= 1 Integer
# 0 <= chosen_10510 <= 1 Integer
# 0 <= chosen_10511 <= 1 Integer
# 0 <= chosen_10512 <= 1 Integer
# 0 <= chosen_10513 <= 1 Integer
# 0 <= chosen_10514 <= 1 Integer
# 0 <= chosen_10515 <= 1 Integer
# 0 <= chosen_10516 <= 1 Integer
# 0 <= chosen_10517 <= 1 Integer
# 0 <= chosen_10518 <= 1 Integer
# 0 <= chosen_10519 <= 1 Integer
# 0 <= chosen_1052 <= 1 Integer
# 0 <= chosen_10520 <= 1 Integer
# 0 <= chosen_10521 <= 1 Integer
# 0 <= chosen_10522 <= 1 Integer
# 0 <= chosen_10523 <= 1 Integer
# 0 <= chosen_10524 <= 1 Integer
# 0 <= chosen_10525 <= 1 Integer
# 0 <= chosen_10526 <= 1 Integer
# 0 <= chosen_10527 <= 1 Integer
# 0 <= chosen_10528 <= 1 Integer
# 0 <= chosen_10529 <= 1 Integer
# 0 <= chosen_1053 <= 1 Integer
# 0 <= chosen_10530 <= 1 Integer
# 0 <= chosen_10531 <= 1 Integer
# 0 <= chosen_10532 <= 1 Integer
# 0 <= chosen_10533 <= 1 Integer
# 0 <= chosen_10534 <= 1 Integer
# 0 <= chosen_10535 <= 1 Integer
# 0 <= chosen_10536 <= 1 Integer
# 0 <= chosen_10537 <= 1 Integer
# 0 <= chosen_10538 <= 1 Integer
# 0 <= chosen_10539 <= 1 Integer
# 0 <= chosen_1054 <= 1 Integer
# 0 <= chosen_10540 <= 1 Integer
# 0 <= chosen_10541 <= 1 Integer
# 0 <= chosen_10542 <= 1 Integer
# 0 <= chosen_10543 <= 1 Integer
# 0 <= chosen_10544 <= 1 Integer
# 0 <= chosen_10545 <= 1 Integer
# 0 <= chosen_10546 <= 1 Integer
# 0 <= chosen_10547 <= 1 Integer
# 0 <= chosen_10548 <= 1 Integer
# 0 <= chosen_10549 <= 1 Integer
# 0 <= chosen_1055 <= 1 Integer
# 0 <= chosen_10550 <= 1 Integer
# 0 <= chosen_10551 <= 1 Integer
# 0 <= chosen_10552 <= 1 Integer
# 0 <= chosen_10553 <= 1 Integer
# 0 <= chosen_10554 <= 1 Integer
# 0 <= chosen_10555 <= 1 Integer
# 0 <= chosen_10556 <= 1 Integer
# 0 <= chosen_10557 <= 1 Integer
# 0 <= chosen_10558 <= 1 Integer
# 0 <= chosen_10559 <= 1 Integer
# 0 <= chosen_1056 <= 1 Integer
# 0 <= chosen_10560 <= 1 Integer
# 0 <= chosen_10561 <= 1 Integer
# 0 <= chosen_10562 <= 1 Integer
# 0 <= chosen_10563 <= 1 Integer
# 0 <= chosen_10564 <= 1 Integer
# 0 <= chosen_10565 <= 1 Integer
# 0 <= chosen_10566 <= 1 Integer
# 0 <= chosen_10567 <= 1 Integer
# 0 <= chosen_10568 <= 1 Integer
# 0 <= chosen_10569 <= 1 Integer
# 0 <= chosen_1057 <= 1 Integer
# 0 <= chosen_10570 <= 1 Integer
# 0 <= chosen_10571 <= 1 Integer
# 0 <= chosen_10572 <= 1 Integer
# 0 <= chosen_10573 <= 1 Integer
# 0 <= chosen_10574 <= 1 Integer
# 0 <= chosen_10575 <= 1 Integer
# 0 <= chosen_10576 <= 1 Integer
# 0 <= chosen_10577 <= 1 Integer
# 0 <= chosen_10578 <= 1 Integer
# 0 <= chosen_10579 <= 1 Integer
# 0 <= chosen_1058 <= 1 Integer
# 0 <= chosen_10580 <= 1 Integer
# 0 <= chosen_10581 <= 1 Integer
# 0 <= chosen_10582 <= 1 Integer
# 0 <= chosen_10583 <= 1 Integer
# 0 <= chosen_10584 <= 1 Integer
# 0 <= chosen_10585 <= 1 Integer
# 0 <= chosen_10586 <= 1 Integer
# 0 <= chosen_10587 <= 1 Integer
# 0 <= chosen_10588 <= 1 Integer
# 0 <= chosen_10589 <= 1 Integer
# 0 <= chosen_1059 <= 1 Integer
# 0 <= chosen_10590 <= 1 Integer
# 0 <= chosen_10591 <= 1 Integer
# 0 <= chosen_10592 <= 1 Integer
# 0 <= chosen_10593 <= 1 Integer
# 0 <= chosen_10594 <= 1 Integer
# 0 <= chosen_10595 <= 1 Integer
# 0 <= chosen_10596 <= 1 Integer
# 0 <= chosen_10597 <= 1 Integer
# 0 <= chosen_10598 <= 1 Integer
# 0 <= chosen_10599 <= 1 Integer
# 0 <= chosen_106 <= 1 Integer
# 0 <= chosen_1060 <= 1 Integer
# 0 <= chosen_10600 <= 1 Integer
# 0 <= chosen_10601 <= 1 Integer
# 0 <= chosen_10602 <= 1 Integer
# 0 <= chosen_10603 <= 1 Integer
# 0 <= chosen_10604 <= 1 Integer
# 0 <= chosen_10605 <= 1 Integer
# 0 <= chosen_10606 <= 1 Integer
# 0 <= chosen_10607 <= 1 Integer
# 0 <= chosen_10608 <= 1 Integer
# 0 <= chosen_10609 <= 1 Integer
# 0 <= chosen_1061 <= 1 Integer
# 0 <= chosen_10610 <= 1 Integer
# 0 <= chosen_10611 <= 1 Integer
# 0 <= chosen_10612 <= 1 Integer
# 0 <= chosen_10613 <= 1 Integer
# 0 <= chosen_10614 <= 1 Integer
# 0 <= chosen_10615 <= 1 Integer
# 0 <= chosen_10616 <= 1 Integer
# 0 <= chosen_10617 <= 1 Integer
# 0 <= chosen_10618 <= 1 Integer
# 0 <= chosen_10619 <= 1 Integer
# 0 <= chosen_1062 <= 1 Integer
# 0 <= chosen_10620 <= 1 Integer
# 0 <= chosen_10621 <= 1 Integer
# 0 <= chosen_10622 <= 1 Integer
# 0 <= chosen_10623 <= 1 Integer
# 0 <= chosen_10624 <= 1 Integer
# 0 <= chosen_10625 <= 1 Integer
# 0 <= chosen_10626 <= 1 Integer
# 0 <= chosen_10627 <= 1 Integer
# 0 <= chosen_10628 <= 1 Integer
# 0 <= chosen_10629 <= 1 Integer
# 0 <= chosen_1063 <= 1 Integer
# 0 <= chosen_10630 <= 1 Integer
# 0 <= chosen_10631 <= 1 Integer
# 0 <= chosen_10632 <= 1 Integer
# 0 <= chosen_10633 <= 1 Integer
# 0 <= chosen_10634 <= 1 Integer
# 0 <= chosen_10635 <= 1 Integer
# 0 <= chosen_10636 <= 1 Integer
# 0 <= chosen_10637 <= 1 Integer
# 0 <= chosen_10638 <= 1 Integer
# 0 <= chosen_10639 <= 1 Integer
# 0 <= chosen_1064 <= 1 Integer
# 0 <= chosen_10640 <= 1 Integer
# 0 <= chosen_10641 <= 1 Integer
# 0 <= chosen_10642 <= 1 Integer
# 0 <= chosen_10643 <= 1 Integer
# 0 <= chosen_10644 <= 1 Integer
# 0 <= chosen_10645 <= 1 Integer
# 0 <= chosen_10646 <= 1 Integer
# 0 <= chosen_10647 <= 1 Integer
# 0 <= chosen_10648 <= 1 Integer
# 0 <= chosen_10649 <= 1 Integer
# 0 <= chosen_1065 <= 1 Integer
# 0 <= chosen_10650 <= 1 Integer
# 0 <= chosen_10651 <= 1 Integer
# 0 <= chosen_10652 <= 1 Integer
# 0 <= chosen_10653 <= 1 Integer
# 0 <= chosen_10654 <= 1 Integer
# 0 <= chosen_10655 <= 1 Integer
# 0 <= chosen_10656 <= 1 Integer
# 0 <= chosen_10657 <= 1 Integer
# 0 <= chosen_10658 <= 1 Integer
# 0 <= chosen_10659 <= 1 Integer
# 0 <= chosen_1066 <= 1 Integer
# 0 <= chosen_10660 <= 1 Integer
# 0 <= chosen_10661 <= 1 Integer
# 0 <= chosen_10662 <= 1 Integer
# 0 <= chosen_10663 <= 1 Integer
# 0 <= chosen_10664 <= 1 Integer
# 0 <= chosen_10665 <= 1 Integer
# 0 <= chosen_10666 <= 1 Integer
# 0 <= chosen_10667 <= 1 Integer
# 0 <= chosen_10668 <= 1 Integer
# 0 <= chosen_10669 <= 1 Integer
# 0 <= chosen_1067 <= 1 Integer
# 0 <= chosen_10670 <= 1 Integer
# 0 <= chosen_10671 <= 1 Integer
# 0 <= chosen_10672 <= 1 Integer
# 0 <= chosen_10673 <= 1 Integer
# 0 <= chosen_10674 <= 1 Integer
# 0 <= chosen_10675 <= 1 Integer
# 0 <= chosen_10676 <= 1 Integer
# 0 <= chosen_10677 <= 1 Integer
# 0 <= chosen_10678 <= 1 Integer
# 0 <= chosen_10679 <= 1 Integer
# 0 <= chosen_1068 <= 1 Integer
# 0 <= chosen_10680 <= 1 Integer
# 0 <= chosen_10681 <= 1 Integer
# 0 <= chosen_10682 <= 1 Integer
# 0 <= chosen_10683 <= 1 Integer
# 0 <= chosen_10684 <= 1 Integer
# 0 <= chosen_10685 <= 1 Integer
# 0 <= chosen_10686 <= 1 Integer
# 0 <= chosen_10687 <= 1 Integer
# 0 <= chosen_10688 <= 1 Integer
# 0 <= chosen_10689 <= 1 Integer
# 0 <= chosen_1069 <= 1 Integer
# 0 <= chosen_10690 <= 1 Integer
# 0 <= chosen_10691 <= 1 Integer
# 0 <= chosen_10692 <= 1 Integer
# 0 <= chosen_10693 <= 1 Integer
# 0 <= chosen_10694 <= 1 Integer
# 0 <= chosen_10695 <= 1 Integer
# 0 <= chosen_10696 <= 1 Integer
# 0 <= chosen_10697 <= 1 Integer
# 0 <= chosen_10698 <= 1 Integer
# 0 <= chosen_10699 <= 1 Integer
# 0 <= chosen_107 <= 1 Integer
# 0 <= chosen_1070 <= 1 Integer
# 0 <= chosen_10700 <= 1 Integer
# 0 <= chosen_10701 <= 1 Integer
# 0 <= chosen_10702 <= 1 Integer
# 0 <= chosen_10703 <= 1 Integer
# 0 <= chosen_10704 <= 1 Integer
# 0 <= chosen_10705 <= 1 Integer
# 0 <= chosen_10706 <= 1 Integer
# 0 <= chosen_10707 <= 1 Integer
# 0 <= chosen_10708 <= 1 Integer
# 0 <= chosen_10709 <= 1 Integer
# 0 <= chosen_1071 <= 1 Integer
# 0 <= chosen_10710 <= 1 Integer
# 0 <= chosen_10711 <= 1 Integer
# 0 <= chosen_10712 <= 1 Integer
# 0 <= chosen_10713 <= 1 Integer
# 0 <= chosen_10714 <= 1 Integer
# 0 <= chosen_10715 <= 1 Integer
# 0 <= chosen_10716 <= 1 Integer
# 0 <= chosen_10717 <= 1 Integer
# 0 <= chosen_10718 <= 1 Integer
# 0 <= chosen_10719 <= 1 Integer
# 0 <= chosen_1072 <= 1 Integer
# 0 <= chosen_10720 <= 1 Integer
# 0 <= chosen_10721 <= 1 Integer
# 0 <= chosen_10722 <= 1 Integer
# 0 <= chosen_10723 <= 1 Integer
# 0 <= chosen_10724 <= 1 Integer
# 0 <= chosen_10725 <= 1 Integer
# 0 <= chosen_10726 <= 1 Integer
# 0 <= chosen_10727 <= 1 Integer
# 0 <= chosen_10728 <= 1 Integer
# 0 <= chosen_10729 <= 1 Integer
# 0 <= chosen_1073 <= 1 Integer
# 0 <= chosen_10730 <= 1 Integer
# 0 <= chosen_10731 <= 1 Integer
# 0 <= chosen_10732 <= 1 Integer
# 0 <= chosen_10733 <= 1 Integer
# 0 <= chosen_10734 <= 1 Integer
# 0 <= chosen_10735 <= 1 Integer
# 0 <= chosen_10736 <= 1 Integer
# 0 <= chosen_10737 <= 1 Integer
# 0 <= chosen_10738 <= 1 Integer
# 0 <= chosen_10739 <= 1 Integer
# 0 <= chosen_1074 <= 1 Integer
# 0 <= chosen_10740 <= 1 Integer
# 0 <= chosen_10741 <= 1 Integer
# 0 <= chosen_10742 <= 1 Integer
# 0 <= chosen_10743 <= 1 Integer
# 0 <= chosen_10744 <= 1 Integer
# 0 <= chosen_10745 <= 1 Integer
# 0 <= chosen_10746 <= 1 Integer
# 0 <= chosen_10747 <= 1 Integer
# 0 <= chosen_10748 <= 1 Integer
# 0 <= chosen_10749 <= 1 Integer
# 0 <= chosen_1075 <= 1 Integer
# 0 <= chosen_10750 <= 1 Integer
# 0 <= chosen_10751 <= 1 Integer
# 0 <= chosen_10752 <= 1 Integer
# 0 <= chosen_10753 <= 1 Integer
# 0 <= chosen_10754 <= 1 Integer
# 0 <= chosen_10755 <= 1 Integer
# 0 <= chosen_10756 <= 1 Integer
# 0 <= chosen_10757 <= 1 Integer
# 0 <= chosen_10758 <= 1 Integer
# 0 <= chosen_10759 <= 1 Integer
# 0 <= chosen_1076 <= 1 Integer
# 0 <= chosen_10760 <= 1 Integer
# 0 <= chosen_10761 <= 1 Integer
# 0 <= chosen_10762 <= 1 Integer
# 0 <= chosen_10763 <= 1 Integer
# 0 <= chosen_10764 <= 1 Integer
# 0 <= chosen_10765 <= 1 Integer
# 0 <= chosen_10766 <= 1 Integer
# 0 <= chosen_10767 <= 1 Integer
# 0 <= chosen_10768 <= 1 Integer
# 0 <= chosen_10769 <= 1 Integer
# 0 <= chosen_1077 <= 1 Integer
# 0 <= chosen_10770 <= 1 Integer
# 0 <= chosen_10771 <= 1 Integer
# 0 <= chosen_10772 <= 1 Integer
# 0 <= chosen_10773 <= 1 Integer
# 0 <= chosen_10774 <= 1 Integer
# 0 <= chosen_10775 <= 1 Integer
# 0 <= chosen_10776 <= 1 Integer
# 0 <= chosen_10777 <= 1 Integer
# 0 <= chosen_10778 <= 1 Integer
# 0 <= chosen_10779 <= 1 Integer
# 0 <= chosen_1078 <= 1 Integer
# 0 <= chosen_10780 <= 1 Integer
# 0 <= chosen_10781 <= 1 Integer
# 0 <= chosen_10782 <= 1 Integer
# 0 <= chosen_10783 <= 1 Integer
# 0 <= chosen_10784 <= 1 Integer
# 0 <= chosen_10785 <= 1 Integer
# 0 <= chosen_10786 <= 1 Integer
# 0 <= chosen_10787 <= 1 Integer
# 0 <= chosen_10788 <= 1 Integer
# 0 <= chosen_10789 <= 1 Integer
# 0 <= chosen_1079 <= 1 Integer
# 0 <= chosen_10790 <= 1 Integer
# 0 <= chosen_10791 <= 1 Integer
# 0 <= chosen_10792 <= 1 Integer
# 0 <= chosen_10793 <= 1 Integer
# 0 <= chosen_10794 <= 1 Integer
# 0 <= chosen_10795 <= 1 Integer
# 0 <= chosen_10796 <= 1 Integer
# 0 <= chosen_10797 <= 1 Integer
# 0 <= chosen_10798 <= 1 Integer
# 0 <= chosen_10799 <= 1 Integer
# 0 <= chosen_108 <= 1 Integer
# 0 <= chosen_1080 <= 1 Integer
# 0 <= chosen_10800 <= 1 Integer
# 0 <= chosen_10801 <= 1 Integer
# 0 <= chosen_10802 <= 1 Integer
# 0 <= chosen_10803 <= 1 Integer
# 0 <= chosen_10804 <= 1 Integer
# 0 <= chosen_10805 <= 1 Integer
# 0 <= chosen_10806 <= 1 Integer
# 0 <= chosen_10807 <= 1 Integer
# 0 <= chosen_10808 <= 1 Integer
# 0 <= chosen_10809 <= 1 Integer
# 0 <= chosen_1081 <= 1 Integer
# 0 <= chosen_10810 <= 1 Integer
# 0 <= chosen_10811 <= 1 Integer
# 0 <= chosen_10812 <= 1 Integer
# 0 <= chosen_10813 <= 1 Integer
# 0 <= chosen_10814 <= 1 Integer
# 0 <= chosen_10815 <= 1 Integer
# 0 <= chosen_10816 <= 1 Integer
# 0 <= chosen_10817 <= 1 Integer
# 0 <= chosen_10818 <= 1 Integer
# 0 <= chosen_10819 <= 1 Integer
# 0 <= chosen_1082 <= 1 Integer
# 0 <= chosen_10820 <= 1 Integer
# 0 <= chosen_10821 <= 1 Integer
# 0 <= chosen_10822 <= 1 Integer
# 0 <= chosen_10823 <= 1 Integer
# 0 <= chosen_10824 <= 1 Integer
# 0 <= chosen_10825 <= 1 Integer
# 0 <= chosen_10826 <= 1 Integer
# 0 <= chosen_10827 <= 1 Integer
# 0 <= chosen_10828 <= 1 Integer
# 0 <= chosen_10829 <= 1 Integer
# 0 <= chosen_1083 <= 1 Integer
# 0 <= chosen_10830 <= 1 Integer
# 0 <= chosen_10831 <= 1 Integer
# 0 <= chosen_10832 <= 1 Integer
# 0 <= chosen_10833 <= 1 Integer
# 0 <= chosen_10834 <= 1 Integer
# 0 <= chosen_10835 <= 1 Integer
# 0 <= chosen_10836 <= 1 Integer
# 0 <= chosen_10837 <= 1 Integer
# 0 <= chosen_10838 <= 1 Integer
# 0 <= chosen_10839 <= 1 Integer
# 0 <= chosen_1084 <= 1 Integer
# 0 <= chosen_10840 <= 1 Integer
# 0 <= chosen_10841 <= 1 Integer
# 0 <= chosen_10842 <= 1 Integer
# 0 <= chosen_10843 <= 1 Integer
# 0 <= chosen_10844 <= 1 Integer
# 0 <= chosen_10845 <= 1 Integer
# 0 <= chosen_10846 <= 1 Integer
# 0 <= chosen_10847 <= 1 Integer
# 0 <= chosen_10848 <= 1 Integer
# 0 <= chosen_10849 <= 1 Integer
# 0 <= chosen_1085 <= 1 Integer
# 0 <= chosen_10850 <= 1 Integer
# 0 <= chosen_10851 <= 1 Integer
# 0 <= chosen_10852 <= 1 Integer
# 0 <= chosen_10853 <= 1 Integer
# 0 <= chosen_10854 <= 1 Integer
# 0 <= chosen_10855 <= 1 Integer
# 0 <= chosen_10856 <= 1 Integer
# 0 <= chosen_10857 <= 1 Integer
# 0 <= chosen_10858 <= 1 Integer
# 0 <= chosen_10859 <= 1 Integer
# 0 <= chosen_1086 <= 1 Integer
# 0 <= chosen_10860 <= 1 Integer
# 0 <= chosen_10861 <= 1 Integer
# 0 <= chosen_10862 <= 1 Integer
# 0 <= chosen_10863 <= 1 Integer
# 0 <= chosen_10864 <= 1 Integer
# 0 <= chosen_10865 <= 1 Integer
# 0 <= chosen_10866 <= 1 Integer
# 0 <= chosen_10867 <= 1 Integer
# 0 <= chosen_10868 <= 1 Integer
# 0 <= chosen_10869 <= 1 Integer
# 0 <= chosen_1087 <= 1 Integer
# 0 <= chosen_10870 <= 1 Integer
# 0 <= chosen_10871 <= 1 Integer
# 0 <= chosen_10872 <= 1 Integer
# 0 <= chosen_10873 <= 1 Integer
# 0 <= chosen_10874 <= 1 Integer
# 0 <= chosen_10875 <= 1 Integer
# 0 <= chosen_10876 <= 1 Integer
# 0 <= chosen_10877 <= 1 Integer
# 0 <= chosen_10878 <= 1 Integer
# 0 <= chosen_10879 <= 1 Integer
# 0 <= chosen_1088 <= 1 Integer
# 0 <= chosen_10880 <= 1 Integer
# 0 <= chosen_10881 <= 1 Integer
# 0 <= chosen_10882 <= 1 Integer
# 0 <= chosen_10883 <= 1 Integer
# 0 <= chosen_10884 <= 1 Integer
# 0 <= chosen_10885 <= 1 Integer
# 0 <= chosen_10886 <= 1 Integer
# 0 <= chosen_10887 <= 1 Integer
# 0 <= chosen_10888 <= 1 Integer
# 0 <= chosen_10889 <= 1 Integer
# 0 <= chosen_1089 <= 1 Integer
# 0 <= chosen_10890 <= 1 Integer
# 0 <= chosen_10891 <= 1 Integer
# 0 <= chosen_10892 <= 1 Integer
# 0 <= chosen_10893 <= 1 Integer
# 0 <= chosen_10894 <= 1 Integer
# 0 <= chosen_10895 <= 1 Integer
# 0 <= chosen_10896 <= 1 Integer
# 0 <= chosen_10897 <= 1 Integer
# 0 <= chosen_10898 <= 1 Integer
# 0 <= chosen_10899 <= 1 Integer
# 0 <= chosen_109 <= 1 Integer
# 0 <= chosen_1090 <= 1 Integer
# 0 <= chosen_10900 <= 1 Integer
# 0 <= chosen_10901 <= 1 Integer
# 0 <= chosen_10902 <= 1 Integer
# 0 <= chosen_10903 <= 1 Integer
# 0 <= chosen_10904 <= 1 Integer
# 0 <= chosen_10905 <= 1 Integer
# 0 <= chosen_10906 <= 1 Integer
# 0 <= chosen_10907 <= 1 Integer
# 0 <= chosen_10908 <= 1 Integer
# 0 <= chosen_10909 <= 1 Integer
# 0 <= chosen_1091 <= 1 Integer
# 0 <= chosen_10910 <= 1 Integer
# 0 <= chosen_10911 <= 1 Integer
# 0 <= chosen_10912 <= 1 Integer
# 0 <= chosen_10913 <= 1 Integer
# 0 <= chosen_10914 <= 1 Integer
# 0 <= chosen_10915 <= 1 Integer
# 0 <= chosen_10916 <= 1 Integer
# 0 <= chosen_10917 <= 1 Integer
# 0 <= chosen_10918 <= 1 Integer
# 0 <= chosen_10919 <= 1 Integer
# 0 <= chosen_1092 <= 1 Integer
# 0 <= chosen_10920 <= 1 Integer
# 0 <= chosen_10921 <= 1 Integer
# 0 <= chosen_10922 <= 1 Integer
# 0 <= chosen_10923 <= 1 Integer
# 0 <= chosen_10924 <= 1 Integer
# 0 <= chosen_10925 <= 1 Integer
# 0 <= chosen_10926 <= 1 Integer
# 0 <= chosen_10927 <= 1 Integer
# 0 <= chosen_10928 <= 1 Integer
# 0 <= chosen_10929 <= 1 Integer
# 0 <= chosen_1093 <= 1 Integer
# 0 <= chosen_10930 <= 1 Integer
# 0 <= chosen_10931 <= 1 Integer
# 0 <= chosen_10932 <= 1 Integer
# 0 <= chosen_10933 <= 1 Integer
# 0 <= chosen_10934 <= 1 Integer
# 0 <= chosen_10935 <= 1 Integer
# 0 <= chosen_10936 <= 1 Integer
# 0 <= chosen_10937 <= 1 Integer
# 0 <= chosen_10938 <= 1 Integer
# 0 <= chosen_10939 <= 1 Integer
# 0 <= chosen_1094 <= 1 Integer
# 0 <= chosen_10940 <= 1 Integer
# 0 <= chosen_10941 <= 1 Integer
# 0 <= chosen_10942 <= 1 Integer
# 0 <= chosen_10943 <= 1 Integer
# 0 <= chosen_10944 <= 1 Integer
# 0 <= chosen_10945 <= 1 Integer
# 0 <= chosen_10946 <= 1 Integer
# 0 <= chosen_10947 <= 1 Integer
# 0 <= chosen_10948 <= 1 Integer
# 0 <= chosen_10949 <= 1 Integer
# 0 <= chosen_1095 <= 1 Integer
# 0 <= chosen_10950 <= 1 Integer
# 0 <= chosen_10951 <= 1 Integer
# 0 <= chosen_10952 <= 1 Integer
# 0 <= chosen_10953 <= 1 Integer
# 0 <= chosen_10954 <= 1 Integer
# 0 <= chosen_10955 <= 1 Integer
# 0 <= chosen_10956 <= 1 Integer
# 0 <= chosen_10957 <= 1 Integer
# 0 <= chosen_10958 <= 1 Integer
# 0 <= chosen_10959 <= 1 Integer
# 0 <= chosen_1096 <= 1 Integer
# 0 <= chosen_10960 <= 1 Integer
# 0 <= chosen_10961 <= 1 Integer
# 0 <= chosen_10962 <= 1 Integer
# 0 <= chosen_10963 <= 1 Integer
# 0 <= chosen_10964 <= 1 Integer
# 0 <= chosen_10965 <= 1 Integer
# 0 <= chosen_10966 <= 1 Integer
# 0 <= chosen_10967 <= 1 Integer
# 0 <= chosen_10968 <= 1 Integer
# 0 <= chosen_10969 <= 1 Integer
# 0 <= chosen_1097 <= 1 Integer
# 0 <= chosen_10970 <= 1 Integer
# 0 <= chosen_10971 <= 1 Integer
# 0 <= chosen_10972 <= 1 Integer
# 0 <= chosen_10973 <= 1 Integer
# 0 <= chosen_10974 <= 1 Integer
# 0 <= chosen_10975 <= 1 Integer
# 0 <= chosen_10976 <= 1 Integer
# 0 <= chosen_10977 <= 1 Integer
# 0 <= chosen_10978 <= 1 Integer
# 0 <= chosen_10979 <= 1 Integer
# 0 <= chosen_1098 <= 1 Integer
# 0 <= chosen_10980 <= 1 Integer
# 0 <= chosen_10981 <= 1 Integer
# 0 <= chosen_10982 <= 1 Integer
# 0 <= chosen_10983 <= 1 Integer
# 0 <= chosen_10984 <= 1 Integer
# 0 <= chosen_10985 <= 1 Integer
# 0 <= chosen_10986 <= 1 Integer
# 0 <= chosen_10987 <= 1 Integer
# 0 <= chosen_10988 <= 1 Integer
# 0 <= chosen_10989 <= 1 Integer
# 0 <= chosen_1099 <= 1 Integer
# 0 <= chosen_10990 <= 1 Integer
# 0 <= chosen_10991 <= 1 Integer
# 0 <= chosen_10992 <= 1 Integer
# 0 <= chosen_10993 <= 1 Integer
# 0 <= chosen_10994 <= 1 Integer
# 0 <= chosen_10995 <= 1 Integer
# 0 <= chosen_10996 <= 1 Integer
# 0 <= chosen_10997 <= 1 Integer
# 0 <= chosen_10998 <= 1 Integer
# 0 <= chosen_10999 <= 1 Integer
# 0 <= chosen_11 <= 1 Integer
# 0 <= chosen_110 <= 1 Integer
# 0 <= chosen_1100 <= 1 Integer
# 0 <= chosen_11000 <= 1 Integer
# 0 <= chosen_11001 <= 1 Integer
# 0 <= chosen_11002 <= 1 Integer
# 0 <= chosen_11003 <= 1 Integer
# 0 <= chosen_11004 <= 1 Integer
# 0 <= chosen_11005 <= 1 Integer
# 0 <= chosen_11006 <= 1 Integer
# 0 <= chosen_11007 <= 1 Integer
# 0 <= chosen_11008 <= 1 Integer
# 0 <= chosen_11009 <= 1 Integer
# 0 <= chosen_1101 <= 1 Integer
# 0 <= chosen_11010 <= 1 Integer
# 0 <= chosen_11011 <= 1 Integer
# 0 <= chosen_11012 <= 1 Integer
# 0 <= chosen_11013 <= 1 Integer
# 0 <= chosen_11014 <= 1 Integer
# 0 <= chosen_11015 <= 1 Integer
# 0 <= chosen_11016 <= 1 Integer
# 0 <= chosen_11017 <= 1 Integer
# 0 <= chosen_11018 <= 1 Integer
# 0 <= chosen_11019 <= 1 Integer
# 0 <= chosen_1102 <= 1 Integer
# 0 <= chosen_11020 <= 1 Integer
# 0 <= chosen_11021 <= 1 Integer
# 0 <= chosen_11022 <= 1 Integer
# 0 <= chosen_11023 <= 1 Integer
# 0 <= chosen_11024 <= 1 Integer
# 0 <= chosen_11025 <= 1 Integer
# 0 <= chosen_11026 <= 1 Integer
# 0 <= chosen_11027 <= 1 Integer
# 0 <= chosen_11028 <= 1 Integer
# 0 <= chosen_11029 <= 1 Integer
# 0 <= chosen_1103 <= 1 Integer
# 0 <= chosen_11030 <= 1 Integer
# 0 <= chosen_11031 <= 1 Integer
# 0 <= chosen_11032 <= 1 Integer
# 0 <= chosen_11033 <= 1 Integer
# 0 <= chosen_11034 <= 1 Integer
# 0 <= chosen_11035 <= 1 Integer
# 0 <= chosen_11036 <= 1 Integer
# 0 <= chosen_11037 <= 1 Integer
# 0 <= chosen_11038 <= 1 Integer
# 0 <= chosen_11039 <= 1 Integer
# 0 <= chosen_1104 <= 1 Integer
# 0 <= chosen_11040 <= 1 Integer
# 0 <= chosen_11041 <= 1 Integer
# 0 <= chosen_11042 <= 1 Integer
# 0 <= chosen_11043 <= 1 Integer
# 0 <= chosen_11044 <= 1 Integer
# 0 <= chosen_11045 <= 1 Integer
# 0 <= chosen_11046 <= 1 Integer
# 0 <= chosen_11047 <= 1 Integer
# 0 <= chosen_11048 <= 1 Integer
# 0 <= chosen_11049 <= 1 Integer
# 0 <= chosen_1105 <= 1 Integer
# 0 <= chosen_11050 <= 1 Integer
# 0 <= chosen_11051 <= 1 Integer
# 0 <= chosen_11052 <= 1 Integer
# 0 <= chosen_11053 <= 1 Integer
# 0 <= chosen_11054 <= 1 Integer
# 0 <= chosen_11055 <= 1 Integer
# 0 <= chosen_11056 <= 1 Integer
# 0 <= chosen_11057 <= 1 Integer
# 0 <= chosen_11058 <= 1 Integer
# 0 <= chosen_11059 <= 1 Integer
# 0 <= chosen_1106 <= 1 Integer
# 0 <= chosen_11060 <= 1 Integer
# 0 <= chosen_11061 <= 1 Integer
# 0 <= chosen_11062 <= 1 Integer
# 0 <= chosen_11063 <= 1 Integer
# 0 <= chosen_11064 <= 1 Integer
# 0 <= chosen_11065 <= 1 Integer
# 0 <= chosen_11066 <= 1 Integer
# 0 <= chosen_11067 <= 1 Integer
# 0 <= chosen_11068 <= 1 Integer
# 0 <= chosen_11069 <= 1 Integer
# 0 <= chosen_1107 <= 1 Integer
# 0 <= chosen_11070 <= 1 Integer
# 0 <= chosen_11071 <= 1 Integer
# 0 <= chosen_11072 <= 1 Integer
# 0 <= chosen_11073 <= 1 Integer
# 0 <= chosen_11074 <= 1 Integer
# 0 <= chosen_11075 <= 1 Integer
# 0 <= chosen_11076 <= 1 Integer
# 0 <= chosen_11077 <= 1 Integer
# 0 <= chosen_11078 <= 1 Integer
# 0 <= chosen_11079 <= 1 Integer
# 0 <= chosen_1108 <= 1 Integer
# 0 <= chosen_11080 <= 1 Integer
# 0 <= chosen_11081 <= 1 Integer
# 0 <= chosen_11082 <= 1 Integer
# 0 <= chosen_11083 <= 1 Integer
# 0 <= chosen_11084 <= 1 Integer
# 0 <= chosen_11085 <= 1 Integer
# 0 <= chosen_11086 <= 1 Integer
# 0 <= chosen_11087 <= 1 Integer
# 0 <= chosen_11088 <= 1 Integer
# 0 <= chosen_11089 <= 1 Integer
# 0 <= chosen_1109 <= 1 Integer
# 0 <= chosen_11090 <= 1 Integer
# 0 <= chosen_11091 <= 1 Integer
# 0 <= chosen_11092 <= 1 Integer
# 0 <= chosen_11093 <= 1 Integer
# 0 <= chosen_11094 <= 1 Integer
# 0 <= chosen_11095 <= 1 Integer
# 0 <= chosen_11096 <= 1 Integer
# 0 <= chosen_11097 <= 1 Integer
# 0 <= chosen_11098 <= 1 Integer
# 0 <= chosen_11099 <= 1 Integer
# 0 <= chosen_111 <= 1 Integer
# 0 <= chosen_1110 <= 1 Integer
# 0 <= chosen_11100 <= 1 Integer
# 0 <= chosen_11101 <= 1 Integer
# 0 <= chosen_11102 <= 1 Integer
# 0 <= chosen_11103 <= 1 Integer
# 0 <= chosen_11104 <= 1 Integer
# 0 <= chosen_11105 <= 1 Integer
# 0 <= chosen_11106 <= 1 Integer
# 0 <= chosen_11107 <= 1 Integer
# 0 <= chosen_11108 <= 1 Integer
# 0 <= chosen_11109 <= 1 Integer
# 0 <= chosen_1111 <= 1 Integer
# 0 <= chosen_11110 <= 1 Integer
# 0 <= chosen_11111 <= 1 Integer
# 0 <= chosen_11112 <= 1 Integer
# 0 <= chosen_11113 <= 1 Integer
# 0 <= chosen_11114 <= 1 Integer
# 0 <= chosen_11115 <= 1 Integer
# 0 <= chosen_11116 <= 1 Integer
# 0 <= chosen_11117 <= 1 Integer
# 0 <= chosen_11118 <= 1 Integer
# 0 <= chosen_11119 <= 1 Integer
# 0 <= chosen_1112 <= 1 Integer
# 0 <= chosen_11120 <= 1 Integer
# 0 <= chosen_11121 <= 1 Integer
# 0 <= chosen_11122 <= 1 Integer
# 0 <= chosen_11123 <= 1 Integer
# 0 <= chosen_11124 <= 1 Integer
# 0 <= chosen_11125 <= 1 Integer
# 0 <= chosen_11126 <= 1 Integer
# 0 <= chosen_11127 <= 1 Integer
# 0 <= chosen_11128 <= 1 Integer
# 0 <= chosen_11129 <= 1 Integer
# 0 <= chosen_1113 <= 1 Integer
# 0 <= chosen_11130 <= 1 Integer
# 0 <= chosen_11131 <= 1 Integer
# 0 <= chosen_11132 <= 1 Integer
# 0 <= chosen_11133 <= 1 Integer
# 0 <= chosen_11134 <= 1 Integer
# 0 <= chosen_11135 <= 1 Integer
# 0 <= chosen_11136 <= 1 Integer
# 0 <= chosen_11137 <= 1 Integer
# 0 <= chosen_11138 <= 1 Integer
# 0 <= chosen_11139 <= 1 Integer
# 0 <= chosen_1114 <= 1 Integer
# 0 <= chosen_11140 <= 1 Integer
# 0 <= chosen_11141 <= 1 Integer
# 0 <= chosen_11142 <= 1 Integer
# 0 <= chosen_11143 <= 1 Integer
# 0 <= chosen_11144 <= 1 Integer
# 0 <= chosen_11145 <= 1 Integer
# 0 <= chosen_11146 <= 1 Integer
# 0 <= chosen_11147 <= 1 Integer
# 0 <= chosen_11148 <= 1 Integer
# 0 <= chosen_11149 <= 1 Integer
# 0 <= chosen_1115 <= 1 Integer
# 0 <= chosen_11150 <= 1 Integer
# 0 <= chosen_11151 <= 1 Integer
# 0 <= chosen_11152 <= 1 Integer
# 0 <= chosen_11153 <= 1 Integer
# 0 <= chosen_11154 <= 1 Integer
# 0 <= chosen_11155 <= 1 Integer
# 0 <= chosen_11156 <= 1 Integer
# 0 <= chosen_11157 <= 1 Integer
# 0 <= chosen_11158 <= 1 Integer
# 0 <= chosen_11159 <= 1 Integer
# 0 <= chosen_1116 <= 1 Integer
# 0 <= chosen_11160 <= 1 Integer
# 0 <= chosen_11161 <= 1 Integer
# 0 <= chosen_11162 <= 1 Integer
# 0 <= chosen_11163 <= 1 Integer
# 0 <= chosen_11164 <= 1 Integer
# 0 <= chosen_11165 <= 1 Integer
# 0 <= chosen_11166 <= 1 Integer
# 0 <= chosen_11167 <= 1 Integer
# 0 <= chosen_11168 <= 1 Integer
# 0 <= chosen_11169 <= 1 Integer
# 0 <= chosen_1117 <= 1 Integer
# 0 <= chosen_11170 <= 1 Integer
# 0 <= chosen_11171 <= 1 Integer
# 0 <= chosen_11172 <= 1 Integer
# 0 <= chosen_11173 <= 1 Integer
# 0 <= chosen_11174 <= 1 Integer
# 0 <= chosen_11175 <= 1 Integer
# 0 <= chosen_11176 <= 1 Integer
# 0 <= chosen_11177 <= 1 Integer
# 0 <= chosen_11178 <= 1 Integer
# 0 <= chosen_11179 <= 1 Integer
# 0 <= chosen_1118 <= 1 Integer
# 0 <= chosen_11180 <= 1 Integer
# 0 <= chosen_11181 <= 1 Integer
# 0 <= chosen_11182 <= 1 Integer
# 0 <= chosen_11183 <= 1 Integer
# 0 <= chosen_11184 <= 1 Integer
# 0 <= chosen_11185 <= 1 Integer
# 0 <= chosen_11186 <= 1 Integer
# 0 <= chosen_11187 <= 1 Integer
# 0 <= chosen_11188 <= 1 Integer
# 0 <= chosen_11189 <= 1 Integer
# 0 <= chosen_1119 <= 1 Integer
# 0 <= chosen_11190 <= 1 Integer
# 0 <= chosen_11191 <= 1 Integer
# 0 <= chosen_11192 <= 1 Integer
# 0 <= chosen_11193 <= 1 Integer
# 0 <= chosen_11194 <= 1 Integer
# 0 <= chosen_11195 <= 1 Integer
# 0 <= chosen_11196 <= 1 Integer
# 0 <= chosen_11197 <= 1 Integer
# 0 <= chosen_11198 <= 1 Integer
# 0 <= chosen_11199 <= 1 Integer
# 0 <= chosen_112 <= 1 Integer
# 0 <= chosen_1120 <= 1 Integer
# 0 <= chosen_11200 <= 1 Integer
# 0 <= chosen_11201 <= 1 Integer
# 0 <= chosen_11202 <= 1 Integer
# 0 <= chosen_11203 <= 1 Integer
# 0 <= chosen_11204 <= 1 Integer
# 0 <= chosen_11205 <= 1 Integer
# 0 <= chosen_11206 <= 1 Integer
# 0 <= chosen_11207 <= 1 Integer
# 0 <= chosen_11208 <= 1 Integer
# 0 <= chosen_11209 <= 1 Integer
# 0 <= chosen_1121 <= 1 Integer
# 0 <= chosen_11210 <= 1 Integer
# 0 <= chosen_11211 <= 1 Integer
# 0 <= chosen_11212 <= 1 Integer
# 0 <= chosen_11213 <= 1 Integer
# 0 <= chosen_11214 <= 1 Integer
# 0 <= chosen_11215 <= 1 Integer
# 0 <= chosen_11216 <= 1 Integer
# 0 <= chosen_11217 <= 1 Integer
# 0 <= chosen_11218 <= 1 Integer
# 0 <= chosen_11219 <= 1 Integer
# 0 <= chosen_1122 <= 1 Integer
# 0 <= chosen_11220 <= 1 Integer
# 0 <= chosen_11221 <= 1 Integer
# 0 <= chosen_11222 <= 1 Integer
# 0 <= chosen_11223 <= 1 Integer
# 0 <= chosen_11224 <= 1 Integer
# 0 <= chosen_11225 <= 1 Integer
# 0 <= chosen_11226 <= 1 Integer
# 0 <= chosen_11227 <= 1 Integer
# 0 <= chosen_11228 <= 1 Integer
# 0 <= chosen_11229 <= 1 Integer
# 0 <= chosen_1123 <= 1 Integer
# 0 <= chosen_11230 <= 1 Integer
# 0 <= chosen_11231 <= 1 Integer
# 0 <= chosen_11232 <= 1 Integer
# 0 <= chosen_11233 <= 1 Integer
# 0 <= chosen_11234 <= 1 Integer
# 0 <= chosen_11235 <= 1 Integer
# 0 <= chosen_11236 <= 1 Integer
# 0 <= chosen_11237 <= 1 Integer
# 0 <= chosen_11238 <= 1 Integer
# 0 <= chosen_11239 <= 1 Integer
# 0 <= chosen_1124 <= 1 Integer
# 0 <= chosen_11240 <= 1 Integer
# 0 <= chosen_11241 <= 1 Integer
# 0 <= chosen_11242 <= 1 Integer
# 0 <= chosen_11243 <= 1 Integer
# 0 <= chosen_11244 <= 1 Integer
# 0 <= chosen_11245 <= 1 Integer
# 0 <= chosen_11246 <= 1 Integer
# 0 <= chosen_11247 <= 1 Integer
# 0 <= chosen_11248 <= 1 Integer
# 0 <= chosen_11249 <= 1 Integer
# 0 <= chosen_1125 <= 1 Integer
# 0 <= chosen_11250 <= 1 Integer
# 0 <= chosen_11251 <= 1 Integer
# 0 <= chosen_11252 <= 1 Integer
# 0 <= chosen_11253 <= 1 Integer
# 0 <= chosen_11254 <= 1 Integer
# 0 <= chosen_11255 <= 1 Integer
# 0 <= chosen_11256 <= 1 Integer
# 0 <= chosen_11257 <= 1 Integer
# 0 <= chosen_11258 <= 1 Integer
# 0 <= chosen_11259 <= 1 Integer
# 0 <= chosen_1126 <= 1 Integer
# 0 <= chosen_11260 <= 1 Integer
# 0 <= chosen_11261 <= 1 Integer
# 0 <= chosen_11262 <= 1 Integer
# 0 <= chosen_11263 <= 1 Integer
# 0 <= chosen_11264 <= 1 Integer
# 0 <= chosen_11265 <= 1 Integer
# 0 <= chosen_11266 <= 1 Integer
# 0 <= chosen_11267 <= 1 Integer
# 0 <= chosen_11268 <= 1 Integer
# 0 <= chosen_11269 <= 1 Integer
# 0 <= chosen_1127 <= 1 Integer
# 0 <= chosen_11270 <= 1 Integer
# 0 <= chosen_11271 <= 1 Integer
# 0 <= chosen_11272 <= 1 Integer
# 0 <= chosen_11273 <= 1 Integer
# 0 <= chosen_11274 <= 1 Integer
# 0 <= chosen_11275 <= 1 Integer
# 0 <= chosen_11276 <= 1 Integer
# 0 <= chosen_11277 <= 1 Integer
# 0 <= chosen_11278 <= 1 Integer
# ...
# 0 <= chosen_9517 <= 1 Integer
# 0 <= chosen_9518 <= 1 Integer
# 0 <= chosen_9519 <= 1 Integer
# 0 <= chosen_952 <= 1 Integer
# 0 <= chosen_9520 <= 1 Integer
# 0 <= chosen_9521 <= 1 Integer
# 0 <= chosen_9522 <= 1 Integer
# 0 <= chosen_9523 <= 1 Integer
# 0 <= chosen_9524 <= 1 Integer
# 0 <= chosen_9525 <= 1 Integer
# 0 <= chosen_9526 <= 1 Integer
# 0 <= chosen_9527 <= 1 Integer
# 0 <= chosen_9528 <= 1 Integer
# 0 <= chosen_9529 <= 1 Integer
# 0 <= chosen_953 <= 1 Integer
# 0 <= chosen_9530 <= 1 Integer
# 0 <= chosen_9531 <= 1 Integer
# 0 <= chosen_9532 <= 1 Integer
# 0 <= chosen_9533 <= 1 Integer
# 0 <= chosen_9534 <= 1 Integer
# 0 <= chosen_9535 <= 1 Integer
# 0 <= chosen_9536 <= 1 Integer
# 0 <= chosen_9537 <= 1 Integer
# 0 <= chosen_9538 <= 1 Integer
# 0 <= chosen_9539 <= 1 Integer
# 0 <= chosen_954 <= 1 Integer
# 0 <= chosen_9540 <= 1 Integer
# 0 <= chosen_9541 <= 1 Integer
# 0 <= chosen_9542 <= 1 Integer
# 0 <= chosen_9543 <= 1 Integer
# 0 <= chosen_9544 <= 1 Integer
# 0 <= chosen_9545 <= 1 Integer
# 0 <= chosen_9546 <= 1 Integer
# 0 <= chosen_9547 <= 1 Integer
# 0 <= chosen_9548 <= 1 Integer
# 0 <= chosen_9549 <= 1 Integer
# 0 <= chosen_955 <= 1 Integer
# 0 <= chosen_9550 <= 1 Integer
# 0 <= chosen_9551 <= 1 Integer
# 0 <= chosen_9552 <= 1 Integer
# 0 <= chosen_9553 <= 1 Integer
# 0 <= chosen_9554 <= 1 Integer
# 0 <= chosen_9555 <= 1 Integer
# 0 <= chosen_9556 <= 1 Integer
# 0 <= chosen_9557 <= 1 Integer
# 0 <= chosen_9558 <= 1 Integer
# 0 <= chosen_9559 <= 1 Integer
# 0 <= chosen_956 <= 1 Integer
# 0 <= chosen_9560 <= 1 Integer
# 0 <= chosen_9561 <= 1 Integer
# 0 <= chosen_9562 <= 1 Integer
# 0 <= chosen_9563 <= 1 Integer
# 0 <= chosen_9564 <= 1 Integer
# 0 <= chosen_9565 <= 1 Integer
# 0 <= chosen_9566 <= 1 Integer
# 0 <= chosen_9567 <= 1 Integer
# 0 <= chosen_9568 <= 1 Integer
# 0 <= chosen_9569 <= 1 Integer
# 0 <= chosen_957 <= 1 Integer
# 0 <= chosen_9570 <= 1 Integer
# 0 <= chosen_9571 <= 1 Integer
# 0 <= chosen_9572 <= 1 Integer
# 0 <= chosen_9573 <= 1 Integer
# 0 <= chosen_9574 <= 1 Integer
# 0 <= chosen_9575 <= 1 Integer
# 0 <= chosen_9576 <= 1 Integer
# 0 <= chosen_9577 <= 1 Integer
# 0 <= chosen_9578 <= 1 Integer
# 0 <= chosen_9579 <= 1 Integer
# 0 <= chosen_958 <= 1 Integer
# 0 <= chosen_9580 <= 1 Integer
# 0 <= chosen_9581 <= 1 Integer
# 0 <= chosen_9582 <= 1 Integer
# 0 <= chosen_9583 <= 1 Integer
# 0 <= chosen_9584 <= 1 Integer
# 0 <= chosen_9585 <= 1 Integer
# 0 <= chosen_9586 <= 1 Integer
# 0 <= chosen_9587 <= 1 Integer
# 0 <= chosen_9588 <= 1 Integer
# 0 <= chosen_9589 <= 1 Integer
# 0 <= chosen_959 <= 1 Integer
# 0 <= chosen_9590 <= 1 Integer
# 0 <= chosen_9591 <= 1 Integer
# 0 <= chosen_9592 <= 1 Integer
# 0 <= chosen_9593 <= 1 Integer
# 0 <= chosen_9594 <= 1 Integer
# 0 <= chosen_9595 <= 1 Integer
# 0 <= chosen_9596 <= 1 Integer
# 0 <= chosen_9597 <= 1 Integer
# 0 <= chosen_9598 <= 1 Integer
# 0 <= chosen_9599 <= 1 Integer
# 0 <= chosen_96 <= 1 Integer
# 0 <= chosen_960 <= 1 Integer
# 0 <= chosen_9600 <= 1 Integer
# 0 <= chosen_9601 <= 1 Integer
# 0 <= chosen_9602 <= 1 Integer
# 0 <= chosen_9603 <= 1 Integer
# 0 <= chosen_9604 <= 1 Integer
# 0 <= chosen_9605 <= 1 Integer
# 0 <= chosen_9606 <= 1 Integer
# 0 <= chosen_9607 <= 1 Integer
# 0 <= chosen_9608 <= 1 Integer
# 0 <= chosen_9609 <= 1 Integer
# 0 <= chosen_961 <= 1 Integer
# 0 <= chosen_9610 <= 1 Integer
# 0 <= chosen_9611 <= 1 Integer
# 0 <= chosen_9612 <= 1 Integer
# 0 <= chosen_9613 <= 1 Integer
# 0 <= chosen_9614 <= 1 Integer
# 0 <= chosen_9615 <= 1 Integer
# 0 <= chosen_9616 <= 1 Integer
# 0 <= chosen_9617 <= 1 Integer
# 0 <= chosen_9618 <= 1 Integer
# 0 <= chosen_9619 <= 1 Integer
# 0 <= chosen_962 <= 1 Integer
# 0 <= chosen_9620 <= 1 Integer
# 0 <= chosen_9621 <= 1 Integer
# 0 <= chosen_9622 <= 1 Integer
# 0 <= chosen_9623 <= 1 Integer
# 0 <= chosen_9624 <= 1 Integer
# 0 <= chosen_9625 <= 1 Integer
# 0 <= chosen_9626 <= 1 Integer
# 0 <= chosen_9627 <= 1 Integer
# 0 <= chosen_9628 <= 1 Integer
# 0 <= chosen_9629 <= 1 Integer
# 0 <= chosen_963 <= 1 Integer
# 0 <= chosen_9630 <= 1 Integer
# 0 <= chosen_9631 <= 1 Integer
# 0 <= chosen_9632 <= 1 Integer
# 0 <= chosen_9633 <= 1 Integer
# 0 <= chosen_9634 <= 1 Integer
# 0 <= chosen_9635 <= 1 Integer
# 0 <= chosen_9636 <= 1 Integer
# 0 <= chosen_9637 <= 1 Integer
# 0 <= chosen_9638 <= 1 Integer
# 0 <= chosen_9639 <= 1 Integer
# 0 <= chosen_964 <= 1 Integer
# 0 <= chosen_9640 <= 1 Integer
# 0 <= chosen_9641 <= 1 Integer
# 0 <= chosen_9642 <= 1 Integer
# 0 <= chosen_9643 <= 1 Integer
# 0 <= chosen_9644 <= 1 Integer
# 0 <= chosen_9645 <= 1 Integer
# 0 <= chosen_9646 <= 1 Integer
# 0 <= chosen_9647 <= 1 Integer
# 0 <= chosen_9648 <= 1 Integer
# 0 <= chosen_9649 <= 1 Integer
# 0 <= chosen_965 <= 1 Integer
# 0 <= chosen_9650 <= 1 Integer
# 0 <= chosen_9651 <= 1 Integer
# 0 <= chosen_9652 <= 1 Integer
# 0 <= chosen_9653 <= 1 Integer
# 0 <= chosen_9654 <= 1 Integer
# 0 <= chosen_9655 <= 1 Integer
# 0 <= chosen_9656 <= 1 Integer
# 0 <= chosen_9657 <= 1 Integer
# 0 <= chosen_9658 <= 1 Integer
# 0 <= chosen_9659 <= 1 Integer
# 0 <= chosen_966 <= 1 Integer
# 0 <= chosen_9660 <= 1 Integer
# 0 <= chosen_9661 <= 1 Integer
# 0 <= chosen_9662 <= 1 Integer
# 0 <= chosen_9663 <= 1 Integer
# 0 <= chosen_9664 <= 1 Integer
# 0 <= chosen_9665 <= 1 Integer
# 0 <= chosen_9666 <= 1 Integer
# 0 <= chosen_9667 <= 1 Integer
# 0 <= chosen_9668 <= 1 Integer
# 0 <= chosen_9669 <= 1 Integer
# 0 <= chosen_967 <= 1 Integer
# 0 <= chosen_9670 <= 1 Integer
# 0 <= chosen_9671 <= 1 Integer
# 0 <= chosen_9672 <= 1 Integer
# 0 <= chosen_9673 <= 1 Integer
# 0 <= chosen_9674 <= 1 Integer
# 0 <= chosen_9675 <= 1 Integer
# 0 <= chosen_9676 <= 1 Integer
# 0 <= chosen_9677 <= 1 Integer
# 0 <= chosen_9678 <= 1 Integer
# 0 <= chosen_9679 <= 1 Integer
# 0 <= chosen_968 <= 1 Integer
# 0 <= chosen_9680 <= 1 Integer
# 0 <= chosen_9681 <= 1 Integer
# 0 <= chosen_9682 <= 1 Integer
# 0 <= chosen_9683 <= 1 Integer
# 0 <= chosen_9684 <= 1 Integer
# 0 <= chosen_9685 <= 1 Integer
# 0 <= chosen_9686 <= 1 Integer
# 0 <= chosen_9687 <= 1 Integer
# 0 <= chosen_9688 <= 1 Integer
# 0 <= chosen_9689 <= 1 Integer
# 0 <= chosen_969 <= 1 Integer
# 0 <= chosen_9690 <= 1 Integer
# 0 <= chosen_9691 <= 1 Integer
# 0 <= chosen_9692 <= 1 Integer
# 0 <= chosen_9693 <= 1 Integer
# 0 <= chosen_9694 <= 1 Integer
# 0 <= chosen_9695 <= 1 Integer
# 0 <= chosen_9696 <= 1 Integer
# 0 <= chosen_9697 <= 1 Integer
# 0 <= chosen_9698 <= 1 Integer
# 0 <= chosen_9699 <= 1 Integer
# 0 <= chosen_97 <= 1 Integer
# 0 <= chosen_970 <= 1 Integer
# 0 <= chosen_9700 <= 1 Integer
# 0 <= chosen_9701 <= 1 Integer
# 0 <= chosen_9702 <= 1 Integer
# 0 <= chosen_9703 <= 1 Integer
# 0 <= chosen_9704 <= 1 Integer
# 0 <= chosen_9705 <= 1 Integer
# 0 <= chosen_9706 <= 1 Integer
# 0 <= chosen_9707 <= 1 Integer
# 0 <= chosen_9708 <= 1 Integer
# 0 <= chosen_9709 <= 1 Integer
# 0 <= chosen_971 <= 1 Integer
# 0 <= chosen_9710 <= 1 Integer
# 0 <= chosen_9711 <= 1 Integer
# 0 <= chosen_9712 <= 1 Integer
# 0 <= chosen_9713 <= 1 Integer
# 0 <= chosen_9714 <= 1 Integer
# 0 <= chosen_9715 <= 1 Integer
# 0 <= chosen_9716 <= 1 Integer
# 0 <= chosen_9717 <= 1 Integer
# 0 <= chosen_9718 <= 1 Integer
# 0 <= chosen_9719 <= 1 Integer
# 0 <= chosen_972 <= 1 Integer
# 0 <= chosen_9720 <= 1 Integer
# 0 <= chosen_9721 <= 1 Integer
# 0 <= chosen_9722 <= 1 Integer
# 0 <= chosen_9723 <= 1 Integer
# 0 <= chosen_9724 <= 1 Integer
# 0 <= chosen_9725 <= 1 Integer
# 0 <= chosen_9726 <= 1 Integer
# 0 <= chosen_9727 <= 1 Integer
# 0 <= chosen_9728 <= 1 Integer
# 0 <= chosen_9729 <= 1 Integer
# 0 <= chosen_973 <= 1 Integer
# 0 <= chosen_9730 <= 1 Integer
# 0 <= chosen_9731 <= 1 Integer
# 0 <= chosen_9732 <= 1 Integer
# 0 <= chosen_9733 <= 1 Integer
# 0 <= chosen_9734 <= 1 Integer
# 0 <= chosen_9735 <= 1 Integer
# 0 <= chosen_9736 <= 1 Integer
# 0 <= chosen_9737 <= 1 Integer
# 0 <= chosen_9738 <= 1 Integer
# 0 <= chosen_9739 <= 1 Integer
# 0 <= chosen_974 <= 1 Integer
# 0 <= chosen_9740 <= 1 Integer
# 0 <= chosen_9741 <= 1 Integer
# 0 <= chosen_9742 <= 1 Integer
# 0 <= chosen_9743 <= 1 Integer
# 0 <= chosen_9744 <= 1 Integer
# 0 <= chosen_9745 <= 1 Integer
# 0 <= chosen_9746 <= 1 Integer
# 0 <= chosen_9747 <= 1 Integer
# 0 <= chosen_9748 <= 1 Integer
# 0 <= chosen_9749 <= 1 Integer
# 0 <= chosen_975 <= 1 Integer
# 0 <= chosen_9750 <= 1 Integer
# 0 <= chosen_9751 <= 1 Integer
# 0 <= chosen_9752 <= 1 Integer
# 0 <= chosen_9753 <= 1 Integer
# 0 <= chosen_9754 <= 1 Integer
# 0 <= chosen_9755 <= 1 Integer
# 0 <= chosen_9756 <= 1 Integer
# 0 <= chosen_9757 <= 1 Integer
# 0 <= chosen_9758 <= 1 Integer
# 0 <= chosen_9759 <= 1 Integer
# 0 <= chosen_976 <= 1 Integer
# 0 <= chosen_9760 <= 1 Integer
# 0 <= chosen_9761 <= 1 Integer
# 0 <= chosen_9762 <= 1 Integer
# 0 <= chosen_9763 <= 1 Integer
# 0 <= chosen_9764 <= 1 Integer
# 0 <= chosen_9765 <= 1 Integer
# 0 <= chosen_9766 <= 1 Integer
# 0 <= chosen_9767 <= 1 Integer
# 0 <= chosen_9768 <= 1 Integer
# 0 <= chosen_9769 <= 1 Integer
# 0 <= chosen_977 <= 1 Integer
# 0 <= chosen_9770 <= 1 Integer
# 0 <= chosen_9771 <= 1 Integer
# 0 <= chosen_9772 <= 1 Integer
# 0 <= chosen_9773 <= 1 Integer
# 0 <= chosen_9774 <= 1 Integer
# 0 <= chosen_9775 <= 1 Integer
# 0 <= chosen_9776 <= 1 Integer
# 0 <= chosen_9777 <= 1 Integer
# 0 <= chosen_9778 <= 1 Integer
# 0 <= chosen_9779 <= 1 Integer
# 0 <= chosen_978 <= 1 Integer
# 0 <= chosen_9780 <= 1 Integer
# 0 <= chosen_9781 <= 1 Integer
# 0 <= chosen_9782 <= 1 Integer
# 0 <= chosen_9783 <= 1 Integer
# 0 <= chosen_9784 <= 1 Integer
# 0 <= chosen_9785 <= 1 Integer
# 0 <= chosen_9786 <= 1 Integer
# 0 <= chosen_9787 <= 1 Integer
# 0 <= chosen_9788 <= 1 Integer
# 0 <= chosen_9789 <= 1 Integer
# 0 <= chosen_979 <= 1 Integer
# 0 <= chosen_9790 <= 1 Integer
# 0 <= chosen_9791 <= 1 Integer
# 0 <= chosen_9792 <= 1 Integer
# 0 <= chosen_9793 <= 1 Integer
# 0 <= chosen_9794 <= 1 Integer
# 0 <= chosen_9795 <= 1 Integer
# 0 <= chosen_9796 <= 1 Integer
# 0 <= chosen_9797 <= 1 Integer
# 0 <= chosen_9798 <= 1 Integer
# 0 <= chosen_9799 <= 1 Integer
# 0 <= chosen_98 <= 1 Integer
# 0 <= chosen_980 <= 1 Integer
# 0 <= chosen_9800 <= 1 Integer
# 0 <= chosen_9801 <= 1 Integer
# 0 <= chosen_9802 <= 1 Integer
# 0 <= chosen_9803 <= 1 Integer
# 0 <= chosen_9804 <= 1 Integer
# 0 <= chosen_9805 <= 1 Integer
# 0 <= chosen_9806 <= 1 Integer
# 0 <= chosen_9807 <= 1 Integer
# 0 <= chosen_9808 <= 1 Integer
# 0 <= chosen_9809 <= 1 Integer
# 0 <= chosen_981 <= 1 Integer
# 0 <= chosen_9810 <= 1 Integer
# 0 <= chosen_9811 <= 1 Integer
# 0 <= chosen_9812 <= 1 Integer
# 0 <= chosen_9813 <= 1 Integer
# 0 <= chosen_9814 <= 1 Integer
# 0 <= chosen_9815 <= 1 Integer
# 0 <= chosen_9816 <= 1 Integer
# 0 <= chosen_9817 <= 1 Integer
# 0 <= chosen_9818 <= 1 Integer
# 0 <= chosen_9819 <= 1 Integer
# 0 <= chosen_982 <= 1 Integer
# 0 <= chosen_9820 <= 1 Integer
# 0 <= chosen_9821 <= 1 Integer
# 0 <= chosen_9822 <= 1 Integer
# 0 <= chosen_9823 <= 1 Integer
# 0 <= chosen_9824 <= 1 Integer
# 0 <= chosen_9825 <= 1 Integer
# 0 <= chosen_9826 <= 1 Integer
# 0 <= chosen_9827 <= 1 Integer
# 0 <= chosen_9828 <= 1 Integer
# 0 <= chosen_9829 <= 1 Integer
# 0 <= chosen_983 <= 1 Integer
# 0 <= chosen_9830 <= 1 Integer
# 0 <= chosen_9831 <= 1 Integer
# 0 <= chosen_9832 <= 1 Integer
# 0 <= chosen_9833 <= 1 Integer
# 0 <= chosen_9834 <= 1 Integer
# 0 <= chosen_9835 <= 1 Integer
# 0 <= chosen_9836 <= 1 Integer
# 0 <= chosen_9837 <= 1 Integer
# 0 <= chosen_9838 <= 1 Integer
# 0 <= chosen_9839 <= 1 Integer
# 0 <= chosen_984 <= 1 Integer
# 0 <= chosen_9840 <= 1 Integer
# 0 <= chosen_9841 <= 1 Integer
# 0 <= chosen_9842 <= 1 Integer
# 0 <= chosen_9843 <= 1 Integer
# 0 <= chosen_9844 <= 1 Integer
# 0 <= chosen_9845 <= 1 Integer
# 0 <= chosen_9846 <= 1 Integer
# 0 <= chosen_9847 <= 1 Integer
# 0 <= chosen_9848 <= 1 Integer
# 0 <= chosen_9849 <= 1 Integer
# 0 <= chosen_985 <= 1 Integer
# 0 <= chosen_9850 <= 1 Integer
# 0 <= chosen_9851 <= 1 Integer
# 0 <= chosen_9852 <= 1 Integer
# 0 <= chosen_9853 <= 1 Integer
# 0 <= chosen_9854 <= 1 Integer
# 0 <= chosen_9855 <= 1 Integer
# 0 <= chosen_9856 <= 1 Integer
# 0 <= chosen_9857 <= 1 Integer
# 0 <= chosen_9858 <= 1 Integer
# 0 <= chosen_9859 <= 1 Integer
# 0 <= chosen_986 <= 1 Integer
# 0 <= chosen_9860 <= 1 Integer
# 0 <= chosen_9861 <= 1 Integer
# 0 <= chosen_9862 <= 1 Integer
# 0 <= chosen_9863 <= 1 Integer
# 0 <= chosen_9864 <= 1 Integer
# 0 <= chosen_9865 <= 1 Integer
# 0 <= chosen_9866 <= 1 Integer
# 0 <= chosen_9867 <= 1 Integer
# 0 <= chosen_9868 <= 1 Integer
# 0 <= chosen_9869 <= 1 Integer
# 0 <= chosen_987 <= 1 Integer
# 0 <= chosen_9870 <= 1 Integer
# 0 <= chosen_9871 <= 1 Integer
# 0 <= chosen_9872 <= 1 Integer
# 0 <= chosen_9873 <= 1 Integer
# 0 <= chosen_9874 <= 1 Integer
# 0 <= chosen_9875 <= 1 Integer
# 0 <= chosen_9876 <= 1 Integer
# 0 <= chosen_9877 <= 1 Integer
# 0 <= chosen_9878 <= 1 Integer
# 0 <= chosen_9879 <= 1 Integer
# 0 <= chosen_988 <= 1 Integer
# 0 <= chosen_9880 <= 1 Integer
# 0 <= chosen_9881 <= 1 Integer
# 0 <= chosen_9882 <= 1 Integer
# 0 <= chosen_9883 <= 1 Integer
# 0 <= chosen_9884 <= 1 Integer
# 0 <= chosen_9885 <= 1 Integer
# 0 <= chosen_9886 <= 1 Integer
# 0 <= chosen_9887 <= 1 Integer
# 0 <= chosen_9888 <= 1 Integer
# 0 <= chosen_9889 <= 1 Integer
# 0 <= chosen_989 <= 1 Integer
# 0 <= chosen_9890 <= 1 Integer
# 0 <= chosen_9891 <= 1 Integer
# 0 <= chosen_9892 <= 1 Integer
# 0 <= chosen_9893 <= 1 Integer
# 0 <= chosen_9894 <= 1 Integer
# 0 <= chosen_9895 <= 1 Integer
# 0 <= chosen_9896 <= 1 Integer
# 0 <= chosen_9897 <= 1 Integer
# 0 <= chosen_9898 <= 1 Integer
# 0 <= chosen_9899 <= 1 Integer
# 0 <= chosen_99 <= 1 Integer
# 0 <= chosen_990 <= 1 Integer
# 0 <= chosen_9900 <= 1 Integer
# 0 <= chosen_9901 <= 1 Integer
# 0 <= chosen_9902 <= 1 Integer
# 0 <= chosen_9903 <= 1 Integer
# 0 <= chosen_9904 <= 1 Integer
# 0 <= chosen_9905 <= 1 Integer
# 0 <= chosen_9906 <= 1 Integer
# 0 <= chosen_9907 <= 1 Integer
# 0 <= chosen_9908 <= 1 Integer
# 0 <= chosen_9909 <= 1 Integer
# 0 <= chosen_991 <= 1 Integer
# 0 <= chosen_9910 <= 1 Integer
# 0 <= chosen_9911 <= 1 Integer
# 0 <= chosen_9912 <= 1 Integer
# 0 <= chosen_9913 <= 1 Integer
# 0 <= chosen_9914 <= 1 Integer
# 0 <= chosen_9915 <= 1 Integer
# 0 <= chosen_9916 <= 1 Integer
# 0 <= chosen_9917 <= 1 Integer
# 0 <= chosen_9918 <= 1 Integer
# 0 <= chosen_9919 <= 1 Integer
# 0 <= chosen_992 <= 1 Integer
# 0 <= chosen_9920 <= 1 Integer
# 0 <= chosen_9921 <= 1 Integer
# 0 <= chosen_9922 <= 1 Integer
# 0 <= chosen_9923 <= 1 Integer
# 0 <= chosen_9924 <= 1 Integer
# 0 <= chosen_9925 <= 1 Integer
# 0 <= chosen_9926 <= 1 Integer
# 0 <= chosen_9927 <= 1 Integer
# 0 <= chosen_9928 <= 1 Integer
# 0 <= chosen_9929 <= 1 Integer
# 0 <= chosen_993 <= 1 Integer
# 0 <= chosen_9930 <= 1 Integer
# 0 <= chosen_9931 <= 1 Integer
# 0 <= chosen_9932 <= 1 Integer
# 0 <= chosen_9933 <= 1 Integer
# 0 <= chosen_9934 <= 1 Integer
# 0 <= chosen_9935 <= 1 Integer
# 0 <= chosen_9936 <= 1 Integer
# 0 <= chosen_9937 <= 1 Integer
# 0 <= chosen_9938 <= 1 Integer
# 0 <= chosen_9939 <= 1 Integer
# 0 <= chosen_994 <= 1 Integer
# 0 <= chosen_9940 <= 1 Integer
# 0 <= chosen_9941 <= 1 Integer
# 0 <= chosen_9942 <= 1 Integer
# 0 <= chosen_9943 <= 1 Integer
# 0 <= chosen_9944 <= 1 Integer
# 0 <= chosen_9945 <= 1 Integer
# 0 <= chosen_9946 <= 1 Integer
# 0 <= chosen_9947 <= 1 Integer
# 0 <= chosen_9948 <= 1 Integer
# 0 <= chosen_9949 <= 1 Integer
# 0 <= chosen_995 <= 1 Integer
# 0 <= chosen_9950 <= 1 Integer
# 0 <= chosen_9951 <= 1 Integer
# 0 <= chosen_9952 <= 1 Integer
# 0 <= chosen_9953 <= 1 Integer
# 0 <= chosen_9954 <= 1 Integer
# 0 <= chosen_9955 <= 1 Integer
# 0 <= chosen_9956 <= 1 Integer
# 0 <= chosen_9957 <= 1 Integer
# 0 <= chosen_9958 <= 1 Integer
# 0 <= chosen_9959 <= 1 Integer
# 0 <= chosen_996 <= 1 Integer
# 0 <= chosen_9960 <= 1 Integer
# 0 <= chosen_9961 <= 1 Integer
# 0 <= chosen_9962 <= 1 Integer
# 0 <= chosen_9963 <= 1 Integer
# 0 <= chosen_9964 <= 1 Integer
# 0 <= chosen_9965 <= 1 Integer
# 0 <= chosen_9966 <= 1 Integer
# 0 <= chosen_9967 <= 1 Integer
# 0 <= chosen_9968 <= 1 Integer
# 0 <= chosen_9969 <= 1 Integer
# 0 <= chosen_997 <= 1 Integer
# 0 <= chosen_9970 <= 1 Integer
# 0 <= chosen_9971 <= 1 Integer
# 0 <= chosen_9972 <= 1 Integer
# 0 <= chosen_9973 <= 1 Integer
# 0 <= chosen_9974 <= 1 Integer
# 0 <= chosen_9975 <= 1 Integer
# 0 <= chosen_9976 <= 1 Integer
# 0 <= chosen_9977 <= 1 Integer
# 0 <= chosen_9978 <= 1 Integer
# 0 <= chosen_9979 <= 1 Integer
# 0 <= chosen_998 <= 1 Integer
# 0 <= chosen_9980 <= 1 Integer
# 0 <= chosen_9981 <= 1 Integer
# 0 <= chosen_9982 <= 1 Integer
# 0 <= chosen_9983 <= 1 Integer
# 0 <= chosen_9984 <= 1 Integer
# 0 <= chosen_9985 <= 1 Integer
# 0 <= chosen_9986 <= 1 Integer
# 0 <= chosen_9987 <= 1 Integer
# 0 <= chosen_9988 <= 1 Integer
# 0 <= chosen_9989 <= 1 Integer
# 0 <= chosen_999 <= 1 Integer
# 0 <= chosen_9990 <= 1 Integer
# 0 <= chosen_9991 <= 1 Integer
# 0 <= chosen_9992 <= 1 Integer
# 0 <= chosen_9993 <= 1 Integer
# 0 <= chosen_9994 <= 1 Integer
# 0 <= chosen_9995 <= 1 Integer
# 0 <= chosen_9996 <= 1 Integer
# 0 <= chosen_9997 <= 1 Integer
# 0 <= chosen_9998 <= 1 Integer
# 0 <= chosen_9999 <= 1 Integer

# %%
prob += (
    lpSum([chosen[game_id] for game_id in unranked_data["game_id"].to_list()]) == sample_num
)

# %%
predictive_spread_cover_push_games = unranked_data.query("predictive_spread_cover == 'push'")["game_id"].to_list()
predictive_home_covers = unranked_data.query("predictive_spread_cover == 'home'")["game_id"].to_list()
predictive_away_covers = unranked_data.query("predictive_spread_cover == 'away'")["game_id"].to_list()
print(len(predictive_spread_cover_push_games), len(predictive_home_covers), len(predictive_away_covers))
# Out:
# 29 12219 100

# %%
predictive_total_result_push_games = unranked_data.query("predictive_total == 'push'")["game_id"].to_list()
predictive_total_over_games = unranked_data.query("predictive_total == 'over'")["game_id"].to_list()
predictive_total_under_games = unranked_data.query("predictive_total == 'under'")["game_id"].to_list()
print(len(predictive_total_result_push_games), len(predictive_total_over_games), len(predictive_total_under_games))
# Out:
# 12 63 12273

# %%
spread_result_push_games =  unranked_data.query("spread_result == 'push'")["game_id"].to_list()
spread_result_home_games =  unranked_data.query("spread_result == 'home_cover'")["game_id"].to_list()
spread_result_away_games =  unranked_data.query("spread_result == 'away_cover'")["game_id"].to_list()
print(len(spread_result_push_games), len(spread_result_home_games), len(spread_result_away_games))
# Out:
# 215 10496 1637

# %%
total_result_push_games =  unranked_data.query("total_result == 'push'")["game_id"].to_list()
total_result_over_games =  unranked_data.query("total_result == 'over'")["game_id"].to_list()
total_result_under_games =  unranked_data.query("total_result == 'under'")["game_id"].to_list()
print(len(total_result_push_games), len(total_result_over_games), len(total_result_under_games))
# Out:
# 108 1121 11119

# %%
equal_median_games = unranked_data.query(f"points == {true_target_values['total']}")["game_id"].to_list()

# %%
over_median_games = unranked_data.query(f"points > {true_target_values['total']}")["game_id"].to_list()
under_median_games = unranked_data.query(f"points < {true_target_values['total']}")["game_id"].to_list()

# %%
## PREDICTIVE SPREAD COVER FOR HOME

prob += (
    true_target_values["home_win"]  * 
    (sample_num - lpSum([chosen[game_id] for game_id in predictive_spread_cover_push_games]))
    
    >= lpSum([chosen[game_id] for game_id in predictive_home_covers]) - 0.5
    )

prob += (
    true_target_values["home_win"]  * 
    (sample_num - lpSum([chosen[game_id] for game_id in predictive_spread_cover_push_games]))
    
    <= lpSum([chosen[game_id] for game_id in predictive_home_covers]) + 0.5
    )


## PREDICTIVE SPREAD COVER FOR AWAY
prob += (
    (1-true_target_values["home_win"])  * 
    (sample_num - lpSum([chosen[game_id] for game_id in predictive_spread_cover_push_games]))
    
    >= lpSum([chosen[game_id] for game_id in predictive_away_covers]) - 0.5
    )
prob += (
    (1-true_target_values["home_win"])  * 
    (sample_num - lpSum([chosen[game_id] for game_id in predictive_spread_cover_push_games]))
    
    <= lpSum([chosen[game_id] for game_id in predictive_away_covers]) + 0.5
    )


## PREDICTIVE TOTAL_RESULT for OVER

prob += (
    true_target_values["over_prob"]  * 
    (sample_num - lpSum([chosen[game_id] for game_id in predictive_total_result_push_games]))
    
    >= lpSum([chosen[game_id] for game_id in predictive_total_over_games]) - 0.5
    )
prob += (
    true_target_values["over_prob"]  * 
    (sample_num - lpSum([chosen[game_id] for game_id in predictive_total_result_push_games]))
    
    <= lpSum([chosen[game_id] for game_id in predictive_total_over_games]) + 0.5
    )


## PREDICTIVE TOTAL_RESULT for UNDER
prob += (
    (1-true_target_values["over_prob"])  * 
    (sample_num - lpSum([chosen[game_id] for game_id in predictive_total_result_push_games]))
    
    >= lpSum([chosen[game_id] for game_id in predictive_total_under_games]) - 0.5
    )
prob += (
    (1-true_target_values["over_prob"])  * 
    (sample_num - lpSum([chosen[game_id] for game_id in predictive_total_result_push_games]))
    
    <= lpSum([chosen[game_id] for game_id in predictive_total_under_games]) + 0.5
    )

# %%
## TOTAL_RESULT for OVER

prob += (
    true_target_values["over_prob"]  * 
    (sample_num - lpSum([chosen[game_id] for game_id in total_result_push_games]))
    
    >= lpSum([chosen[game_id] for game_id in total_result_over_games]) - 0.5
    )
prob += (
    true_target_values["over_prob"]  * 
    (sample_num - lpSum([chosen[game_id] for game_id in total_result_push_games]))
    
    <= lpSum([chosen[game_id] for game_id in total_result_over_games]) + 0.5
    )

## TOTAL_RESULT for UNDER
prob += (
    (1-true_target_values["over_prob"])  * 
    (sample_num - lpSum([chosen[game_id] for game_id in total_result_push_games]))
    
    >= lpSum([chosen[game_id] for game_id in total_result_under_games]) - 0.5
    )
prob += (
    (1-true_target_values["over_prob"])  * 
    (sample_num - lpSum([chosen[game_id] for game_id in total_result_push_games]))
    
    <= lpSum([chosen[game_id] for game_id in total_result_under_games]) + 0.5
    )



## SPREAD COVER FOR HOME

prob += (
    true_target_values["home_win"]  * 
    (sample_num - lpSum([chosen[game_id] for game_id in spread_result_push_games]))
    
    >= lpSum([chosen[game_id] for game_id in spread_result_home_games]) - 0.5
    )

prob += (
    true_target_values["home_win"]  * 
    (sample_num - lpSum([chosen[game_id] for game_id in spread_result_push_games]))
    
    <= lpSum([chosen[game_id] for game_id in spread_result_home_games]) + 0.5
    )


## SPREAD COVER FOR AWAY
prob += (
    (1-true_target_values["home_win"])  * 
    (sample_num - lpSum([chosen[game_id] for game_id in spread_result_push_games]))
    
    >= lpSum([chosen[game_id] for game_id in spread_result_away_games]) - 0.5
    )
prob += (
    (1-true_target_values["home_win"])  * 
    (sample_num - lpSum([chosen[game_id] for game_id in spread_result_push_games]))
    
    <= lpSum([chosen[game_id] for game_id in spread_result_away_games]) + 0.5
    )

# %%
# prob += (
#     (500 - lpSum([chosen[game_id] for game_id in equal_median_games]))/2.0
    
#     >= lpSum([chosen[game_id] for game_id in over_median_games]) - 4
#     )

# prob += (
#     (500 - lpSum([chosen[game_id] for game_id in equal_median_games]))/2.0
    
#     <= lpSum([chosen[game_id] for game_id in over_median_games]) + 4
#     )

# prob += (
#     (500 - lpSum([chosen[game_id] for game_id in equal_median_games]))/2.0
    
#     >= lpSum([chosen[game_id] for game_id in under_median_games]) - 4
#     )

# prob += (
#     (500 - lpSum([chosen[game_id] for game_id in equal_median_games]))/2.0
    
#     <= lpSum([chosen[game_id] for game_id in under_median_games]) + 4
#     )

# %%
prob
# Out:
# Pythag_error_minimize:
# MINIMIZE
# 51.0*chosen_1 + 59.0*chosen_10 + 48.5*chosen_100 + 56.0*chosen_1000 + 20.5*chosen_10000 + 33.0*chosen_10001 + 27.5*chosen_10002 + 49.5*chosen_10003 + 31.5*chosen_10004 + 40.5*chosen_10005 + 25.0*chosen_10006 + 21.5*chosen_10007 + 16.0*chosen_10008 + 45.0*chosen_10009 + 56.0*chosen_1001 + 14.0*chosen_10010 + 9.0*chosen_10011 + 45.0*chosen_10012 + 22.0*chosen_10013 + 29.0*chosen_10014 + 28.5*chosen_10015 + 17.5*chosen_10016 + 32.5*chosen_10017 + 37.5*chosen_10018 + 27.0*chosen_10019 + 45.5*chosen_1002 + 7.5*chosen_10020 + 31.5*chosen_10021 + 35.5*chosen_10022 + 21.5*chosen_10023 + 18.0*chosen_10024 + 37.5*chosen_10025 + 27.0*chosen_10026 + 45.0*chosen_10027 + 37.0*chosen_10028 + 43.0*chosen_10029 + 51.5*chosen_1003 + 34.0*chosen_10030 + 37.5*chosen_10031 + 21.0*chosen_10032 + 18.5*chosen_10033 + 18.5*chosen_10034 + 4.0*chosen_10035 + 4.0*chosen_10036 + 34.5*chosen_10037 + 34.5*chosen_10038 + 37.0*chosen_10039 + 59.0*chosen_1004 + 37.0*chosen_10040 + 42.5*chosen_10041 + 24.0*chosen_10042 + 27.0*chosen_10043 + 38.5*chosen_10044 + 27.5*chosen_10045 + 33.5*chosen_10046 + 4.0*chosen_10047 + 25.0*chosen_10048 + 52.5*chosen_10049 + 54.0*chosen_1005 + 21.5*chosen_10050 + 20.0*chosen_10051 + 22.5*chosen_10052 + 19.0*chosen_10053 + 43.5*chosen_10054 + 28.0*chosen_10055 + 26.0*chosen_10056 + 30.0*chosen_10057 + 11.5*chosen_10058 + 15.5*chosen_10059 + 42.0*chosen_1006 + 39.5*chosen_10060 + 17.0*chosen_10061 + 21.0*chosen_10062 + 44.0*chosen_10063 + 39.0*chosen_10064 + 49.5*chosen_10065 + 13.0*chosen_10066 + 39.0*chosen_10067 + 27.0*chosen_10068 + 26.5*chosen_10069 + 43.5*chosen_1007 + 35.5*chosen_10070 + 29.5*chosen_10071 + 41.0*chosen_10072 + 26.0*chosen_10073 + 43.0*chosen_10074 + 51.5*chosen_10075 + 30.0*chosen_10076 + 15.5*chosen_10077 + 18.0*chosen_10078 + 23.5*chosen_10079 + 47.0*chosen_1008 + 27.5*chosen_10080 + 34.0*chosen_10081 + 46.5*chosen_10082 + 13.0*chosen_10083 + 39.5*chosen_10084 + 9.0*chosen_10085 + 41.0*chosen_10086 + 46.5*chosen_10087 + 33.5*chosen_10088 + 12.0*chosen_10089 + 58.5*chosen_1009 + 12.0*chosen_10090 + 18.0*chosen_10091 + 18.0*chosen_10092 + 14.5*chosen_10093 + 25.5*chosen_10094 + 19.0*chosen_10095 + 19.5*chosen_10096 + 11.0*chosen_10097 + 39.0*chosen_10098 + 30.5*chosen_10099 + 49.0*chosen_101 + 61.0*chosen_1010 + 39.0*chosen_10100 + 37.0*chosen_10101 + 49.5*chosen_10102 + 45.5*chosen_10103 + 18.5*chosen_10104 + 23.0*chosen_10105 + 22.5*chosen_10106 + 31.0*chosen_10107 + 32.5*chosen_10108 + 18.5*chosen_10109 + 65.5*chosen_1011 + 34.5*chosen_10110 + 40.5*chosen_10111 + 42.5*chosen_10112 + 21.5*chosen_10113 + 24.0*chosen_10114 + 23.0*chosen_10115 + 34.5*chosen_10116 + 15.0*chosen_10117 + 16.5*chosen_10118 + 38.5*chosen_10119 + 53.0*chosen_1012 + 33.0*chosen_10120 + 29.5*chosen_10121 + 24.5*chosen_10122 + 41.0*chosen_10123 + 34.5*chosen_10124 + 25.0*chosen_10125 + 15.5*chosen_10126 + 22.0*chosen_10127 + 29.5*chosen_10128 + 16.5*chosen_10129 + 55.5*chosen_1013 + 18.0*chosen_10130 + 40.5*chosen_10131 + 38.5*chosen_10132 + 23.5*chosen_10133 + 33.5*chosen_10134 + 29.0*chosen_10135 + 28.0*chosen_10136 + 22.5*chosen_10137 + 23.5*chosen_10138 + 24.0*chosen_10139 + 65.5*chosen_1014 + 26.5*chosen_10140 + 26.5*chosen_10141 + 39.0*chosen_10142 + 39.0*chosen_10143 + 26.0*chosen_10144 + 26.0*chosen_10145 + 46.5*chosen_10146 + 46.5*chosen_10147 + 21.0*chosen_10148 + 21.0*chosen_10149 + 56.5*chosen_1015 + 14.5*chosen_10150 + 14.5*chosen_10151 + 35.0*chosen_10152 + 37.5*chosen_10153 + 34.0*chosen_10154 + 38.5*chosen_10155 + 18.0*chosen_10156 + 34.0*chosen_10157 + 38.0*chosen_10158 + 35.5*chosen_10159 + 39.0*chosen_1016 + 23.0*chosen_10160 + 16.5*chosen_10161 + 27.0*chosen_10162 + 24.5*chosen_10163 + 29.0*chosen_10164 + 56.5*chosen_10165 + 54.0*chosen_10166 + 24.5*chosen_10167 + 34.5*chosen_10168 + 24.5*chosen_10169 + 58.0*chosen_1017 + 20.0*chosen_10170 + 32.0*chosen_10171 + 33.0*chosen_10172 + 44.0*chosen_10173 + 24.0*chosen_10174 + 32.5*chosen_10175 + 29.0*chosen_10176 + 28.0*chosen_10177 + 21.5*chosen_10178 + 27.5*chosen_101 ...
# SUBJECT TO
# _C1: chosen_1 + chosen_10 + chosen_100 + chosen_1000 + chosen_10000
#  + chosen_10001 + chosen_10002 + chosen_10003 + chosen_10004 + chosen_10005
#  + chosen_10006 + chosen_10007 + chosen_10008 + chosen_10009 + chosen_1001
#  + chosen_10010 + chosen_10011 + chosen_10012 + chosen_10013 + chosen_10014
#  + chosen_10015 + chosen_10016 + chosen_10017 + chosen_10018 + chosen_10019
#  + chosen_1002 + chosen_10020 + chosen_10021 + chosen_10022 + chosen_10023
#  + chosen_10024 + chosen_10025 + chosen_10026 + chosen_10027 + chosen_10028
#  + chosen_10029 + chosen_1003 + chosen_10030 + chosen_10031 + chosen_10032
#  + chosen_10033 + chosen_10034 + chosen_10035 + chosen_10036 + chosen_10037
#  + chosen_10038 + chosen_10039 + chosen_1004 + chosen_10040 + chosen_10041
#  + chosen_10042 + chosen_10043 + chosen_10044 + chosen_10045 + chosen_10046
#  + chosen_10047 + chosen_10048 + chosen_10049 + chosen_1005 + chosen_10050
#  + chosen_10051 + chosen_10052 + chosen_10053 + chosen_10054 + chosen_10055
#  + chosen_10056 + chosen_10057 + chosen_10058 + chosen_10059 + chosen_1006
#  + chosen_10060 + chosen_10061 + chosen_10062 + chosen_10063 + chosen_10064
#  + chosen_10065 + chosen_10066 + chosen_10067 + chosen_10068 + chosen_10069
#  + chosen_1007 + chosen_10070 + chosen_10071 + chosen_10072 + chosen_10073
#  + chosen_10074 + chosen_10075 + chosen_10076 + chosen_10077 + chosen_10078
#  + chosen_10079 + chosen_1008 + chosen_10080 + chosen_10081 + chosen_10082
#  + chosen_10083 + chosen_10084 + chosen_10085 + chosen_10086 + chosen_10087
#  + chosen_10088 + chosen_10089 + chosen_1009 + chosen_10090 + chosen_10091
#  + chosen_10092 + chosen_10093 + chosen_10094 + chosen_10095 + chosen_10096
#  + chosen_10097 + chosen_10098 + chosen_10099 + chosen_101 + chosen_1010
#  + chosen_10100 + chosen_10101 + chosen_10102 + chosen_10103 + chosen_10104
#  + chosen_10105 + chosen_10106 + chosen_10107 + chosen_10108 + chosen_10109
#  + chosen_1011 + chosen_10110 + chosen_10111 + chosen_10112 + chosen_10113
#  + chosen_10114 + chosen_10115 + chosen_10116 + chosen_10117 + chosen_10118
#  + chosen_10119 + chosen_1012 + chosen_10120 + chosen_10121 + chosen_10122
#  + chosen_10123 + chosen_10124 + chosen_10125 + chosen_10126 + chosen_10127
#  + chosen_10128 + chosen_10129 + chosen_1013 + chosen_10130 + chosen_10131
#  + chosen_10132 + chosen_10133 + chosen_10134 + chosen_10135 + chosen_10136
#  + chosen_10137 + chosen_10138 + chosen_10139 + chosen_1014 + chosen_10140
#  + chosen_10141 + chosen_10142 + chosen_10143 + chosen_10144 + chosen_10145
#  + chosen_10146 + chosen_10147 + chosen_10148 + chosen_10149 + chosen_1015
#  + chosen_10150 + chosen_10151 + chosen_10152 + chosen_10153 + chosen_10154
#  + chosen_10155 + chosen_10156 + chosen_10157 + chosen_10158 + chosen_10159
#  + chosen_1016 + chosen_10160 + chosen_10161 + chosen_10162 + chosen_10163
#  + chosen_10164 + chosen_10165 + chosen_10166 + chosen_10167 + chosen_10168
#  + chosen_10169 + chosen_1017 + chosen_10170 + chosen_10171 + chosen_10172
#  + chosen_10173 + chosen_10174 + chosen_10175 + chosen_10176 + chosen_10177
#  + chosen_10178 + chosen_10179 + chosen_1018 + chosen_10180 + chosen_10181
#  + chosen_10182 + chosen_10183 + chosen_10184 + chosen_10185 + chosen_10186
#  + chosen_10187 + chosen_10188 + chosen_10189 + chosen_1019 + chosen_10190
#  + chosen_10191 + chosen_10192 + chosen_10193 + chosen_10194 + chosen_10195
#  + chosen_10196 + chosen_10197 + chosen_10198 + chosen_10199 + chosen_102
#  + chosen_1020 + chosen_10200 + chosen_10201 + chosen_10202 + chosen_10203
#  + chosen_10204 + chosen_10205 + chosen_10206 + chosen_10207 + chosen_10208
#  + chosen_10209 + chosen_1021 + chosen_10210 + chosen_10211 + chosen_10212
#  + chosen_10213 + chosen_10214 + chosen_10215 + chosen_10216 + chosen_10217
#  + chosen_10218 + chosen_10219 + chosen_1022 + chosen_10220 + chosen_10221
#  + chosen_10222 + chosen_10223 + chosen_10224 + chosen_10225 + chosen_10226
#  + chosen_10227 + chosen_10228 + chosen_10229 + chosen_1023 + chosen_10230
#  + chosen_10231 + chosen_10232 + chosen_10233 + chosen_10234 + chosen_10235
#  + chosen_10236 + chosen_10237 + chosen_10238 + chosen_10239 + chosen_1024
#  + chosen_10240 + chosen_10241 + chosen_10242 + chosen_10243 + chosen_10244
#  + chosen_10245 + chosen_10246 + chosen_10247 + chosen_10248 + chosen_10249
#  + chosen_1025 + chosen_10250 + chosen_10251 + chosen_10252 + chosen_10253
#  + chosen_10254 + chosen_10255 + chosen_10256 + chosen_10257 + chosen_10258
#  + chosen_10259 + chosen_1026 + chosen_10260 + chosen_10261 + chosen_10262
#  + chosen_10263 + chosen_10264 + chosen_10265 + chosen_10266 + chosen_10267
#  + chosen_10268 + chosen_10269 + chosen_1027 + chosen_10270 + chosen_10271
#  + chosen_10272 + chosen_10273 + chosen_10274 + chosen_10275 + chosen_10276
#  + chosen_10277 + chosen_10278 + chosen_10279 + chosen_1028 + chosen_10280
#  + chosen_10281 + chosen_10282 + chosen_10283 + chosen_10284 + chosen_10285
#  + chosen_10286 + chosen_10287 + chosen_10288 + chosen_10289 + chosen_1029
#  + chosen_10290 + chosen_10291 + chosen_10292 + chosen_10293 + chosen_10294
#  + chosen_10295 + chosen_10296 + chosen_10297 + chosen_10298 + chosen_10299
#  + chosen_103 + chosen_1030 + chosen_10300 + chosen_10301 + chosen_10302
#  + chosen_10303 + chosen_10304 + chosen_10305 + chosen_10306 + chosen_10307
#  + chosen_10308 + chosen_10309 + chosen_1031 + chosen_10310 + chosen_10311
#  + chosen_10312 + chosen_10313 + chosen_10314 + chosen_10315 + chosen_10316
#  + chosen_10317 + chosen_10318 + chosen_10319 + chosen_1032 + chosen_10320
#  + chosen_10321 + chosen_10322 + chosen_10323 + chosen_10324 + chosen_10325
#  + chosen_10326 + chosen_10327 + chosen_10328 + chosen_10329 + chosen_1033
#  + chosen_10330 + chosen_10331 + chosen_10332 + chosen_10333 + chosen_10334
#  + chosen_10335 + chosen_10336 + chosen_10337 + chosen_10338 + chosen_10339
#  + chosen_1034 + chosen_10340 + chosen_10341 + chosen_10342 + chosen_10343
#  + chosen_10344 + chosen_10345 + chosen_10346 + chosen_10347 + chosen_10348
#  + chosen_10349 + chosen_1035 + chosen_10350 + chosen_10351 + chosen_10352
#  + chosen_10353 + chosen_10354 + chosen_10355 + chosen_10356 + chosen_10357
#  + chosen_10358 + chosen_10359 + chosen_1036 + chosen_10360 + chosen_10361
#  + chosen_10362 + chosen_10363 + chosen_10364 + chosen_10365 + chosen_10366
#  + chosen_10367 + chosen_10368 + chosen_10369 + chosen_1037 + chosen_10370
#  + chosen_10371 + chosen_10372 + chosen_10373 + chosen_10374 + chosen_10375
#  + chosen_10376 + chosen_10377 + chosen_10378 + chosen_10379 + chosen_1038
#  + chosen_10380 + chosen_10381 + chosen_10382 + chosen_10383 + chosen_10384
#  + chosen_10385 + chosen_10386 + chosen_10387 + chosen_10388 + chosen_10389
#  + chosen_1039 + chosen_10390 + chosen_10391 + chosen_10392 + chosen_10393
#  + chosen_10394 + chosen_10395 + chosen_10396 + chosen_10397 + chosen_10398
#  + chosen_10399 + chosen_104 + chosen_1040 + chosen_10400 + chosen_10401
#  + chosen_10402 + chosen_10403 + chosen_10404 + chosen_10405 + chosen_10406
#  + chosen_10407 + chosen_10408 + chosen_10409 + chosen_1041 + chosen_10410
#  + chosen_10411 + chosen_10412 + chosen_10413 + chosen_10414 + chosen_10415
#  + chosen_10416 + chosen_10417 + chosen_10418 + chosen_10419 + chosen_1042
#  + chosen_10420 + chosen_10421 + chosen_10422 + chosen_10423 + chosen_10424
#  + chosen_10425 + chosen_10426 + chosen_10427 + chosen_10428 + chosen_10429
#  + chosen_1043 + chosen_10430 + chosen_10431 + chosen_10432 + chosen_10433
#  + chosen_10434 + chosen_10435 + chosen_10436 + chosen_10437 + chosen_10438
#  + chosen_10439 + chosen_1044 + chosen_10440 + chosen_10441 + chosen_10442
#  + chosen_10443 + chosen_10444 + chosen_10445 + chosen_10446 + chosen_10447
#  + chosen_10448 + chosen_10449 + chosen_1045 + chosen_10450 + chosen_10451
#  + chosen_10452 + chosen_10453 + chosen_10454 + chosen_10455 + chosen_10456
#  + chosen_10457 + chosen_10458 + chosen_10459 + chosen_1046 + chosen_10460
#  + chosen_10461 + chosen_10462 + chosen_10463 + chosen_10464 + chosen_10465
#  + chosen_10466 + chosen_10467 + chosen_10468 + chosen_10469 + chosen_1047
#  + chosen_10470 + chosen_10471 + chosen_10472 + chosen_10473 + chosen_10474
#  + chosen_10475 + chosen_10476 + chosen_10477 + chosen_10478 + chosen_10479
#  + chosen_1048 + chosen_10480 + chosen_10481 + chosen_10482 + chosen_10483
#  + chosen_10484 + chosen_10485 + chosen_10486 + chosen_10487 + chosen_10488
#  + chosen_10489 + chosen_1049 + chosen_10490 + chosen_10491 + chosen_10492
#  + chosen_10493 + chosen_10494 + chosen_10495 + chosen_10496 + chosen_10497
#  + chosen_10498 + chosen_10499 + chosen_105 + chosen_1050 + chosen_10500
#  + chosen_10501 + chosen_10502 + chosen_10503 + chosen_10504 + chosen_10505
#  + chosen_10506 + chosen_10507 + chosen_10508 + chosen_10509 + chosen_1051
#  + chosen_10510 + chosen_10511 + chosen_10512 + chosen_10513 + chosen_10514
#  + chosen_10515 + chosen_10516 + chosen_10517 + chosen_10518 + chosen_10519
#  + chosen_1052 + chosen_10520 + chosen_10521 + chosen_10522 + chosen_10523
#  + chosen_10524 + chosen_10525 + chosen_10526 + chosen_10527 + chosen_10528
#  + chosen_10529 + chosen_1053 + chosen_10530 + chosen_10531 + chosen_10532
#  + chosen_10533 + chosen_10534 + chosen_10535 + chosen_10536 + chosen_10537
#  + chosen_10538 + chosen_10539 + chosen_1054 + chosen_10540 + chosen_10541
#  + chosen_10542 + chosen_10543 + chosen_10544 + chosen_10545 + chosen_10546
#  + chosen_10547 + chosen_10548 + chosen_10549 + chosen_1055 + chosen_10550
#  + chosen_10551 + chosen_10552 + chosen_10553 + chosen_10554 + chosen_10555
#  + chosen_10556 + chosen_10557 + chosen_10558 + chosen_10559 + chosen_1056
#  + chosen_10560 + chosen_10561 + chosen_10562 + chosen_10563 + chosen_10564
#  + chosen_10565 + chosen_10566 + chosen_10567 + chosen_10568 + chosen_10569
#  + chosen_1057 + chosen_10570 + chosen_10571 + chosen_10572 + chosen_10573
#  + chosen_10574 + chosen_10575 + chosen_10576 + chosen_10577 + chosen_10578
#  + chosen_10579 + chosen_1058 + chosen_10580 + chosen_10581 + chosen_10582
#  + chosen_10583 + chosen_10584 + chosen_10585 + chosen_10586 + chosen_10587
#  + chosen_10588 + chosen_10589 + chosen_1059 + chosen_10590 + chosen_10591
#  + chosen_10592 + chosen_10593 + chosen_10594 + chosen_10595 + chosen_10596
#  + chosen_10597 + chosen_10598 + chosen_10599 + chosen_106 + chosen_1060
#  + chosen_10600 + chosen_10601 + chosen_10602 + chosen_10603 + chosen_10604
#  + chosen_10605 + chosen_10606 + chosen_10607 + chosen_10608 + chosen_10609
#  + chosen_1061 + chosen_10610 + chosen_10611 + chosen_10612 + chosen_10613
#  + chosen_10614 + chosen_10615 + chosen_10616 + chosen_10617 + chosen_10618
#  + chosen_10619 + chosen_1062 + chosen_10620 + chosen_10621 + chosen_10622
#  + chosen_10623 + chosen_10624 + chosen_10625 + chosen_10626 + chosen_10627
#  + chosen_10628 + chosen_10629 + chosen_1063 + chosen_10630 + chosen_10631
#  + chosen_10632 + chosen_10633 + chosen_10634 + chosen_10635 + chosen_10636
#  + chosen_10637 + chosen_10638 + chosen_10639 + chosen_1064 + chosen_10640
#  + chosen_10641 + chosen_10642 + chosen_10643 + chosen_10644 + chosen_10645
#  + chosen_10646 + chosen_10647 + chosen_10648 + chosen_10649 + chosen_1065
#  + chosen_10650 + chosen_10651 + chosen_10652 + chosen_10653 + chosen_10654
#  + chosen_10655 + chosen_10656 + chosen_10657 + chosen_10658 + chosen_10659
#  + chosen_1066 + chosen_10660 + chosen_10661 + chosen_10662 + chosen_10663
#  + chosen_10664 + chosen_10665 + chosen_10666 + chosen_10667 + chosen_10668
#  + chosen_10669 + chosen_1067 + chosen_10670 + chosen_10671 + chosen_10672
#  + chosen_10673 + chosen_10674 + chosen_10675 + chosen_10676 + chosen_10677
#  + chosen_10678 + chosen_10679 + chosen_1068 + chosen_10680 + chosen_10681
#  + chosen_10682 + chosen_10683 + chosen_10684 + chosen_10685 + chosen_10686
#  + chosen_10687 + chosen_10688 + chosen_10689 + chosen_1069 + chosen_10690
#  + chosen_10691 + chosen_10692 + chosen_10693 + chosen_10694 + chosen_10695
#  + chosen_10696 + chosen_10697 + chosen_10698 + chosen_10699 + chosen_107
#  + chosen_1070 + chosen_10700 + chosen_10701 + chosen_10702 + chosen_10703
#  + chosen_10704 + chosen_10705 + chosen_10706 + chosen_10707 + chosen_10708
#  + chosen_10709 + chosen_1071 + chosen_10710 + chosen_10711 + chosen_10712
#  + chosen_10713 + chosen_10714 + chosen_10715 + chosen_10716 + chosen_10717
#  + chosen_10718 + chosen_10719 + chosen_1072 + chosen_10720 + chosen_10721
#  + chosen_10722 + chosen_10723 + chosen_10724 + chosen_10725 + chosen_10726
#  + chosen_10727 + chosen_10728 + chosen_10729 + chosen_1073 + chosen_10730
#  + chosen_10731 + chosen_10732 + chosen_10733 + chosen_10734 + chosen_10735
#  + chosen_10736 + chosen_10737 + chosen_10738 + chosen_10739 + chosen_1074
#  + chosen_10740 + chosen_10741 + chosen_10742 + chosen_10743 + chosen_10744
#  + chosen_10745 + chosen_10746 + chosen_10747 + chosen_10748 + chosen_10749
#  + chosen_1075 + chosen_10750 + chosen_10751 + chosen_10752 + chosen_10753
#  + chosen_10754 + chosen_10755 + chosen_10756 + chosen_10757 + chosen_10758
#  + chosen_10759 + chosen_1076 + chosen_10760 + chosen_10761 + chosen_10762
#  + chosen_10763 + chosen_10764 + chosen_10765 + chosen_10766 + chosen_10767
#  + chosen_10768 + chosen_10769 + chosen_1077 + chosen_10770 + chosen_10771
#  + chosen_10772 + chosen_10773 + chosen_10774 + chosen_10775 + chosen_10776
#  + chosen_10777 + chosen_10778 + chosen_10779 + chosen_1078 + chosen_10780
#  + chosen_10781 + chosen_10782 + chosen_10783 + chosen_10784 + chosen_10785
#  + chosen_10786 + chosen_10787 + chosen_10788 + chosen_10789 + chosen_1079
#  + chosen_10790 + chosen_10791 + chosen_10792 + chosen_10793 + chosen_10794
#  + chosen_10795 + chosen_10796 + chosen_10797 + chosen_10798 + chosen_10799
#  + chosen_108 + chosen_1080 + chosen_10800 + chosen_10801 + chosen_10802
#  + chosen_10803 + chosen_10804 + chosen_10805 + chosen_10806 + chosen_10807
#  + chosen_10808 + chosen_10809 + chosen_1081 + chosen_10810 + chosen_10811
#  + chosen_10812 + chosen_10813 + chosen_10814 + chosen_10815 + chosen_10816
#  + chosen_10817 + chosen_10818 + chosen_10819 + chosen_1082 + chosen_10820
#  + chosen_10821 + chosen_10822 + chosen_10823 + chosen_10824 + chosen_10825
#  + chosen_10826 + chosen_10827 + chosen_10828 + chosen_10829 + chosen_1083
#  + chosen_10830 + chosen_10831 + chosen_10832 + chosen_10833 + chosen_10834
#  + chosen_10835 + chosen_10836 + chosen_10837 + chosen_10838 + chosen_10839
#  + chosen_1084 + chosen_10840 + chosen_10841 + chosen_10842 + chosen_10843
#  + chosen_10844 + chosen_10845 + chosen_10846 + chosen_10847 + chosen_10848
#  + chosen_10849 + chosen_1085 + chosen_10850 + chosen_10851 + chosen_10852
#  + chosen_10853 + chosen_10854 + chosen_10855 + chosen_10856 + chosen_10857
#  + chosen_10858 + chosen_10859 + chosen_1086 + chosen_10860 + chosen_10861
#  + chosen_10862 + chosen_10863 + chosen_10864 + chosen_10865 + chosen_10866
#  + chosen_10867 + chosen_10868 + chosen_10869 + chosen_1087 + chosen_10870
#  + chosen_10871 + chosen_10872 + chosen_10873 + chosen_10874 + chosen_10875
#  + chosen_10876 + chosen_10877 + chosen_10878 + chosen_10879 + chosen_1088
#  + chosen_10880 + chosen_10881 + chosen_10882 + chosen_10883 + chosen_10884
#  + chosen_10885 + chosen_10886 + chosen_10887 + chosen_10888 + chosen_10889
#  + chosen_1089 + chosen_10890 + chosen_10891 + chosen_10892 + chosen_10893
#  + chosen_10894 + chosen_10895 + chosen_10896 + chosen_10897 + chosen_10898
#  + chosen_10899 + chosen_109 + chosen_1090 + chosen_10900 + chosen_10901
#  + chosen_10902 + chosen_10903 + chosen_10904 + chosen_10905 + chosen_10906
#  + chosen_10907 + chosen_10908 + chosen_10909 + chosen_1091 + chosen_10910
#  + chosen_10911 + chosen_10912 + chosen_10913 + chosen_10914 + chosen_10915
#  + chosen_10916 + chosen_10917 + chosen_10918 + chosen_10919 + chosen_1092
#  + chosen_10920 + chosen_10921 + chosen_10922 + chosen_10923 + chosen_10924
#  + chosen_10925 + chosen_10926 + chosen_10927 + chosen_10928 + chosen_10929
#  + chosen_1093 + chosen_10930 + chosen_10931 + chosen_10932 + chosen_10933
#  + chosen_10934 + chosen_10935 + chosen_10936 + chosen_10937 + chosen_10938
#  + chosen_10939 + chosen_1094 + chosen_10940 + chosen_10941 + chosen_10942
#  + chosen_10943 + chosen_10944 + chosen_10945 + chosen_10946 + chosen_10947
#  + chosen_10948 + chosen_10949 + chosen_1095 + chosen_10950 + chosen_10951
#  + chosen_10952 + chosen_10953 + chosen_10954 + chosen_10955 + chosen_10956
#  + chosen_10957 + chosen_10958 + chosen_10959 + chosen_1096 + chosen_10960
#  + chosen_10961 + chosen_10962 + chosen_10963 + chosen_10964 + chosen_10965
#  + chosen_10966 + chosen_10967 + chosen_10968 + chosen_10969 + chosen_1097
#  + chosen_10970 + chosen_10971 + chosen_10972 + chosen_10973 + chosen_10974
#  + chosen_10975 + chosen_10976 + chosen_10977 + chosen_10978 + chosen_10979
#  + chosen_1098 + chosen_10980 + chosen_10981 + chosen_10982 + chosen_10983
#  + chosen_10984 + chosen_10985 + chosen_10986 + chosen_10987 + chosen_10988
#  + chosen_10989 + chosen_1099 + chosen_10990 + chosen_10991 + chosen_10992
#  + chosen_10993 + chosen_10994 + chosen_10995 + chosen_10996 + chosen_10997
#  + chosen_10998 + chosen_10999 + chosen_11 + chosen_110 + chosen_1100
#  + chosen_11000 + chosen_11001 + chosen_11002 + chosen_11003 + chosen_11004
#  + chosen_11005 + chosen_11006 + chosen_11007 + chosen_11008 + chosen_11009
#  + chosen_1101 + chosen_11010 + chosen_11011 + chosen_11012 + chosen_11013
#  + chosen_11014 + chosen_11015 + chosen_11016 + chosen_11017 + chosen_11018
#  + chosen_11019 + chosen_1102 + chosen_11020 + chosen_11021 + chosen_11022
#  + chosen_11023 + chosen_11024 + chosen_11025 + chosen_11026 + chosen_11027
#  + chosen_11028 + chosen_11029 + chosen_1103 + chosen_11030 + chosen_11031
#  + chosen_11032 + chosen_11033 + chosen_11034 + chosen_11035 + chosen_11036
#  + chosen_11037 + chosen_11038 + chosen_11039 + chosen_1104 + chosen_11040
#  + chosen_11041 + chosen_11042 + chosen_11043 + chosen_11044 + chosen_11045
#  + chosen_11046 + chosen_11047 + chosen_11048 + chosen_11049 + chosen_1105
#  + chosen_11050 + chosen_11051 + chosen_11052 + chosen_11053 + chosen_11054
#  + chosen_11055 + chosen_11056 + chosen_11057 + chosen_11058 + chosen_11059
#  + chosen_1106 + chosen_11060 + chosen_11061 + chosen_11062 + chosen_11063
#  + chosen_11064 + chosen_11065 + chosen_11066 + chosen_11067 + chosen_11068
#  + chosen_11069 + chosen_1107 + chosen_11070 + chosen_11071 + chosen_11072
#  + chosen_11073 + chosen_11074 + chosen_11075 + chosen_11076 + chosen_11077
#  + chosen_11078 + chosen_11079 + chosen_1108 + chosen_11080 + chosen_11081
#  + chosen_11082 + chosen_11083 + chosen_11084 + chosen_11085 + chosen_11086
#  + chosen_11087 + chosen_11088 + chosen_11089 + chosen_1109 + chosen_11090
#  + chosen_11091 + chosen_11092 + chosen_11093 + chosen_11094 + chosen_11095
#  + chosen_11096 + chosen_11097 + chosen_11098 + chosen_11099 + chosen_111
#  + chosen_1110 + chosen_11100 + chosen_11101 + chosen_11102 + chosen_11103
#  + chosen_11104 + chosen_11105 + chosen_11106 + chosen_11107 + chosen_11108
#  + chosen_11109 + chosen_1111 + chosen_11110 + chosen_11111 + chosen_11112
#  + chosen_11113 + chosen_11114 + chosen_11115 + chosen_11116 + chosen_11117
#  + chosen_11118 + chosen_11119 + chosen_1112 + chosen_11120 + chosen_11121
#  + chosen_11122 + chosen_11123 + chosen_11124 + chosen_11125 + chosen_11126
#  + chosen_11127 + chosen_11128 + chosen_11129 + chosen_1113 + chosen_11130
#  + chosen_11131 + chosen_11132 + chosen_11133 + chosen_11134 + chosen_11135
#  + chosen_11136 + chosen_11137 + chosen_11138 + chosen_11139 + chosen_1114
#  + chosen_11140 + chosen_11141 + chosen_11142 + chosen_11143 + chosen_11144
#  + chosen_11145 + chosen_11146 + chosen_11147 + chosen_11148 + chosen_11149
#  + chosen_1115 + chosen_11150 + chosen_11151 + chosen_11152 + chosen_11153
#  + chosen_11154 + chosen_11155 + chosen_11156 + chosen_11157 + chosen_11158
#  + chosen_11159 + chosen_1116 + chosen_11160 + chosen_11161 + chosen_11162
#  + chosen_11163 + chosen_11164 + chosen_11165 + chosen_11166 + chosen_11167
#  + chosen_11168 + chosen_11169 + chosen_1117 + chosen_11170 + chosen_11171
#  + chosen_11172 + chosen_11173 + chosen_11174 + chosen_11175 + chosen_11176
#  + chosen_11177 + chosen_11178 + chosen_11179 + chosen_1118 + chosen_11180
#  + chosen_11181 + chosen_11182 + chosen_11183 + chosen_11184 + chosen_11185
#  + chosen_11186 + chosen_11187 + chosen_11188 + chosen_11189 + chosen_1119
#  + chosen_11190 + chosen_11191 + chosen_11192 + chosen_11193 + chosen_11194
#  + chosen_11195 + chosen_11196 + chosen_11197 + chosen_11198 + chosen_11199
#  + chosen_112 + chosen_1120 + chosen_11200 + chosen_11201 + chosen_11202
#  + chosen_11203 + chosen_11204 + chosen_11205 + chosen_11206 + chosen_11207
#  + chosen_11208 + chosen_11209 + chosen_1121 + chosen_11210 + chosen_11211
#  + chosen_11212 + chosen_11213 + chosen_11214 + chosen_11215 + chosen_11216
#  + chosen_11217 + chosen_11218 + chosen_11219 + chosen_1122 + chosen_11220
#  + chosen_11221 + chosen_11222 + chosen_11223 + chosen_11224 + chosen_11225
#  + chosen_11226 + chosen_11227 + chosen_11228 + chosen_11229 + chosen_1123
#  + chosen_11230 + chosen_11231 + chosen_11232 + chosen_11233 + chosen_11234
#  + chosen_11235 + chosen_11236 + chosen_11237 + chosen_11238 + chosen_11239
#  + chosen_1124 + chosen_11240 + chosen_11241 + chosen_11242 + chosen_11243
#  + chosen_11244 + chosen_11245 + chosen_11246 + chosen_11247 + chosen_11248
#  + chosen_11249 + chosen_1125 + chosen_11250 + chosen_11251 + chosen_11252
#  + chosen_11253 + chosen_11254 + chosen_11255 + chosen_11256 + chosen_11257
#  + chosen_11258 + chosen_11259 + chosen_1126 + chosen_11260 + chosen_11261
#  + chosen_11262 + chosen_11263 + chosen_11264 + chosen_11265 + chosen_11266
#  + chosen_11267 + chosen_11268 + chosen_11269 + chosen_1127 + chosen_11270
#  + chosen_11271 + chosen_11272 + chosen_11273 + chosen_11274 + chosen_11275
#  + chosen_11276 + chosen_11277 + chosen_11278 + chosen_11279 + chosen_1128
#  + chosen_11280 + chosen_11281 + chosen_11282 + chosen_11283 + chosen_11284
#  + chosen_11285 + chosen_11286 + chosen_11287 + chosen_11288 + chosen_11289
#  + chosen_1129 + chosen_11290 + chosen_11291 + chosen_11292 + chosen_11293
#  + chosen_11294 + chosen_11295 + chosen_11296 + chosen_11297 + chosen_11298
#  + chosen_11299 + chosen_113 + chosen_1130 + chosen_11300 + chosen_11301
#  + chosen_11302 + chosen_11303 + chosen_11304 + chosen_11305 + chosen_11306
#  + chosen_11307 + chosen_11308 + chosen_11309 + chosen_1131 + chosen_11310
#  + chosen_11311 + chosen_11312 + chosen_11313 + chosen_11314 + chosen_11315
#  + chosen_11316 + chosen_11317 + chosen_11318 + chosen_11319 + chosen_1132
#  + chosen_11320 + chosen_11321 + chosen_11322 + chosen_11323 + chosen_11324
#  + chosen_11325 + chosen_11326 + chosen_11327 + chosen_11328 + chosen_11329
#  + chosen_1133 + chosen_11330 + chosen_11331 + chosen_11332 + chosen_11333
#  + chosen_11334 + chosen_11335 + chosen_11336 + chosen_11337 + chosen_11338
#  + chosen_11339 + chosen_1134 + chosen_11340 + chosen_11341 + chosen_11342
#  + chosen_11343 + chosen_11344 + chosen_11345 + chosen_11346 + chosen_11347
#  + chosen_11348 + chosen_11349 + chosen_1135 + chosen_11350 + chosen_11351
#  + chosen_11352 + chosen_11353 + chosen_11354 + chosen_11355 + chosen_11356
#  + chosen_11357 + chosen_11358 + chosen_11359 + chosen_1136 + chosen_11360
#  + chosen_11361 + chosen_11362 + chosen_11363 + chosen_11364 + chosen_11365
#  + chosen_11366 + chosen_11367 + chosen_11368 + chosen_11369 + chosen_1137
#  + chosen_11370 + chosen_11371 + chosen_11372 + chosen_11373 + chosen_11374
#  + chosen_11375 + chosen_11376 + chosen_11377 + chosen_11378 + chosen_11379
#  + chosen_1138 + chosen_11380 + chosen_11381 + chosen_11382 + chosen_11383
#  + chosen_11384 + chosen_11385 + chosen_11386 + chosen_11387 + chosen_11388
#  + chosen_11389 + chosen_1139 + chosen_11390 + chosen_11391 + chosen_11392
#  + chosen_11393 + chosen_11394 + chosen_11395 + chosen_11396 + chosen_11397
#  + chosen_11398 + chosen_11399 + chosen_114 + chosen_1140 + chosen_11400
#  + chosen_11401 + chosen_11402 + chosen_11403 + chosen_11404 + chosen_11405
#  + chosen_11406 + chosen_11407 + chosen_11408 + chosen_11409 + chosen_1141
#  + chosen_11410 + chosen_11411 + chosen_11412 + chosen_11413 + chosen_11414
#  + chosen_11415 + chosen_11416 + chosen_11417 + chosen_11418 + chosen_11419
#  + chosen_1142 + chosen_11420 + chosen_11421 + chosen_11422 + chosen_11423
#  + chosen_11424 + chosen_11425 + chosen_11426 + chosen_11427 + chosen_11428
#  + chosen_11429 + chosen_1143 + chosen_11430 + chosen_11431 + chosen_11432
#  + chosen_11433 + chosen_11434 + chosen_11435 + chosen_11436 + chosen_11437
#  + chosen_11438 + chosen_11439 + chosen_1144 + chosen_11440 + chosen_11441
#  + chosen_11442 + chosen_11443 + chosen_11444 + chosen_11445 + chosen_11446
#  + chosen_11447 + chosen_11448 + chosen_11449 + chosen_1145 + chosen_11450
#  + chosen_11451 + chosen_11452 + chosen_11453 + chosen_11454 + chosen_11455
#  + chosen_11456 + chosen_11457 + chosen_11458 + chosen_11459 + chosen_1146
#  + chosen_11460 + chosen_11461 + chosen_11462 + chosen_11463 + chosen_11464
#  + chosen_11465 + chosen_11466 + chosen_11467 + chosen_11468 + chosen_11469
#  + chosen_1147 + chosen_11470 + chosen_11471 + chosen_11472 + chosen_11473
#  + chosen_11474 + chosen_11475 + chosen_11476 + chosen_11477 + chosen_11478
#  + chosen_11479 + chosen_1148 + chosen_11480 + chosen_11481 + chosen_11482
#  + chosen_11483 + chosen_11484 + chosen_11485 + chosen_11486 + chosen_11487
#  + chosen_11488 + chosen_11489 + chosen_1149 + chosen_11490 + chosen_11491
#  + chosen_11492 + chosen_11493 + chosen_11494 + chosen_11495 + chosen_11496
#  + chosen_11497 + chosen_11498 + chosen_11499 + chosen_115 + chosen_1150
#  + chosen_11500 + chosen_11501 + chosen_11502 + chosen_11503 + chosen_11504
#  + chosen_11505 + chosen_11506 + chosen_11507 + chosen_11508 + chosen_11509
#  + chosen_1151 + chosen_11510 + chosen_11511 + chosen_11512 + chosen_11513
#  + chosen_11514 + chosen_11515 + chosen_11516 + chosen_11517 + chosen_11518
#  + chosen_11519 + chosen_1152 + chosen_11520 + chosen_11521 + chosen_11522
#  + chosen_11523 + chosen_11524 + chosen_11525 + chosen_11526 + chosen_11527
#  + chosen_11528 + chosen_11529 + chosen_1153 + chosen_11530 + chosen_11531
#  + chosen_11532 + chosen_11533 + chosen_11534 + chosen_11535 + chosen_11536
#  + chosen_11537 + chosen_11538 + chosen_11539 + chosen_1154 + chosen_11540
#  + chosen_11541 + chosen_11542 + chosen_11543 + chosen_11544 + chosen_11545
#  + chosen_11546 + chosen_11547 + chosen_11548 + chosen_11549 + chosen_1155
#  + chosen_11550 + chosen_11551 + chosen_11552 + chosen_11553 + chosen_11554
#  + chosen_11555 + chosen_11556 + chosen_11557 + chosen_11558 + chosen_11559
#  + chosen_1156 + chosen_11560 + chosen_11561 + chosen_11562 + chosen_11563
#  + chosen_11564 + chosen_11565 + chosen_11566 + chosen_11567 + chosen_11568
#  + chosen_11569 + chosen_1157 + chosen_11570 + chosen_11571 + chosen_11572
#  + chosen_11573 + chosen_11574 + chosen_11575 + chosen_11576 + chosen_11577
#  + chosen_11578 + chosen_11579 + chosen_1158 + chosen_11580 + chosen_11581
#  + chosen_11582 + chosen_11583 + chosen_11584 + chosen_11585 + chosen_11586
#  + chosen_11587 + chosen_11588 + chosen_11589 + chosen_1159 + chosen_11590
#  + chosen_11591 + chosen_11592 + chosen_11593 + chosen_11594 + chosen_11595
#  + chosen_11596 + chosen_11597 + chosen_11598 + chosen_11599 + chosen_116
#  + chosen_1160 + chosen_11600 + chosen_11601 + chosen_11602 + chosen_11603
#  + chosen_11604 + chosen_11605 + chosen_11606 + chosen_11607 + chosen_11608
#  + chosen_11609 + chosen_1161 + chosen_11610 + chosen_11611 + chosen_11612
#  + chosen_11613 + chosen_11614 + chosen_11615 + chosen_11616 + chosen_11617
#  + chosen_11618 + chosen_11619 + chosen_1162 + chosen_11620 + chosen_11621
#  + chosen_11622 + chosen_11623 + chosen_11624 + chosen_11625 + chosen_11626
#  + chosen_11627 + chosen_11628 + chosen_11629 + chosen_1163 + chosen_11630
#  + chosen_11631 + chosen_11632 + chosen_11633 + chosen_11634 + chosen_11635
#  + chosen_11636 + chosen_11637 + chosen_11638 + chosen_11639 + chosen_1164
#  + chosen_11640 + chosen_11641 + chosen_11642 + chosen_11643 + chosen_11644
#  + chosen_11645 + chosen_11646 + chosen_11647 + chosen_11648 + chosen_11649
#  + chosen_1165 + chosen_11650 + chosen_11651 + chosen_11652 + chosen_11653
#  + chosen_11654 + chosen_11655 + chosen_11656 + chosen_11657 + chosen_11658
#  + chosen_11659 + chosen_1166 + chosen_11660 + chosen_11661 + chosen_11662
#  + chosen_11663 + chosen_11664 + chosen_11665 + chosen_11666 + chosen_11667
#  + chosen_11668 + chosen_11669 + chosen_1167 + chosen_11670 + chosen_11671
#  + chosen_11672 + chosen_11673 + chosen_11674 + chosen_11675 + chosen_11676
#  + chosen_11677 + chosen_11678 + chosen_11679 + chosen_1168 + chosen_11680
#  + chosen_11681 + chosen_11682 + chosen_11683 + chosen_11684 + chosen_11685
#  + chosen_11686 + chosen_11687 + chosen_11688 + chosen_11689 + chosen_1169
#  + chosen_11690 + chosen_11691 + chosen_11692 + chosen_11693 + chosen_11694
#  + chosen_11695 + chosen_11696 + chosen_11697 + chosen_11698 + chosen_11699
#  + chosen_117 + chosen_1170 + chosen_11700 + chosen_11701 + chosen_11702
#  + chosen_11703 + chosen_11704 + chosen_11705 + chosen_11706 + chosen_11707
#  + chosen_11708 + chosen_11709 + chosen_1171 + chosen_11710 + chosen_11711
#  + chosen_11712 + chosen_11713 + chosen_11714 + chosen_11715 + chosen_11716
#  + chosen_11717 + chosen_11718 + chosen_11719 + chosen_1172 + chosen_11720
#  + chosen_11721 + chosen_11722 + chosen_11723 + chosen_11724 + chosen_11725
#  + chosen_11726 + chosen_11727 + chosen_11728 + chosen_11729 + chosen_1173
#  + chosen_11730 + chosen_11731 + chosen_11732 + chosen_11733 + chosen_11734
#  + chosen_11735 + chosen_11736 + chosen_11737 + chosen_11738 + chosen_11739
#  + chosen_1174 + chosen_11740 + chosen_11741 + chosen_11742 + chosen_11743
#  + chosen_11744 + chosen_11745 + chosen_11746 + chosen_11747 + chosen_11748
#  + chosen_11749 + chosen_1175 + chosen_11750 + chosen_11751 + chosen_11752
#  + chosen_11753 + chosen_11754 + chosen_11755 + chosen_11756 + chosen_11757
#  + chosen_11758 + chosen_11759 + chosen_1176 + chosen_11760 + chosen_11761
#  + chosen_11762 + chosen_11763 + chosen_11764 + chosen_11765 + chosen_11766
#  + chosen_11767 + chosen_11768 + chosen_11769 + chosen_1177 + chosen_11770
#  + chosen_11771 + chosen_11772 + chosen_11773 + chosen_11774 + chosen_11775
#  + chosen_11776 + chosen_11777 + chosen_11778 + chosen_11779 + chosen_1178
#  + chosen_11780 + chosen_11781 + chosen_11782 + chosen_11783 + chosen_11784
#  + chosen_11785 + chosen_11786 + chosen_11787 + chosen_11788 + chosen_11789
#  + chosen_1179 + chosen_11790 + chosen_11791 + chosen_11792 + chosen_11793
#  + chosen_11794 + chosen_11795 + chosen_11796 + chosen_11797 + chosen_11798
#  + chosen_11799 + chosen_118 + chosen_1180 + chosen_11800 + chosen_11801
#  + chosen_11802 + chosen_11803 + chosen_11804 + chosen_11805 + chosen_11806
#  + chosen_11807 + chosen_11808 + chosen_11809 + chosen_1181 + chosen_11810
#  + chosen_11811 + chosen_11812 + chosen_11813 + chosen_11814 + chosen_11815
#  + chosen_11816 + chosen_11817 + chosen_11818 + chosen_11819 + chosen_1182
#  + chosen_11820 + chosen_11821 + chosen_11822 + chosen_11823 + chosen_11824
#  + chosen_11825 + chosen_11826 + chosen_11827 + chosen_11828 + chosen_11829
#  + chosen_1183 + chosen_11830 + chosen_11831 + chosen_11832 + chosen_11833
#  + chosen_11834 + chosen_11835 + chosen_11836 + chosen_11837 + chosen_11838
#  + chosen_11839 + chosen_1184 + chosen_11840 + chosen_11841 + chosen_11842
#  + chosen_11843 + chosen_11844 + chosen_11845 + chosen_11846 + chosen_11847
#  + chosen_11848 + chosen_11849 + chosen_1185 + chosen_11850 + chosen_11851
#  + chosen_11852 + chosen_11853 + chosen_11854 + chosen_11855 + chosen_11856
#  + chosen_11857 + chosen_11858 + chosen_11859 + chosen_1186 + chosen_11860
#  + chosen_11861 + chosen_11862 + chosen_11863 + chosen_11864 + chosen_11865
#  + chosen_11866 + chosen_11867 + chosen_11868 + chosen_11869 + chosen_1187
#  + chosen_11870 + chosen_11871 + chosen_11872 + chosen_11873 + chosen_11874
#  + chosen_11875 + chosen_11876 + chosen_11877 + chosen_11878 + chosen_11879
#  + chosen_1188 + chosen_11880 + chosen_11881 + chosen_11882 + chosen_11883
#  + chosen_11884 + chosen_11885 + chosen_11886 + chosen_11887 + chosen_11888
#  + chosen_11889 + chosen_1189 + chosen_11890 + chosen_11891 + chosen_11892
#  + chosen_11893 + chosen_11894 + chosen_11895 + chosen_11896 + chosen_11897
#  + chosen_11898 + chosen_11899 + chosen_119 + chosen_1190 + chosen_11900
#  + chosen_11901 + chosen_11902 + chosen_11903 + chosen_11904 + chosen_11905
#  + chosen_11906 + chosen_11907 + chosen_11908 + chosen_11909 + chosen_1191
#  + chosen_11910 + chosen_11911 + chosen_11912 + chosen_11913 + chosen_11914
#  + chosen_11915 + chosen_11916 + chosen_11917 + chosen_11918 + chosen_11919
#  + chosen_1192 + chosen_11920 + chosen_11921 + chosen_11922 + chosen_11923
#  + chosen_11924 + chosen_11925 + chosen_11926 + chosen_11927 + chosen_11928
#  + chosen_11929 + chosen_1193 + chosen_11930 + chosen_11931 + chosen_11932
#  + chosen_11933 + chosen_11934 + chosen_11935 + chosen_11936 + chosen_11937
#  + chosen_11938 + chosen_11939 + chosen_1194 + chosen_11940 + chosen_11941
#  + chosen_11942 + chosen_11943 + chosen_11944 + chosen_11945 + chosen_11946
#  + chosen_11947 + chosen_11948 + chosen_11949 + chosen_1195 + chosen_11950
#  + chosen_11951 + chosen_11952 + chosen_11953 + chosen_11954 + chosen_11955
#  + chosen_11956 + chosen_11957 + chosen_11958 + chosen_11959 + chosen_1196
#  + chosen_11960 + chosen_11961 + chosen_11962 + chosen_11963 + chosen_11964
#  + chosen_11965 + chosen_11966 + chosen_11967 + chosen_11968 + chosen_11969
#  + chosen_1197 + chosen_11970 + chosen_11971 + chosen_11972 + chosen_11973
#  + chosen_11974 + chosen_11975 + chosen_11976 + chosen_11977 + chosen_11978
#  + chosen_11979 + chosen_1198 + chosen_11980 + chosen_11981 + chosen_11982
#  + chosen_11983 + chosen_11984 + chosen_11985 + chosen_11986 + chosen_11987
#  + chosen_11988 + chosen_11989 + chosen_1199 + chosen_11990 + chosen_11991
#  + chosen_11992 + chosen_11993 + chosen_11994 + chosen_11995 + chosen_11996
#  + chosen_11997 + chosen_11998 + chosen_11999 + chosen_12 + chosen_120
#  + chosen_1200 + chosen_12000 + chosen_12001 + chosen_12002 + chosen_12003
#  + chosen_12004 + chosen_12005 + chosen_12006 + chosen_12007 + chosen_12008
#  + chosen_12009 + chosen_1201 + chosen_12010 + chosen_12011 + chosen_12012
#  + chosen_12013 + chosen_12014 + chosen_12015 + chosen_12016 + chosen_12017
#  + chosen_12018 + chosen_12019 + chosen_1202 + chosen_12020 + chosen_12021
#  + chosen_12022 + chosen_12023 + chosen_12024 + chosen_12025 + chosen_12026
#  + chosen_12027 + chosen_12028 + chosen_12029 + chosen_1203 + chosen_12030
#  + chosen_12031 + chosen_12032 + chosen_12033 + chosen_12034 + chosen_12035
#  + chosen_12036 + chosen_12037 + chosen_12038 + chosen_12039 + chosen_1204
#  + chosen_12040 + chosen_12041 + chosen_12042 + chosen_12043 + chosen_12044
#  + chosen_12045 + chosen_12046 + chosen_12047 + chosen_12048 + chosen_12049
#  + chosen_1205 + chosen_12050 + chosen_12051 + chosen_12052 + chosen_12053
#  + chosen_12054 + chosen_12055 + chosen_12056 + chosen_12057 + chosen_12058
#  + chosen_12059 + chosen_1206 + chosen_12060 + chosen_12061 + chosen_12062
#  + chosen_12063 + chosen_12064 + chosen_12065 + chosen_12066 + chosen_12067
#  + chosen_12068 + chosen_12069 + chosen_1207 + chosen_12070 + chosen_12071
#  + chosen_12072 + chosen_12073 + chosen_12074 + chosen_12075 + chosen_12076
#  + chosen_12077 + chosen_12078 + chosen_12079 + chosen_1208 + chosen_12080
#  + chosen_12081 + chosen_12082 + chosen_12083 + chosen_12084 + chosen_12085
#  + chosen_12086 + chosen_12087 + chosen_12088 + chosen_12089 + chosen_1209
#  + chosen_12090 + chosen_12091 + chosen_12092 + chosen_12093 + chosen_12094
#  + chosen_12095 + chosen_12096 + chosen_12097 + chosen_12098 + chosen_12099
#  + chosen_121 + chosen_1210 + chosen_12100 + chosen_12101 + chosen_12102
#  + chosen_12103 + chosen_12104 + chosen_12105 + chosen_12106 + chosen_12107
#  + chosen_12108 + chosen_12109 + chosen_1211 + chosen_12110 + chosen_12111
#  + chosen_12112 + chosen_12113 + chosen_12114 + chosen_12115 + chosen_12116
#  + chosen_12117 + chosen_12118 + chosen_12119 + chosen_1212 + chosen_12120
#  + chosen_12121 + chosen_12122 + chosen_12123 + chosen_12124 + chosen_12125
#  + chosen_12126 + chosen_12127 + chosen_12128 + chosen_12129 + chosen_1213
#  + chosen_12130 + chosen_12131 + chosen_12132 + chosen_12133 + chosen_12134
#  + chosen_12135 + chosen_12136 + chosen_12137 + chosen_12138 + chosen_12139
#  + chosen_1214 + chosen_12140 + chosen_12141 + chosen_12142 + chosen_12143
#  + chosen_12144 + chosen_12145 + chosen_12146 + chosen_12147 + chosen_12148
#  + chosen_12149 + chosen_1215 + chosen_12150 + chosen_12151 + chosen_12152
#  + chosen_12153 + chosen_12154 + chosen_12155 + chosen_12156 + chosen_12157
#  + chosen_12158 + chosen_12159 + chosen_1216 + chosen_12160 + chosen_12161
#  + chosen_12162 + chosen_12163 + chosen_12164 + chosen_12165 + chosen_12166
#  + chosen_12167 + chosen_12168 + chosen_12169 + chosen_1217 + chosen_12170
#  + chosen_12171 + chosen_12172 + chosen_12173 + chosen_12174 + chosen_12175
#  + chosen_12176 + chosen_12177 + chosen_12178 + chosen_12179 + chosen_1218
#  + chosen_12180 + chosen_12181 + chosen_12182 + chosen_12183 + chosen_12184
#  + chosen_12185 + chosen_12186 + chosen_12187 + chosen_12188 + chosen_12189
#  + chosen_1219 + chosen_12190 + chosen_12191 + chosen_12192 + chosen_12193
#  + chosen_12194 + chosen_12195 + chosen_12196 + chosen_12197 + chosen_12198
#  + chosen_12199 + chosen_122 + chosen_1220 + chosen_12200 + chosen_12201
#  + chosen_12202 + chosen_12203 + chosen_12204 + chosen_12205 + chosen_12206
#  + chosen_12207 + chosen_12208 + chosen_12209 + chosen_1221 + chosen_12210
#  + chosen_12211 + chosen_12212 + chosen_12213 + chosen_12214 + chosen_12215
#  + chosen_12216 + chosen_12217 + chosen_12218 + chosen_12219 + chosen_1222
#  + chosen_12220 + chosen_12221 + chosen_12222 + chosen_12223 + chosen_12224
#  + chosen_12225 + chosen_12226 + chosen_12227 + chosen_12228 + chosen_12229
#  + chosen_1223 + chosen_12230 + chosen_12231 + chosen_12232 + chosen_12233
#  + chosen_12234 + chosen_12235 + chosen_12236 + chosen_12237 + chosen_12238
#  + chosen_12239 + chosen_1224 + chosen_12240 + chosen_12241 + chosen_12242
#  + chosen_12243 + chosen_12244 + chosen_12245 + chosen_12246 + chosen_12247
#  + chosen_12248 + chosen_12249 + chosen_1225 + chosen_12250 + chosen_12251
#  + chosen_12252 + chosen_12253 + chosen_12254 + chosen_12255 + chosen_12256
#  + chosen_12257 + chosen_12258 + chosen_12259 + chosen_1226 + chosen_12260
#  + chosen_12261 + chosen_12262 + chosen_12263 + chosen_12264 + chosen_12265
#  + chosen_12266 + chosen_12267 + chosen_12268 + chosen_12269 + chosen_1227
#  + chosen_12270 + chosen_12271 + chosen_12272 + chosen_12273 + chosen_12274
#  + chosen_12275 + chosen_12276 + chosen_12277 + chosen_12278 + chosen_12279
#  + chosen_1228 + chosen_12280 + chosen_12281 + chosen_12282 + chosen_12283
#  + chosen_12284 + chosen_12285 + chosen_12286 + chosen_12287 + chosen_12288
#  + chosen_12289 + chosen_1229 + chosen_12290 + chosen_12291 + chosen_12292
#  + chosen_12293 + chosen_12294 + chosen_12295 + chosen_12296 + chosen_12297
#  + chosen_12298 + chosen_12299 + chosen_123 + chosen_1230 + chosen_12300
#  + chosen_12301 + chosen_12302 + chosen_12303 + chosen_12304 + chosen_12305
#  + chosen_12306 + chosen_12307 + chosen_12308 + chosen_12309 + chosen_1231
#  + chosen_12310 + chosen_12311 + chosen_12312 + chosen_12313 + chosen_12314
#  + chosen_12315 + chosen_12316 + chosen_12317 + chosen_12318 + chosen_12319
#  + chosen_1232 + chosen_12320 + chosen_12321 + chosen_12322 + chosen_12323
#  + chosen_12324 + chosen_12325 + chosen_12326 + chosen_12327 + chosen_12328
#  + chosen_12329 + chosen_1233 + chosen_12330 + chosen_12331 + chosen_12332
#  + chosen_12333 + chosen_12334 + chosen_12335 + chosen_12336 + chosen_12337
#  + chosen_12338 + chosen_12339 + chosen_1234 + chosen_12340 + chosen_12341
#  + chosen_12342 + chosen_12343 + chosen_12344 + chosen_12345 + chosen_12346
#  + chosen_12347 + chosen_12348 + chosen_1235 + chosen_1236 + chosen_1237
#  + chosen_1238 + chosen_1239 + chosen_124 + chosen_1240 + chosen_1241
#  + chosen_1242 + chosen_1243 + chosen_1244 + chosen_1245 + chosen_1246
#  + chosen_1247 + chosen_1248 + chosen_1249 + chosen_125 + chosen_1250
#  + chosen_1251 + chosen_1252 + chosen_1253 + chosen_1254 + chosen_1255
#  + chosen_1256 + chosen_1257 + chosen_1258 + chosen_1259 + chosen_126
#  + chosen_1260 + chosen_1261 + chosen_1262 + chosen_1263 + chosen_1264
#  + chosen_1265 + chosen_1266 + chosen_1267 + chosen_1268 + chosen_1269
#  + chosen_127 + chosen_1270 + chosen_1271 + chosen_1272 + chosen_1273
#  + chosen_1274 + chosen_1275 + chosen_1276 + chosen_1277 + chosen_1278
#  + chosen_1279 + chosen_128 + chosen_1280 + chosen_1281 + chosen_1282
#  + chosen_1283 + chosen_1284 + chosen_1285 + chosen_1286 + chosen_1287
#  + chosen_1288 + chosen_1289 + chosen_129 + chosen_1290 + chosen_1291
#  + chosen_1292 + chosen_1293 + chosen_1294 + chosen_1295 + chosen_1296
#  + chosen_1297 + chosen_1298 + chosen_1299 + chosen_13 + chosen_130
#  + chosen_1300 + chosen_1301 + chosen_1302 + chosen_1303 + chosen_1304
#  + chosen_1305 + chosen_1306 + chosen_1307 + chosen_1308 + chosen_1309
#  + chosen_131 + chosen_1310 + chosen_1311 + chosen_1312 + chosen_1313
#  + chosen_1314 + chosen_1315 + chosen_1316 + chosen_1317 + chosen_1318
#  + chosen_1319 + chosen_132 + chosen_1320 + chosen_1321 + chosen_1322
#  + chosen_1323 + chosen_1324 + chosen_1325 + chosen_1326 + chosen_1327
#  + chosen_1328 + chosen_1329 + chosen_133 + chosen_1330 + chosen_1331
#  + chosen_1332 + chosen_1333 + chosen_1334 + chosen_1335 + chosen_1336
#  + chosen_1337 + chosen_1338 + chosen_1339 + chosen_134 + chosen_1340
#  + chosen_1341 + chosen_1342 + chosen_1343 + chosen_1344 + chosen_1345
#  + chosen_1346 + chosen_1347 + chosen_1348 + chosen_1349 + chosen_135
#  + chosen_1350 + chosen_1351 + chosen_1352 + chosen_1353 + chosen_1354
#  + chosen_1355 + chosen_1356 + chosen_1357 + chosen_1358 + chosen_1359
#  + chosen_136 + chosen_1360 + chosen_1361 + chosen_1362 + chosen_1363
#  + chosen_1364 + chosen_1365 + chosen_1366 + chosen_1367 + chosen_1368
#  + chosen_1369 + chosen_137 + chosen_1370 + chosen_1371 + chosen_1372
#  + chosen_1373 + chosen_1374 + chosen_1375 + chosen_1376 + chosen_1377
#  + chosen_1378 + chosen_1379 + chosen_138 + chosen_1380 + chosen_1381
#  + chosen_1382 + chosen_1383 + chosen_1384 + chosen_1385 + chosen_1386
#  + chosen_1387 + chosen_1388 + chosen_1389 + chosen_139 + chosen_1390
#  + chosen_1391 + chosen_1392 + chosen_1393 + chosen_1394 + chosen_1395
#  + chosen_1396 + chosen_1397 + chosen_1398 + chosen_1399 + chosen_14
#  + chosen_140 + chosen_1400 + chosen_1401 + chosen_1402 + chosen_1403
#  + chosen_1404 + chosen_1405 + chosen_1406 + chosen_1407 + chosen_1408
#  + chosen_1409 + chosen_141 + chosen_1410 + chosen_1411 + chosen_1412
#  + chosen_1413 + chosen_1414 + chosen_1415 + chosen_1416 + chosen_1417
#  + chosen_1418 + chosen_1419 + chosen_142 + chosen_1420 + chosen_1421
#  + chosen_1422 + chosen_1423 + chosen_1424 + chosen_1425 + chosen_1426
#  + chosen_1427 + chosen_1428 + chosen_1429 + chosen_143 + chosen_1430
#  + chosen_1431 + chosen_1432 + chosen_1433 + chosen_1434 + chosen_1435
#  + chosen_1436 + chosen_1437 + chosen_1438 + chosen_1439 + chosen_144
#  + chosen_1440 + chosen_1441 + chosen_1442 + chosen_1443 + chosen_1444
#  + chosen_1445 + chosen_1446 + chosen_1447 + chosen_1448 + chosen_1449
#  + chosen_145 + chosen_1450 + chosen_1451 + chosen_1452 + chosen_1453
#  + chosen_1454 + chosen_1455 + chosen_1456 + chosen_1457 + chosen_1458
#  + chosen_1459 + chosen_146 + chosen_1460 + chosen_1461 + chosen_1462
#  + chosen_1463 + chosen_1464 + chosen_1465 + chosen_1466 + chosen_1467
#  + chosen_1468 + chosen_1469 + chosen_147 + chosen_1470 + chosen_1471
#  + chosen_1472 + chosen_1473 + chosen_1474 + chosen_1475 + chosen_1476
#  + chosen_1477 + chosen_1478 + chosen_1479 + chosen_148 + chosen_1480
#  + chosen_1481 + chosen_1482 + chosen_1483 + chosen_1484 + chosen_1485
#  + chosen_1486 + chosen_1487 + chosen_1488 + chosen_1489 + chosen_149
#  + chosen_1490 + chosen_1491 + chosen_1492 + chosen_1493 + chosen_1494
#  + chosen_1495 + chosen_1496 + chosen_1497 + chosen_1498 + chosen_1499
#  + chosen_15 + chosen_150 + chosen_1500 + chosen_1501 + chosen_1502
#  + chosen_1503 + chosen_1504 + chosen_1505 + chosen_1506 + chosen_1507
#  + chosen_1508 + chosen_1509 + chosen_151 + chosen_1510 + chosen_1511
#  + chosen_1512 + chosen_1513 + chosen_1514 + chosen_1515 + chosen_1516
#  + chosen_1517 + chosen_1518 + chosen_1519 + chosen_152 + chosen_1520
# ...
# 0 <= chosen_9517 <= 1 Integer
# 0 <= chosen_9518 <= 1 Integer
# 0 <= chosen_9519 <= 1 Integer
# 0 <= chosen_952 <= 1 Integer
# 0 <= chosen_9520 <= 1 Integer
# 0 <= chosen_9521 <= 1 Integer
# 0 <= chosen_9522 <= 1 Integer
# 0 <= chosen_9523 <= 1 Integer
# 0 <= chosen_9524 <= 1 Integer
# 0 <= chosen_9525 <= 1 Integer
# 0 <= chosen_9526 <= 1 Integer
# 0 <= chosen_9527 <= 1 Integer
# 0 <= chosen_9528 <= 1 Integer
# 0 <= chosen_9529 <= 1 Integer
# 0 <= chosen_953 <= 1 Integer
# 0 <= chosen_9530 <= 1 Integer
# 0 <= chosen_9531 <= 1 Integer
# 0 <= chosen_9532 <= 1 Integer
# 0 <= chosen_9533 <= 1 Integer
# 0 <= chosen_9534 <= 1 Integer
# 0 <= chosen_9535 <= 1 Integer
# 0 <= chosen_9536 <= 1 Integer
# 0 <= chosen_9537 <= 1 Integer
# 0 <= chosen_9538 <= 1 Integer
# 0 <= chosen_9539 <= 1 Integer
# 0 <= chosen_954 <= 1 Integer
# 0 <= chosen_9540 <= 1 Integer
# 0 <= chosen_9541 <= 1 Integer
# 0 <= chosen_9542 <= 1 Integer
# 0 <= chosen_9543 <= 1 Integer
# 0 <= chosen_9544 <= 1 Integer
# 0 <= chosen_9545 <= 1 Integer
# 0 <= chosen_9546 <= 1 Integer
# 0 <= chosen_9547 <= 1 Integer
# 0 <= chosen_9548 <= 1 Integer
# 0 <= chosen_9549 <= 1 Integer
# 0 <= chosen_955 <= 1 Integer
# 0 <= chosen_9550 <= 1 Integer
# 0 <= chosen_9551 <= 1 Integer
# 0 <= chosen_9552 <= 1 Integer
# 0 <= chosen_9553 <= 1 Integer
# 0 <= chosen_9554 <= 1 Integer
# 0 <= chosen_9555 <= 1 Integer
# 0 <= chosen_9556 <= 1 Integer
# 0 <= chosen_9557 <= 1 Integer
# 0 <= chosen_9558 <= 1 Integer
# 0 <= chosen_9559 <= 1 Integer
# 0 <= chosen_956 <= 1 Integer
# 0 <= chosen_9560 <= 1 Integer
# 0 <= chosen_9561 <= 1 Integer
# 0 <= chosen_9562 <= 1 Integer
# 0 <= chosen_9563 <= 1 Integer
# 0 <= chosen_9564 <= 1 Integer
# 0 <= chosen_9565 <= 1 Integer
# 0 <= chosen_9566 <= 1 Integer
# 0 <= chosen_9567 <= 1 Integer
# 0 <= chosen_9568 <= 1 Integer
# 0 <= chosen_9569 <= 1 Integer
# 0 <= chosen_957 <= 1 Integer
# 0 <= chosen_9570 <= 1 Integer
# 0 <= chosen_9571 <= 1 Integer
# 0 <= chosen_9572 <= 1 Integer
# 0 <= chosen_9573 <= 1 Integer
# 0 <= chosen_9574 <= 1 Integer
# 0 <= chosen_9575 <= 1 Integer
# 0 <= chosen_9576 <= 1 Integer
# 0 <= chosen_9577 <= 1 Integer
# 0 <= chosen_9578 <= 1 Integer
# 0 <= chosen_9579 <= 1 Integer
# 0 <= chosen_958 <= 1 Integer
# 0 <= chosen_9580 <= 1 Integer
# 0 <= chosen_9581 <= 1 Integer
# 0 <= chosen_9582 <= 1 Integer
# 0 <= chosen_9583 <= 1 Integer
# 0 <= chosen_9584 <= 1 Integer
# 0 <= chosen_9585 <= 1 Integer
# 0 <= chosen_9586 <= 1 Integer
# 0 <= chosen_9587 <= 1 Integer
# 0 <= chosen_9588 <= 1 Integer
# 0 <= chosen_9589 <= 1 Integer
# 0 <= chosen_959 <= 1 Integer
# 0 <= chosen_9590 <= 1 Integer
# 0 <= chosen_9591 <= 1 Integer
# 0 <= chosen_9592 <= 1 Integer
# 0 <= chosen_9593 <= 1 Integer
# 0 <= chosen_9594 <= 1 Integer
# 0 <= chosen_9595 <= 1 Integer
# 0 <= chosen_9596 <= 1 Integer
# 0 <= chosen_9597 <= 1 Integer
# 0 <= chosen_9598 <= 1 Integer
# 0 <= chosen_9599 <= 1 Integer
# 0 <= chosen_96 <= 1 Integer
# 0 <= chosen_960 <= 1 Integer
# 0 <= chosen_9600 <= 1 Integer
# 0 <= chosen_9601 <= 1 Integer
# 0 <= chosen_9602 <= 1 Integer
# 0 <= chosen_9603 <= 1 Integer
# 0 <= chosen_9604 <= 1 Integer
# 0 <= chosen_9605 <= 1 Integer
# 0 <= chosen_9606 <= 1 Integer
# 0 <= chosen_9607 <= 1 Integer
# 0 <= chosen_9608 <= 1 Integer
# 0 <= chosen_9609 <= 1 Integer
# 0 <= chosen_961 <= 1 Integer
# 0 <= chosen_9610 <= 1 Integer
# 0 <= chosen_9611 <= 1 Integer
# 0 <= chosen_9612 <= 1 Integer
# 0 <= chosen_9613 <= 1 Integer
# 0 <= chosen_9614 <= 1 Integer
# 0 <= chosen_9615 <= 1 Integer
# 0 <= chosen_9616 <= 1 Integer
# 0 <= chosen_9617 <= 1 Integer
# 0 <= chosen_9618 <= 1 Integer
# 0 <= chosen_9619 <= 1 Integer
# 0 <= chosen_962 <= 1 Integer
# 0 <= chosen_9620 <= 1 Integer
# 0 <= chosen_9621 <= 1 Integer
# 0 <= chosen_9622 <= 1 Integer
# 0 <= chosen_9623 <= 1 Integer
# 0 <= chosen_9624 <= 1 Integer
# 0 <= chosen_9625 <= 1 Integer
# 0 <= chosen_9626 <= 1 Integer
# 0 <= chosen_9627 <= 1 Integer
# 0 <= chosen_9628 <= 1 Integer
# 0 <= chosen_9629 <= 1 Integer
# 0 <= chosen_963 <= 1 Integer
# 0 <= chosen_9630 <= 1 Integer
# 0 <= chosen_9631 <= 1 Integer
# 0 <= chosen_9632 <= 1 Integer
# 0 <= chosen_9633 <= 1 Integer
# 0 <= chosen_9634 <= 1 Integer
# 0 <= chosen_9635 <= 1 Integer
# 0 <= chosen_9636 <= 1 Integer
# 0 <= chosen_9637 <= 1 Integer
# 0 <= chosen_9638 <= 1 Integer
# 0 <= chosen_9639 <= 1 Integer
# 0 <= chosen_964 <= 1 Integer
# 0 <= chosen_9640 <= 1 Integer
# 0 <= chosen_9641 <= 1 Integer
# 0 <= chosen_9642 <= 1 Integer
# 0 <= chosen_9643 <= 1 Integer
# 0 <= chosen_9644 <= 1 Integer
# 0 <= chosen_9645 <= 1 Integer
# 0 <= chosen_9646 <= 1 Integer
# 0 <= chosen_9647 <= 1 Integer
# 0 <= chosen_9648 <= 1 Integer
# 0 <= chosen_9649 <= 1 Integer
# 0 <= chosen_965 <= 1 Integer
# 0 <= chosen_9650 <= 1 Integer
# 0 <= chosen_9651 <= 1 Integer
# 0 <= chosen_9652 <= 1 Integer
# 0 <= chosen_9653 <= 1 Integer
# 0 <= chosen_9654 <= 1 Integer
# 0 <= chosen_9655 <= 1 Integer
# 0 <= chosen_9656 <= 1 Integer
# 0 <= chosen_9657 <= 1 Integer
# 0 <= chosen_9658 <= 1 Integer
# 0 <= chosen_9659 <= 1 Integer
# 0 <= chosen_966 <= 1 Integer
# 0 <= chosen_9660 <= 1 Integer
# 0 <= chosen_9661 <= 1 Integer
# 0 <= chosen_9662 <= 1 Integer
# 0 <= chosen_9663 <= 1 Integer
# 0 <= chosen_9664 <= 1 Integer
# 0 <= chosen_9665 <= 1 Integer
# 0 <= chosen_9666 <= 1 Integer
# 0 <= chosen_9667 <= 1 Integer
# 0 <= chosen_9668 <= 1 Integer
# 0 <= chosen_9669 <= 1 Integer
# 0 <= chosen_967 <= 1 Integer
# 0 <= chosen_9670 <= 1 Integer
# 0 <= chosen_9671 <= 1 Integer
# 0 <= chosen_9672 <= 1 Integer
# 0 <= chosen_9673 <= 1 Integer
# 0 <= chosen_9674 <= 1 Integer
# 0 <= chosen_9675 <= 1 Integer
# 0 <= chosen_9676 <= 1 Integer
# 0 <= chosen_9677 <= 1 Integer
# 0 <= chosen_9678 <= 1 Integer
# 0 <= chosen_9679 <= 1 Integer
# 0 <= chosen_968 <= 1 Integer
# 0 <= chosen_9680 <= 1 Integer
# 0 <= chosen_9681 <= 1 Integer
# 0 <= chosen_9682 <= 1 Integer
# 0 <= chosen_9683 <= 1 Integer
# 0 <= chosen_9684 <= 1 Integer
# 0 <= chosen_9685 <= 1 Integer
# 0 <= chosen_9686 <= 1 Integer
# 0 <= chosen_9687 <= 1 Integer
# 0 <= chosen_9688 <= 1 Integer
# 0 <= chosen_9689 <= 1 Integer
# 0 <= chosen_969 <= 1 Integer
# 0 <= chosen_9690 <= 1 Integer
# 0 <= chosen_9691 <= 1 Integer
# 0 <= chosen_9692 <= 1 Integer
# 0 <= chosen_9693 <= 1 Integer
# 0 <= chosen_9694 <= 1 Integer
# 0 <= chosen_9695 <= 1 Integer
# 0 <= chosen_9696 <= 1 Integer
# 0 <= chosen_9697 <= 1 Integer
# 0 <= chosen_9698 <= 1 Integer
# 0 <= chosen_9699 <= 1 Integer
# 0 <= chosen_97 <= 1 Integer
# 0 <= chosen_970 <= 1 Integer
# 0 <= chosen_9700 <= 1 Integer
# 0 <= chosen_9701 <= 1 Integer
# 0 <= chosen_9702 <= 1 Integer
# 0 <= chosen_9703 <= 1 Integer
# 0 <= chosen_9704 <= 1 Integer
# 0 <= chosen_9705 <= 1 Integer
# 0 <= chosen_9706 <= 1 Integer
# 0 <= chosen_9707 <= 1 Integer
# 0 <= chosen_9708 <= 1 Integer
# 0 <= chosen_9709 <= 1 Integer
# 0 <= chosen_971 <= 1 Integer
# 0 <= chosen_9710 <= 1 Integer
# 0 <= chosen_9711 <= 1 Integer
# 0 <= chosen_9712 <= 1 Integer
# 0 <= chosen_9713 <= 1 Integer
# 0 <= chosen_9714 <= 1 Integer
# 0 <= chosen_9715 <= 1 Integer
# 0 <= chosen_9716 <= 1 Integer
# 0 <= chosen_9717 <= 1 Integer
# 0 <= chosen_9718 <= 1 Integer
# 0 <= chosen_9719 <= 1 Integer
# 0 <= chosen_972 <= 1 Integer
# 0 <= chosen_9720 <= 1 Integer
# 0 <= chosen_9721 <= 1 Integer
# 0 <= chosen_9722 <= 1 Integer
# 0 <= chosen_9723 <= 1 Integer
# 0 <= chosen_9724 <= 1 Integer
# 0 <= chosen_9725 <= 1 Integer
# 0 <= chosen_9726 <= 1 Integer
# 0 <= chosen_9727 <= 1 Integer
# 0 <= chosen_9728 <= 1 Integer
# 0 <= chosen_9729 <= 1 Integer
# 0 <= chosen_973 <= 1 Integer
# 0 <= chosen_9730 <= 1 Integer
# 0 <= chosen_9731 <= 1 Integer
# 0 <= chosen_9732 <= 1 Integer
# 0 <= chosen_9733 <= 1 Integer
# 0 <= chosen_9734 <= 1 Integer
# 0 <= chosen_9735 <= 1 Integer
# 0 <= chosen_9736 <= 1 Integer
# 0 <= chosen_9737 <= 1 Integer
# 0 <= chosen_9738 <= 1 Integer
# 0 <= chosen_9739 <= 1 Integer
# 0 <= chosen_974 <= 1 Integer
# 0 <= chosen_9740 <= 1 Integer
# 0 <= chosen_9741 <= 1 Integer
# 0 <= chosen_9742 <= 1 Integer
# 0 <= chosen_9743 <= 1 Integer
# 0 <= chosen_9744 <= 1 Integer
# 0 <= chosen_9745 <= 1 Integer
# 0 <= chosen_9746 <= 1 Integer
# 0 <= chosen_9747 <= 1 Integer
# 0 <= chosen_9748 <= 1 Integer
# 0 <= chosen_9749 <= 1 Integer
# 0 <= chosen_975 <= 1 Integer
# 0 <= chosen_9750 <= 1 Integer
# 0 <= chosen_9751 <= 1 Integer
# 0 <= chosen_9752 <= 1 Integer
# 0 <= chosen_9753 <= 1 Integer
# 0 <= chosen_9754 <= 1 Integer
# 0 <= chosen_9755 <= 1 Integer
# 0 <= chosen_9756 <= 1 Integer
# 0 <= chosen_9757 <= 1 Integer
# 0 <= chosen_9758 <= 1 Integer
# 0 <= chosen_9759 <= 1 Integer
# 0 <= chosen_976 <= 1 Integer
# 0 <= chosen_9760 <= 1 Integer
# 0 <= chosen_9761 <= 1 Integer
# 0 <= chosen_9762 <= 1 Integer
# 0 <= chosen_9763 <= 1 Integer
# 0 <= chosen_9764 <= 1 Integer
# 0 <= chosen_9765 <= 1 Integer
# 0 <= chosen_9766 <= 1 Integer
# 0 <= chosen_9767 <= 1 Integer
# 0 <= chosen_9768 <= 1 Integer
# 0 <= chosen_9769 <= 1 Integer
# 0 <= chosen_977 <= 1 Integer
# 0 <= chosen_9770 <= 1 Integer
# 0 <= chosen_9771 <= 1 Integer
# 0 <= chosen_9772 <= 1 Integer
# 0 <= chosen_9773 <= 1 Integer
# 0 <= chosen_9774 <= 1 Integer
# 0 <= chosen_9775 <= 1 Integer
# 0 <= chosen_9776 <= 1 Integer
# 0 <= chosen_9777 <= 1 Integer
# 0 <= chosen_9778 <= 1 Integer
# 0 <= chosen_9779 <= 1 Integer
# 0 <= chosen_978 <= 1 Integer
# 0 <= chosen_9780 <= 1 Integer
# 0 <= chosen_9781 <= 1 Integer
# 0 <= chosen_9782 <= 1 Integer
# 0 <= chosen_9783 <= 1 Integer
# 0 <= chosen_9784 <= 1 Integer
# 0 <= chosen_9785 <= 1 Integer
# 0 <= chosen_9786 <= 1 Integer
# 0 <= chosen_9787 <= 1 Integer
# 0 <= chosen_9788 <= 1 Integer
# 0 <= chosen_9789 <= 1 Integer
# 0 <= chosen_979 <= 1 Integer
# 0 <= chosen_9790 <= 1 Integer
# 0 <= chosen_9791 <= 1 Integer
# 0 <= chosen_9792 <= 1 Integer
# 0 <= chosen_9793 <= 1 Integer
# 0 <= chosen_9794 <= 1 Integer
# 0 <= chosen_9795 <= 1 Integer
# 0 <= chosen_9796 <= 1 Integer
# 0 <= chosen_9797 <= 1 Integer
# 0 <= chosen_9798 <= 1 Integer
# 0 <= chosen_9799 <= 1 Integer
# 0 <= chosen_98 <= 1 Integer
# 0 <= chosen_980 <= 1 Integer
# 0 <= chosen_9800 <= 1 Integer
# 0 <= chosen_9801 <= 1 Integer
# 0 <= chosen_9802 <= 1 Integer
# 0 <= chosen_9803 <= 1 Integer
# 0 <= chosen_9804 <= 1 Integer
# 0 <= chosen_9805 <= 1 Integer
# 0 <= chosen_9806 <= 1 Integer
# 0 <= chosen_9807 <= 1 Integer
# 0 <= chosen_9808 <= 1 Integer
# 0 <= chosen_9809 <= 1 Integer
# 0 <= chosen_981 <= 1 Integer
# 0 <= chosen_9810 <= 1 Integer
# 0 <= chosen_9811 <= 1 Integer
# 0 <= chosen_9812 <= 1 Integer
# 0 <= chosen_9813 <= 1 Integer
# 0 <= chosen_9814 <= 1 Integer
# 0 <= chosen_9815 <= 1 Integer
# 0 <= chosen_9816 <= 1 Integer
# 0 <= chosen_9817 <= 1 Integer
# 0 <= chosen_9818 <= 1 Integer
# 0 <= chosen_9819 <= 1 Integer
# 0 <= chosen_982 <= 1 Integer
# 0 <= chosen_9820 <= 1 Integer
# 0 <= chosen_9821 <= 1 Integer
# 0 <= chosen_9822 <= 1 Integer
# 0 <= chosen_9823 <= 1 Integer
# 0 <= chosen_9824 <= 1 Integer
# 0 <= chosen_9825 <= 1 Integer
# 0 <= chosen_9826 <= 1 Integer
# 0 <= chosen_9827 <= 1 Integer
# 0 <= chosen_9828 <= 1 Integer
# 0 <= chosen_9829 <= 1 Integer
# 0 <= chosen_983 <= 1 Integer
# 0 <= chosen_9830 <= 1 Integer
# 0 <= chosen_9831 <= 1 Integer
# 0 <= chosen_9832 <= 1 Integer
# 0 <= chosen_9833 <= 1 Integer
# 0 <= chosen_9834 <= 1 Integer
# 0 <= chosen_9835 <= 1 Integer
# 0 <= chosen_9836 <= 1 Integer
# 0 <= chosen_9837 <= 1 Integer
# 0 <= chosen_9838 <= 1 Integer
# 0 <= chosen_9839 <= 1 Integer
# 0 <= chosen_984 <= 1 Integer
# 0 <= chosen_9840 <= 1 Integer
# 0 <= chosen_9841 <= 1 Integer
# 0 <= chosen_9842 <= 1 Integer
# 0 <= chosen_9843 <= 1 Integer
# 0 <= chosen_9844 <= 1 Integer
# 0 <= chosen_9845 <= 1 Integer
# 0 <= chosen_9846 <= 1 Integer
# 0 <= chosen_9847 <= 1 Integer
# 0 <= chosen_9848 <= 1 Integer
# 0 <= chosen_9849 <= 1 Integer
# 0 <= chosen_985 <= 1 Integer
# 0 <= chosen_9850 <= 1 Integer
# 0 <= chosen_9851 <= 1 Integer
# 0 <= chosen_9852 <= 1 Integer
# 0 <= chosen_9853 <= 1 Integer
# 0 <= chosen_9854 <= 1 Integer
# 0 <= chosen_9855 <= 1 Integer
# 0 <= chosen_9856 <= 1 Integer
# 0 <= chosen_9857 <= 1 Integer
# 0 <= chosen_9858 <= 1 Integer
# 0 <= chosen_9859 <= 1 Integer
# 0 <= chosen_986 <= 1 Integer
# 0 <= chosen_9860 <= 1 Integer
# 0 <= chosen_9861 <= 1 Integer
# 0 <= chosen_9862 <= 1 Integer
# 0 <= chosen_9863 <= 1 Integer
# 0 <= chosen_9864 <= 1 Integer
# 0 <= chosen_9865 <= 1 Integer
# 0 <= chosen_9866 <= 1 Integer
# 0 <= chosen_9867 <= 1 Integer
# 0 <= chosen_9868 <= 1 Integer
# 0 <= chosen_9869 <= 1 Integer
# 0 <= chosen_987 <= 1 Integer
# 0 <= chosen_9870 <= 1 Integer
# 0 <= chosen_9871 <= 1 Integer
# 0 <= chosen_9872 <= 1 Integer
# 0 <= chosen_9873 <= 1 Integer
# 0 <= chosen_9874 <= 1 Integer
# 0 <= chosen_9875 <= 1 Integer
# 0 <= chosen_9876 <= 1 Integer
# 0 <= chosen_9877 <= 1 Integer
# 0 <= chosen_9878 <= 1 Integer
# 0 <= chosen_9879 <= 1 Integer
# 0 <= chosen_988 <= 1 Integer
# 0 <= chosen_9880 <= 1 Integer
# 0 <= chosen_9881 <= 1 Integer
# 0 <= chosen_9882 <= 1 Integer
# 0 <= chosen_9883 <= 1 Integer
# 0 <= chosen_9884 <= 1 Integer
# 0 <= chosen_9885 <= 1 Integer
# 0 <= chosen_9886 <= 1 Integer
# 0 <= chosen_9887 <= 1 Integer
# 0 <= chosen_9888 <= 1 Integer
# 0 <= chosen_9889 <= 1 Integer
# 0 <= chosen_989 <= 1 Integer
# 0 <= chosen_9890 <= 1 Integer
# 0 <= chosen_9891 <= 1 Integer
# 0 <= chosen_9892 <= 1 Integer
# 0 <= chosen_9893 <= 1 Integer
# 0 <= chosen_9894 <= 1 Integer
# 0 <= chosen_9895 <= 1 Integer
# 0 <= chosen_9896 <= 1 Integer
# 0 <= chosen_9897 <= 1 Integer
# 0 <= chosen_9898 <= 1 Integer
# 0 <= chosen_9899 <= 1 Integer
# 0 <= chosen_99 <= 1 Integer
# 0 <= chosen_990 <= 1 Integer
# 0 <= chosen_9900 <= 1 Integer
# 0 <= chosen_9901 <= 1 Integer
# 0 <= chosen_9902 <= 1 Integer
# 0 <= chosen_9903 <= 1 Integer
# 0 <= chosen_9904 <= 1 Integer
# 0 <= chosen_9905 <= 1 Integer
# 0 <= chosen_9906 <= 1 Integer
# 0 <= chosen_9907 <= 1 Integer
# 0 <= chosen_9908 <= 1 Integer
# 0 <= chosen_9909 <= 1 Integer
# 0 <= chosen_991 <= 1 Integer
# 0 <= chosen_9910 <= 1 Integer
# 0 <= chosen_9911 <= 1 Integer
# 0 <= chosen_9912 <= 1 Integer
# 0 <= chosen_9913 <= 1 Integer
# 0 <= chosen_9914 <= 1 Integer
# 0 <= chosen_9915 <= 1 Integer
# 0 <= chosen_9916 <= 1 Integer
# 0 <= chosen_9917 <= 1 Integer
# 0 <= chosen_9918 <= 1 Integer
# 0 <= chosen_9919 <= 1 Integer
# 0 <= chosen_992 <= 1 Integer
# 0 <= chosen_9920 <= 1 Integer
# 0 <= chosen_9921 <= 1 Integer
# 0 <= chosen_9922 <= 1 Integer
# 0 <= chosen_9923 <= 1 Integer
# 0 <= chosen_9924 <= 1 Integer
# 0 <= chosen_9925 <= 1 Integer
# 0 <= chosen_9926 <= 1 Integer
# 0 <= chosen_9927 <= 1 Integer
# 0 <= chosen_9928 <= 1 Integer
# 0 <= chosen_9929 <= 1 Integer
# 0 <= chosen_993 <= 1 Integer
# 0 <= chosen_9930 <= 1 Integer
# 0 <= chosen_9931 <= 1 Integer
# 0 <= chosen_9932 <= 1 Integer
# 0 <= chosen_9933 <= 1 Integer
# 0 <= chosen_9934 <= 1 Integer
# 0 <= chosen_9935 <= 1 Integer
# 0 <= chosen_9936 <= 1 Integer
# 0 <= chosen_9937 <= 1 Integer
# 0 <= chosen_9938 <= 1 Integer
# 0 <= chosen_9939 <= 1 Integer
# 0 <= chosen_994 <= 1 Integer
# 0 <= chosen_9940 <= 1 Integer
# 0 <= chosen_9941 <= 1 Integer
# 0 <= chosen_9942 <= 1 Integer
# 0 <= chosen_9943 <= 1 Integer
# 0 <= chosen_9944 <= 1 Integer
# 0 <= chosen_9945 <= 1 Integer
# 0 <= chosen_9946 <= 1 Integer
# 0 <= chosen_9947 <= 1 Integer
# 0 <= chosen_9948 <= 1 Integer
# 0 <= chosen_9949 <= 1 Integer
# 0 <= chosen_995 <= 1 Integer
# 0 <= chosen_9950 <= 1 Integer
# 0 <= chosen_9951 <= 1 Integer
# 0 <= chosen_9952 <= 1 Integer
# 0 <= chosen_9953 <= 1 Integer
# 0 <= chosen_9954 <= 1 Integer
# 0 <= chosen_9955 <= 1 Integer
# 0 <= chosen_9956 <= 1 Integer
# 0 <= chosen_9957 <= 1 Integer
# 0 <= chosen_9958 <= 1 Integer
# 0 <= chosen_9959 <= 1 Integer
# 0 <= chosen_996 <= 1 Integer
# 0 <= chosen_9960 <= 1 Integer
# 0 <= chosen_9961 <= 1 Integer
# 0 <= chosen_9962 <= 1 Integer
# 0 <= chosen_9963 <= 1 Integer
# 0 <= chosen_9964 <= 1 Integer
# 0 <= chosen_9965 <= 1 Integer
# 0 <= chosen_9966 <= 1 Integer
# 0 <= chosen_9967 <= 1 Integer
# 0 <= chosen_9968 <= 1 Integer
# 0 <= chosen_9969 <= 1 Integer
# 0 <= chosen_997 <= 1 Integer
# 0 <= chosen_9970 <= 1 Integer
# 0 <= chosen_9971 <= 1 Integer
# 0 <= chosen_9972 <= 1 Integer
# 0 <= chosen_9973 <= 1 Integer
# 0 <= chosen_9974 <= 1 Integer
# 0 <= chosen_9975 <= 1 Integer
# 0 <= chosen_9976 <= 1 Integer
# 0 <= chosen_9977 <= 1 Integer
# 0 <= chosen_9978 <= 1 Integer
# 0 <= chosen_9979 <= 1 Integer
# 0 <= chosen_998 <= 1 Integer
# 0 <= chosen_9980 <= 1 Integer
# 0 <= chosen_9981 <= 1 Integer
# 0 <= chosen_9982 <= 1 Integer
# 0 <= chosen_9983 <= 1 Integer
# 0 <= chosen_9984 <= 1 Integer
# 0 <= chosen_9985 <= 1 Integer
# 0 <= chosen_9986 <= 1 Integer
# 0 <= chosen_9987 <= 1 Integer
# 0 <= chosen_9988 <= 1 Integer
# 0 <= chosen_9989 <= 1 Integer
# 0 <= chosen_999 <= 1 Integer
# 0 <= chosen_9990 <= 1 Integer
# 0 <= chosen_9991 <= 1 Integer
# 0 <= chosen_9992 <= 1 Integer
# 0 <= chosen_9993 <= 1 Integer
# 0 <= chosen_9994 <= 1 Integer
# 0 <= chosen_9995 <= 1 Integer
# 0 <= chosen_9996 <= 1 Integer
# 0 <= chosen_9997 <= 1 Integer
# 0 <= chosen_9998 <= 1 Integer
# 0 <= chosen_9999 <= 1 Integer

# %%
prob.solve(pulp.PULP_CBC_CMD(timeLimit=120, msg=True))
# Out:
# -1

# %%
chosen_games = []
for value in chosen:
    if chosen[value].varValue == 1:
        print(value,chosen[value].varValue)
        chosen_games.append(value)
# Out:
# 9497 1.0
# 9260 1.0
# 11235 1.0
# 11243 1.0
# 2641 1.0
# 11329 1.0
# 9897 1.0
# 11891 1.0
# 10981 1.0
# 3870 1.0
# 6375 1.0
# 8572 1.0
# 7937 1.0
# 5567 1.0
# 10558 1.0
# 6586 1.0
# 11314 1.0
# 9826 1.0
# 8957 1.0
# 4640 1.0
# 3364 1.0
# 9008 1.0
# 9561 1.0
# 10789 1.0
# 6758 1.0
# 8832 1.0
# 10156 1.0
# 11249 1.0
# 6006 1.0
# 9827 1.0
# 8789 1.0
# 9974 1.0
# 4781 1.0
# 7998 1.0
# 10692 1.0
# 9867 1.0
# 3581 1.0
# 11245 1.0
# 10484 1.0
# 10010 1.0
# 7324 1.0
# 7923 1.0
# 11239 1.0
# 3134 1.0
# 11905 1.0
# 4557 1.0
# 5945 1.0
# 11247 1.0
# 10255 1.0
# 9667 1.0
# 8877 1.0
# 5120 1.0
# 10383 1.0
# 3934 1.0
# 9939 1.0
# 2670 1.0
# 4627 1.0
# 8814 1.0
# 11192 1.0
# 6846 1.0
# 10085 1.0
# 11193 1.0
# 8523 1.0
# 10485 1.0
# 9853 1.0
# 11178 1.0
# 11197 1.0
# 10243 1.0
# 11130 1.0
# 10500 1.0
# 10956 1.0
# 4416 1.0
# 10093 1.0
# 3935 1.0
# 4646 1.0
# 10809 1.0
# 10109 1.0
# 12280 1.0
# 10047 1.0
# 9891 1.0
# 9912 1.0
# 9991 1.0
# 7829 1.0
# 10831 1.0
# 9383 1.0
# 9778 1.0
# 8653 1.0
# 10654 1.0
# 10338 1.0
# 9074 1.0
# 11069 1.0
# 1408 1.0
# 5121 1.0
# 9966 1.0
# 168 1.0
# 4192 1.0
# 11224 1.0
# 10495 1.0
# 5992 1.0
# 11127 1.0
# 10653 1.0
# 3858 1.0
# 9412 1.0
# 5540 1.0
# 8537 1.0
# 7828 1.0
# 12250 1.0
# 11067 1.0
# 5771 1.0
# 4193 1.0
# 11225 1.0
# 11304 1.0
# 4513 1.0

# %%
len(chosen_games)
# Out:
# 113

# %%
games_500 = unranked_data[unranked_data["game_id"].isin(chosen_games)].sort_values("pythag_error_rank")

# %%
true_target_values
# Out:
# {'total': 240,
#  'home_spread': 12,
#  'home_win': 0.5,
#  'away_win': 0.5,
#  'over_prob': 0.5,
#  'under_prob': 0.5}

# %%
home_spread_cover_count = games_500.query("spread_result == 'home_cover'").shape[0]
away_spread_cover_count = games_500.query("spread_result == 'away_cover'").shape[0]
push_spread_cover_count = games_500.query("spread_result == 'push'").shape[0]

print(home_spread_cover_count, away_spread_cover_count, push_spread_cover_count,home_spread_cover_count + away_spread_cover_count + push_spread_cover_count)
print(home_spread_cover_count/(home_spread_cover_count + away_spread_cover_count), away_spread_cover_count/(home_spread_cover_count + away_spread_cover_count))
# Out:
# 50 61 2 113
# 0.45045045045045046 0.5495495495495496

# %%
under_total_result_count = games_500.query("total_result == 'under'").shape[0]
over_total_result_count = games_500.query("total_result == 'over'").shape[0]
push_total_result_count = games_500.query("total_result == 'push'").shape[0]

print(over_total_result_count, under_total_result_count, push_total_result_count, under_total_result_count + over_total_result_count + push_total_result_count)
print(over_total_result_count/(under_total_result_count+ over_total_result_count), under_total_result_count/(over_total_result_count+ under_total_result_count))
# Out:
# 56 57 0 113
# 0.49557522123893805 0.504424778761062

# %%
home_predictive_spread_cover_count = games_500.query("predictive_spread_cover == 'home'").shape[0]
away_predictive_spread_cover_count = games_500.query("predictive_spread_cover == 'away'").shape[0]
push_predictive_spread_cover_count = games_500.query("predictive_spread_cover == 'push'").shape[0]

print(home_predictive_spread_cover_count, away_predictive_spread_cover_count, push_predictive_spread_cover_count,home_predictive_spread_cover_count + away_predictive_spread_cover_count + push_predictive_spread_cover_count)
print(home_predictive_spread_cover_count/(home_predictive_spread_cover_count + away_predictive_spread_cover_count), away_predictive_spread_cover_count/(home_predictive_spread_cover_count + away_predictive_spread_cover_count))
# Out:
# 53 56 4 113
# 0.48623853211009177 0.5137614678899083

# %%
over_predictive_total_count = games_500.query("predictive_total == 'over'").shape[0]
under_predictive_total_count = games_500.query("predictive_total == 'under'").shape[0]
push_predictive_total_count = games_500.query("predictive_total == 'push'").shape[0]

print(over_predictive_total_count, under_predictive_total_count, push_predictive_total_count,over_predictive_total_count + under_predictive_total_count + push_predictive_total_count)
print(over_predictive_total_count/(over_predictive_total_count + under_predictive_total_count), under_predictive_total_count/(over_predictive_total_count + under_predictive_total_count))
# Out:
# 51 58 4 113
# 0.46788990825688076 0.5321100917431193

# %%
over_actual_total_count = games_500.query(f"points > {true_target_values['total']}").shape[0]
away_actual_total_count = games_500.query(f"points < {true_target_values['total']}").shape[0]
push_actual_total_count = games_500.query(f"points == {true_target_values['total']}").shape[0]

print(over_actual_total_count, away_actual_total_count, push_actual_total_count,over_actual_total_count + away_actual_total_count + push_actual_total_count)
print(over_actual_total_count/(over_actual_total_count + away_actual_total_count), away_actual_total_count/(over_actual_total_count + away_actual_total_count))
# Out:
# 56 57 0 113
# 0.49557522123893805 0.504424778761062

# %%
games_500
# Out:
#        game_id   game_date           home_team              away_team  \
# 9116     10831  2021-03-19  Washington Wizards              Utah Jazz
# 6106      6846  2017-11-30  Los Angeles Lakers  Golden State Warriors
# 8153     10047  2020-02-25  Washington Wizards        Milwaukee Bucks
# 1921     11314  2021-05-14      Indiana Pacers        Milwaukee Bucks
# 2663     10789  2021-03-14  Washington Wizards        Milwaukee Bucks
# ...        ...         ...                 ...                    ...
# 5957      4627  2016-01-21       Brooklyn Nets    Cleveland Cavaliers
# 7670      4646  2016-01-23  Los Angeles Lakers      San Antonio Spurs
# 2382      3364  2015-01-09     New York Knicks        Houston Rockets
# 11875     3858  2015-03-26     New York Knicks   Los Angeles Clippers
# 4589      4557  2016-01-12       Brooklyn Nets      San Antonio Spurs
#
#        home_score  away_score  spread  total  over_odds  under_odds  ...  \
# 9116          131         122    10.5  241.0       -111        -108  ...
# 6106          123         127    13.0  242.0       -114        -114  ...
# 8153          134         137    12.5  243.5       -109        -108  ...
# 1921          133         142     9.0  241.5       -108        -110  ...
# 2663          119         125    13.0  236.0       -110        -108  ...
# ...           ...         ...     ...    ...        ...         ...  ...
# 5957           78          91    13.0  197.0       -106        -106  ...
# 7670           95         108    16.0  199.0       -106        -108  ...
# 2382           96         120    12.5  194.5       -112        -108  ...
# 11875          80         111    15.0  197.0       -106        -109  ...
# 4589           79         106    14.5  195.5       -108        -107  ...
#
#        over_true_prob  home_margin  points  spread_home  pythag_error  \
# 9116         0.503270            9     253         10.5           2.5
# 6106         0.500000           -4     250         13.0           3.0
# 8153         0.501105           -3     271         12.5           4.0
# 1921         0.497805           -9     275          9.0           4.5
# 2663         0.502195           -6     244         13.0           5.0
# ...               ...          ...     ...          ...           ...
# 5957         0.500000          -13     169         13.0          44.0
# 7670         0.497742          -13     203         16.0          45.0
# 2382         0.504330          -24     216         12.5          46.0
# 11875        0.496637          -31     191         15.0          46.0
# 4589         0.501121          -27     185         14.5          47.0
#
#        total_result  spread_result  predictive_spread_cover predictive_total  \
# 9116           over     home_cover                     home             over
# 6106           over     home_cover                     away             over
# 8153           over     home_cover                     away             over
# 1921           over     home_cover                     home             over
# 2663           over     home_cover                     away            under
# ...             ...            ...                      ...              ...
# 5957          under     away_cover                     away            under
# 7670          under     away_cover                     away            under
# 2382          under     away_cover                     away            under
# 11875         under     away_cover                     away            under
# 4589          under     away_cover                     away            under
#
#       pythag_error_rank
# 9116                1.0
# 6106                2.0
# 8153                5.0
# 1921                7.0
# 2663                9.0
# ...                 ...
# 5957             6169.0
# 7670             6528.0
# 2382             6797.0
# 11875            6939.0
# 4589             7175.0
#
# [113 rows x 23 columns]

# %%
games_500.to_excel("sampled_data_with_4_medians.xlsx",index=False)
